# %%
import pandas as pd

df = pd.read_csv("test_generation_2.tsv", sep="\t", na_filter=False)
print(df.columns)
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'filename', 'report_id', 'enc_text',
#        'labels', 'enc_text_eddl', 'target_text', 'gen_text', 'gen_wis',
#        'partition', 'bleu'],
#       dtype='object')

# %%
display(df.loc[df.partition == "train"])
# Out:
#       Unnamed: 0.1  Unnamed: 0                  filename  report_id  \
# 1                1           1   CXR1_1_IM-0001-4001.png          1
# 2                2           2    CXR10_IM-0002-1001.png         10
# 3                3           3    CXR10_IM-0002-2001.png         10
# 7                7           7  CXR1000_IM-0003-2001.png       1000
# 8                8           8  CXR1000_IM-0003-3001.png       1000
# ...            ...         ...                       ...        ...
# 7460          7460        7460   CXR995_IM-2478-1002.png        995
# 7462          7462        7462   CXR996_IM-2479-2001.png        996
# 7464          7464        7464   CXR997_IM-2479-2001.png        997
# 7466          7466        7466   CXR998_IM-2479-2001.png        998
# 7469          7469        7469   CXR999_IM-2480-3001.png        999
#
#                                                enc_text labels  \
# 1     5 51 32 9 46 19 7 22 14 54 2. 15 6 4 21 131 2....     16
# ...

# %%
print("train:", df.loc[df.partition=="train", "bleu"].mean() )
print("validation:", df.loc[df.partition=="validation", "bleu"].mean())
print("test:", df.loc[df.partition=="test", "bleu"].mean())
# Out:
# train: 0.02637580540611567
# validation: nan
# test: 0.027497637906498663

# %%
df.loc[df.partition=="validation"]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, filename, report_id, enc_text, labels, enc_text_eddl, target_text, gen_text, gen_wis, partition, bleu]
# Index: []
