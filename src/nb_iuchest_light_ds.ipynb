# %% [markdown]
# <font color="yellow">IU-Chest X-Ray dataset</font>
#
# This notebook contains pre-processing and plotting functions.

# %% [markdown]
# The first set of cells process raw files (as they are downloaded)

# %%
from bs4 import BeautifulSoup
from collections import defaultdict
import numpy as np
import os
import numpy as np
from numpy import count_nonzero as nnz
import pandas as pd
import pickle
from posixpath import join
from tqdm.notebook import tqdm
import os
import lightning.reports as iureports
from lightning.vocabulary_light import Vocabulary

# %load_ext autoreload
# %autoreload 2
base_path = "/mnt/datasets/uc5/std-dataset"  # subfolders image, text
reports_fld = join(base_path, "text")
images_fld = join(base_path, "image")

meta_fld = "/mnt/datasets/uc5/meta/iuchest_light"
os.makedirs(meta_fld, exist_ok=True)

# %%
# process dataset and produce a first, raw csv file with all the available information

def filename_from_path(path, keep_extension=True):
    base = os.path.basename(path)
    if keep_extension:
        return base

    pre, _ = os.path.splitext(base)
    return pre
    
def parse_id(soup):
    keys = ['pmcid', 'iuxrid', 'uid']
    d = defaultdict(None)
    selected_id = None
    for k in keys:
        if soup(k):
            # since: soup(k) returns:
            #        [<pmcid id="3315"></pmcid>]
            # 1) soup(k)[0] takes the first element of the result set: <pmcid id="3315"></pmcid>
            # 2) soup(k)[0].get('id') reads the value of the property 'id': 3315
            v = soup(k)[0].get('id')
            d[k] = v
            selected_id = v
            if k == keys[0] or k == keys[1]:
                # prefer pmcid or uixrid, that are simple integers. uid starts with 'CXR'
                # example: pmcid=3700, uixrid=3700, uid=CXR3700
                # break as soon as you find one of the first two keys
                break
    assert selected_id  # is not None and is not empty, fail otherwise
    return {"id": selected_id}

def parse_medical_texts(soup):
    a = soup.abstract
    ats = a.find_all('abstracttext')
    res = {}
    valid_labels = ["impression", "indication", "findings", "comparison"]
    for at in ats:
        label = at.get('label').lower()
        if label in valid_labels:
            res[label] = at.text
    return res

def parse_mesh_terms(soup):
    mt = soup.mesh
    res = {}
    if mt:
        mt_major = mt.find_all('major')
        mt_minor = mt.find_all('minor')
        if mt_major:
            res["orig_mesh_terms"] = [major.text for major in mt_major if major.text]
        if mt_minor:
            res["minor_mesh"] = [minor.text for minor in mt_minor if minor.text]
    return res

def parse_automatic_terms(soup):
    mt = soup.mesh
    res = {}
    terms = []
    if mt:
        mt_auto = mt.find_all('automatic')
        if mt_auto:
            terms = [term.text for term in mt_auto if term.text]
    res["orig_auto_term"] = terms
    return res

def parse_images(soup):
    res = []
    imgs = soup.find_all('parentimage')
    for img in imgs:
        d = {}
        if img.caption:
            d["image_caption"] = img.caption.text
        if img.url:
            p = img.url.text  # this is an absolute path
            fn = filename_from_path(p, keep_extension=False)
            # dataset contains png images, but paths in reports point to (old) jpeg versions
            d["image_filename"] = fn + '.png'
        else:
            print('FATAL: NO img.url')
            exit()
        res.append(d)
    return res  # {"images": res}


def parse_single_report(filepath, verbose=False):
    with open(filepath, "r", encoding="utf-8") as fin:
        xml = fin.read()
    soup = BeautifulSoup(xml, "lxml")
    parsed = {}
    parsed.update(parse_id(soup))
    parsed.update(parse_medical_texts(soup))
    parsed.update(parse_mesh_terms(soup))
    parsed.update(parse_automatic_terms(soup))
    images = parse_images(soup)
    parsed["image_filename"] = [d["image_filename"] for d in images]
    parsed["filename"] = os.path.basename(filepath)
    return parsed

def parse_reports(txt_fld, ext="xml", verbose=False, dev=False):
    reports = []
    for i, fn in enumerate(tqdm( [ join(txt_fld, fn) for fn in os.listdir(txt_fld) if (ext is None or fn.endswith(ext)) ])):
        reports.append(parse_single_report(fn))
    return reports




reports = parse_reports(reports_fld)
reports = pd.DataFrame.from_records(reports).set_index("id")
reports.sort_index(inplace=True)

reports["n_images"] = reports["image_filename"].apply(lambda l: len(l))
reports["n_orig_mesh_terms"] = reports["orig_mesh_terms"].apply(lambda l: len(l))
reports["n_orig_auto_terms"] = reports["orig_auto_term"].apply(lambda l: len(l))

out_fn = join(meta_fld, "reports_raw.pkl")
reports.to_pickle( out_fn )
print(f"saved {out_fn}, all done.")
# Out:
#   0%|          | 0/3955 [00:00<?, ?it/s]
# saved /mnt/datasets/uc5/meta/iuchest_light/reports_raw.pkl, all done.

# %% [markdown]
# # <font color="red">STEP</font>
# <font color="yellow">previously on nb_iuchsts.nb, reports processed and saved in the file reports_raw.pkl.</font>
# The next cells perform basic operations that are needed for any subsequent processing pipeline:
# 1. remove reports without images;
# 2. all text to lowercase;
# 3. add some columns with text length and number of sentences;
# 4. clean MeSH and automatic terms. In case of automatic terms, there is a step for term normalization using term equivalences provided by the dataset authors (and available on the website);
# 5. text in impression, findings, etc. is CLEANED (see the cell for details)

# %%
from bs4 import BeautifulSoup
from collections import defaultdict
import numpy as np
import os
import numpy as np
from numpy import count_nonzero as nnz
import pandas as pd
import pickle
from posixpath import join
from tqdm.notebook import tqdm

import lightning.reports as iureports
from lightning.vocabulary_light import Vocabulary
from nltk import sent_tokenize


# %load_ext autoreload
# %autoreload 2
base_path = "/mnt/datasets/uc5/std-dataset"  # subfolders image, text
reports_fld = join(base_path, "text")
images_fld = join(base_path, "image")

meta_fld = "/mnt/datasets/uc5/meta/iuchest_light"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_pickle( join(meta_fld, "reports_raw.pkl"))
print(f"raw csv, shape {df.shape}")
display(df.T)
# Out:
# raw csv, shape (3955, 11)
# id                                                                 1  \
# comparison                                                     None.
# indication                                          Positive TB test
# findings           The cardiac silhouette and mediastinum size ar...
# impression                                      Normal chest x-XXXX.
# orig_mesh_terms                                             [normal]
# orig_auto_term                                                    []
# image_filename     [CXR1_1_IM-0001-3001.png, CXR1_1_IM-0001-4001....
# filename                                                       1.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  0
#
# id                                                                10  \
# comparison                                   Chest radiographs XXXX.
# indication                           XXXX-year-old male, chest pain.
# findings           The cardiomediastinal silhouette is within nor...
# impression                         No acute cardiopulmonary process.
# orig_mesh_terms          [Calcified Granuloma/lung/upper lobe/right]
# orig_auto_term                                 [calcified granuloma]
# image_filename      [CXR10_IM-0002-1001.png, CXR10_IM-0002-2001.png]
# filename                                                      10.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  1
#
# id                                                               100  \
# comparison                                                     None.
# indication
# findings           Both lungs are clear and expanded. Heart and m...
# impression                                        No active disease.
# orig_mesh_terms                                             [normal]
# orig_auto_term                                                    []
# image_filename     [CXR100_IM-0002-1001.png, CXR100_IM-0002-2001....
# filename                                                     100.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  0
#
# id                                                              1000  \
# comparison                     XXXX PA and lateral chest radiographs
# indication                                 XXXX-year-old male, XXXX.
# findings           There is XXXX increased opacity within the rig...
# impression         1. Increased opacity in the right upper lobe w...
# orig_mesh_terms    [Opacity/lung/upper lobe/right, Pulmonary Atel...
# orig_auto_term     [atelectases, mass lesion, opacity, Atelectasi...
# image_filename     [CXR1000_IM-0003-1001.png, CXR1000_IM-0003-200...
# filename                                                    1000.xml
# n_images                                                           3
# n_orig_mesh_terms                                                  3
# n_orig_auto_terms                                                  5
#
# id                                                              1001  \
# comparison                                                      None
# indication         dyspnea, subjective fevers, arthritis, immigra...
# findings           Interstitial markings are diffusely prominent ...
# impression         Diffuse fibrosis. No visible focal acute disease.
# orig_mesh_terms    [Markings/lung/bilateral/interstitial/diffuse/...
# orig_auto_term      [diffuse fibrosis, Fibrosis, Pulmonary Fibrosis]
# image_filename     [CXR1001_IM-0004-1001.png, CXR1001_IM-0004-100...
# filename                                                    1001.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  2
# n_orig_auto_terms                                                  3
#
# id                                                              1002  \
# comparison
# indication                                     History of chest pain
# findings
# impression         Status post left mastectomy. Heart size normal...
# orig_mesh_terms                                    [Mastectomy/left]
# orig_auto_term                   [mastectomies, Mastectomy, surgery]
# image_filename     [CXR1002_IM-0004-1001.png, CXR1002_IM-0004-200...
# filename                                                    1002.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  3
#
# id                                                              1003  \
# comparison
# indication                                         Acute bronchitis.
# findings           Heart size and pulmonary vascularity appear wi...
# impression         1. Retrocardiac soft tissue density. The appea...
# orig_mesh_terms    [Density/retrocardiac, Calcinosis/blood vessel...
# orig_auto_term     [atelectases, calcified granuloma, hiatal hern...
# image_filename                            [CXR1003_IM-0005-2002.png]
# filename                                                    1003.xml
# n_images                                                           1
# n_orig_mesh_terms                                                  5
# n_orig_auto_terms                                                  8
#
# id                                                              1004  \
# comparison                        Two views of the chest dated XXXX.
# indication         XXXX-year-old with XXXX for one month. History...
# findings           The heart, pulmonary XXXX and mediastinum are ...
# impression                         No acute cardiopulmonary disease.
# orig_mesh_terms    [Aorta/tortuous, Shoulder/bilateral/degenerati...
# orig_auto_term                                 [degenerative change]
# image_filename     [CXR1004_IM-0005-1001.png, CXR1004_IM-0005-200...
# filename                                                    1004.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  4
# n_orig_auto_terms                                                  1
#
# id                                                              1005  \
# comparison                                                     None.
# indication                                                 Pruritic.
# findings           Cardiac and mediastinal contours are within no...
# impression                                        No acute findings.
# orig_mesh_terms                                             [normal]
# orig_auto_term                                                    []
# image_filename     [CXR1005_IM-0006-1001.png, CXR1005_IM-0006-300...
# filename                                                    1005.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  0
#
# id                                                              1006  ...  \
# comparison                                                            ...
# indication                                 ,786.05 XXXX XXXX to XXXX  ...
# findings           The lungs appear clear. There are no focal air...  ...
# impression                         No acute cardiopulmonary disease.  ...
# orig_mesh_terms                                             [normal]  ...
# orig_auto_term                                                    []  ...
# image_filename     [CXR1006_IM-0007-1001.png, CXR1006_IM-0007-300...  ...
# filename                                                    1006.xml  ...
# n_images                                                           2  ...
# n_orig_mesh_terms                                                  1  ...
# n_orig_auto_terms                                                  0  ...
#
# id                                                               990  \
# comparison                                 Two-view chest from XXXX.
# indication            XXXX-year-old male with altered mental status.
# findings           Heart size within normal limits. No focal airs...
# impression                        No acute cardiopulmonary findings.
# orig_mesh_terms                                             [normal]
# orig_auto_term                                                    []
# image_filename     [CXR990_IM-2476-1001.png, CXR990_IM-2476-2001....
# filename                                                     990.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  0
#
# id                                                               991  \
# comparison                               Rib radiographs dated XXXX.
# indication         XXXX-year-old with pneumonia. Shortness of bre...
# findings           The heart size is upper limits of normal. The ...
# impression         Minimal perihilar opacity which could indicate...
# orig_mesh_terms                    [Opacity/lung/hilum/streaky/mild]
# orig_auto_term                        [atypical pneumonias, opacity]
# image_filename     [CXR991_IM-2476-1001.png, CXR991_IM-2476-2001....
# filename                                                     991.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  2
#
# id                                                               992  \
# comparison                                                      None
# indication                                                  MELANOMA
# findings           There are bilateral pulmonary nodules whose ap...
# impression         1. Bilateral pulmonary nodules suggesting pulm...
# orig_mesh_terms    [Nodule/lung/bilateral/multiple, Surgical Inst...
# orig_auto_term     [metastatic disease, nodule, opacity, pulmonar...
# image_filename     [CXR992_IM-2477-0001-0001.png, CXR992_IM-2477-...
# filename                                                     992.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  3
# n_orig_auto_terms                                                  9
#
# id                                                               993  \
# comparison                                                     None.
# indication                                     possible tuberculosis
# findings           Heart size normal. Lungs are clear. XXXX are n...
# impression                  Normal chest No evidence of tuberculosis
# orig_mesh_terms                                             [normal]
# orig_auto_term                                                    []
# image_filename     [CXR993_IM-2478-1001.png, CXR993_IM-2478-1002....
# filename                                                     993.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  0
#
# id                                                               994  \
# comparison                                                      XXXX
# indication                                         XXXX for one XXXX
# findings           The lungs are clear. The cardiomediastinal sil...
# impression                                          Negative chest .
# orig_mesh_terms                                             [normal]
# orig_auto_term                                                    []
# image_filename     [CXR994_IM-2478-1001.png, CXR994_IM-2478-2001....
# filename                                                     994.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  0
#
# id                                                               995  \
# comparison                                               XXXX, XXXX.
# indication                                      SP CABG SOB NO RALES
# findings           Sternotomy sutures and bypass grafts have been...
# impression               Post operative chest with no acute disease.
# orig_mesh_terms                                    [Sutures/sternum]
# orig_auto_term     [bypass grafts, sternotomy, Coronary Artery By...
# image_filename     [CXR995_IM-2478-1001.png, CXR995_IM-2478-1002....
# filename                                                     995.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  5
#
# id                                                               996  \
# comparison
# indication                                               chest pain.
# findings
# impression         Heart size is normal and lungs are clear. No p...
# orig_mesh_terms                                             [normal]
# orig_auto_term                                                    []
# image_filename     [CXR996_IM-2479-1001.png, CXR996_IM-2479-2001....
# filename                                                     996.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  0
#
# id                                                               997  \
# comparison                    Chest x-XXXX dated XXXX at XXXX hours.
# indication                  XXXX-year-old female, transplant workup.
# findings           Calcified mediastinal XXXX. No focal areas of ...
# impression                   No acute cardiopulmonary abnormality. .
# orig_mesh_terms    [Calcinosis/mediastinum, Thoracic Vertebrae/de...
# orig_auto_term                                 [degenerative change]
# image_filename     [CXR997_IM-2479-1001.png, CXR997_IM-2479-2001....
# filename                                                     997.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  2
# n_orig_auto_terms                                                  1
#
# id                                                               998  \
# comparison                                                     None.
# indication                             XXXX-year-old XXXX with pain.
# findings           Cardiomediastinal silhouette demonstrates norm...
# impression                     No acute cardiopulmonary abnormality.
# orig_mesh_terms    [Atherosclerosis/aorta, thoracic, Aorta, Thora...
# orig_auto_term     [atheroscleroses, degenerative disc diseases, ...
# image_filename     [CXR998_IM-2479-1001.png, CXR998_IM-2479-2001....
# filename                                                     998.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  3
# n_orig_auto_terms                                                  5
#
# id                                                               999
# comparison                                                      None
# indication                                                Chest pain
# findings           Lungs are clear bilaterally. There is no focal...
# impression                     No acute cardiopulmonary abnormality.
# orig_mesh_terms                                             [normal]
# orig_auto_term                                                    []
# image_filename     [CXR999_IM-2480-1001.png, CXR999_IM-2480-2001....
# filename                                                     999.xml
# n_images                                                           3
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  0
#
# [11 rows x 3955 columns]

# %%
# REMOVE REPORTS WITHOUT IMAGES
# image per reports
print("num images - reports with num images")
print(df.n_images.value_counts())

print("null major mesh", df.orig_mesh_terms.isnull().sum())
print("empty major mesh", nnz(df.orig_mesh_terms == ""))

# remove empty images
iii = df["n_images"] == 0
print("reports without images:", nnz(iii))
df = df.drop(df[iii].index)
print("removed reports without images, new shape", df.shape)
# Out:
# num images - reports with num images
# 2    3208
# 1     446
# 3     181
# 0     104
# 4      15
# 5       1
# Name: n_images, dtype: int64
# null major mesh 0
# empty major mesh 0
# reports without images: 104
# removed reports without images, new shape (3851, 11)

# %%
# all text to lowercase
# all to lowercase:
columns = ["comparison", "indication", "findings", "impression", "orig_mesh_terms", "orig_auto_term"]

def strip_field(s):
    s = s.strip()
    if s is None or s == "":
        return s
    elif s.endswith("."):
        return s
    else:
        return s + "."



for c in ["impression", "findings"]:
    df[c] = df[c].apply(lambda s: strip_field(s))

def to_lowercase(s):
    if isinstance(s, str):
        return s.strip().lower()
    elif isinstance(s, list):
        return [to_lowercase(x.strip()) for x in s]
    else:
        print("errors, unexpected type:", type(s))

for c in columns:
    df[c] = df[c].apply(to_lowercase)


# split text into sentences

columns = ["impression", "findings"]
for c in columns:
    df[c + "_sents"] = df[c].apply(lambda s: sent_tokenize(s))

for c in columns:
    df["len_" + c] = df[c].apply(lambda s: len(s.strip()))

for c in columns:
    df["nsents_" + c] = df[c + "_sents"].apply(lambda l: len(l))

for c in columns:
    print("column:", c)
    print(df["nsents_" + c].value_counts())

# some reports have 0 sentences either in "findings" or "impression"

def concat_columns(row):
    return row["findings"].strip() + " " + row["impression"].strip()

def concat_columns2(row):
    f = row["findings"].strip()
    i = row["impression"].strip()
    if len(i) > 0 and len(f) > 0:
        return f + " " + i
    elif len(i) > 0:
        return i
    elif len(f) > 0:
        return f
    else:
        print("EMPTY")
        print(row)
        return ""

df["raw_text"] = df.apply(concat_columns2, axis=1)
df["len_raw_text"] = df.raw_text.apply(len)
df["nsents_raw_text"] = df["nsents_findings"] + df["nsents_impression"]

assert (df.nsents_raw_text == df.nsents_findings + df.nsents_impression).all()

iii = df["raw_text"].str.len == 0
print("empty text:", nnz(iii))

eee = df["len_raw_text"] == 0
print("empty text:", nnz(eee))

iii = df["raw_text"].str == "."
print("dot:", nnz(iii))

if nnz(eee) > 0:
    display(df.loc[eee])

print("text to lowercase, done")
# Out:
# column: impression
# 1     2391
# 2      692
# 3      296
# 4      211
# 5      104
# 6       63
# 7       32
# 0       31
# 8       15
# 9       12
# 10       3
# 13       1
# Name: nsents_impression, dtype: int64
# column: findings
# 4     938
# 3     768
# 5     746
# 0     514
# 6     436
# 7     171
# 2      96
# 8      88
# 9      47
# 10     17
# 11     10
# 1       8
# 12      7
# 13      3
# 17      1
# 18      1
# Name: nsents_findings, dtype: int64
# EMPTY
# comparison
# indication
# findings
# impression
# orig_mesh_terms                                               [normal]
# orig_auto_term                                                      []
# image_filename       [CXR1137_IM-0093-12012.png, CXR1137_IM-0093-40...
# filename                                                      1137.xml
# n_images                                                             2
# n_orig_mesh_terms                                                    1
# n_orig_auto_terms                                                    0
# impression_sents                                                    []
# findings_sents                                                      []
# len_impression                                                       0
# len_findings                                                         0
# nsents_impression                                                    0
# nsents_findings                                                      0
# raw_text
# len_raw_text                                                         0
# nsents_raw_text                                                      0
# Name: 1137, dtype: object
# EMPTY
# comparison
# indication
# findings
# impression
# orig_mesh_terms                                               [normal]
# orig_auto_term                                                      []
# image_filename       [CXR1142_IM-0096-1001.png, CXR1142_IM-0096-200...
# filename                                                      1142.xml
# n_images                                                             2
# n_orig_mesh_terms                                                    1
# n_orig_auto_terms                                                    0
# impression_sents                                                    []
# findings_sents                                                      []
# len_impression                                                       0
# len_findings                                                         0
# nsents_impression                                                    0
# nsents_findings                                                      0
# raw_text
# len_raw_text                                                         0
# nsents_raw_text                                                      0
# Name: 1142, dtype: object
# EMPTY
# comparison
# indication
# findings
# impression
# orig_mesh_terms                        [normal]
# orig_auto_term                               []
# image_filename       [CXR1147_IM-0099-4004.png]
# filename                               1147.xml
# n_images                                      1
# n_orig_mesh_terms                             1
# n_orig_auto_terms                             0
# impression_sents                             []
# findings_sents                               []
# len_impression                                0
# len_findings                                  0
# nsents_impression                             0
# nsents_findings                               0
# raw_text
# len_raw_text                                  0
# nsents_raw_text                               0
# Name: 1147, dtype: object
# EMPTY
# comparison
# indication
# findings
# impression
# orig_mesh_terms                        [normal]
# orig_auto_term                               []
# image_filename       [CXR1293_IM-0192-4004.png]
# filename                               1293.xml
# n_images                                      1
# n_orig_mesh_terms                             1
# n_orig_auto_terms                             0
# impression_sents                             []
# findings_sents                               []
# len_impression                                0
# len_findings                                  0
# nsents_impression                             0
# nsents_findings                               0
# raw_text
# len_raw_text                                  0
# nsents_raw_text                               0
# Name: 1293, dtype: object
# EMPTY
# comparison
# indication
# findings
# impression
# orig_mesh_terms                                               [normal]
# orig_auto_term                                                      []
# image_filename       [CXR1297_IM-0195-1001.png, CXR1297_IM-0195-400...
# filename                                                      1297.xml
# n_images                                                             2
# n_orig_mesh_terms                                                    1
# n_orig_auto_terms                                                    0
# impression_sents                                                    []
# findings_sents                                                      []
# len_impression                                                       0
# len_findings                                                         0
# nsents_impression                                                    0
# nsents_findings                                                      0
# raw_text
# len_raw_text                                                         0
# nsents_raw_text                                                      0
# Name: 1297, dtype: object
# EMPTY
# comparison
# indication
# findings
# impression
# orig_mesh_terms                                               [normal]
# orig_auto_term                                                      []
# image_filename       [CXR1536_IM-0347-0001-0001.png, CXR1536_IM-034...
# filename                                                      1536.xml
# n_images                                                             3
# n_orig_mesh_terms                                                    1
# n_orig_auto_terms                                                    0
# impression_sents                                                    []
# findings_sents                                                      []
# len_impression                                                       0
# len_findings                                                         0
# nsents_impression                                                    0
# nsents_findings                                                      0
# raw_text
# len_raw_text                                                         0
# nsents_raw_text                                                      0
# Name: 1536, dtype: object
# EMPTY
# comparison
# indication
# findings
# impression
# orig_mesh_terms                        [normal]
# orig_auto_term                               []
# image_filename       [CXR1566_IM-0369-1001.png]
# filename                               1566.xml
# n_images                                      1
# n_orig_mesh_terms                             1
# n_orig_auto_terms                             0
# impression_sents                             []
# findings_sents                               []
# len_impression                                0
# len_findings                                  0
# nsents_impression                             0
# nsents_findings                               0
# raw_text
# len_raw_text                                  0
# nsents_raw_text                               0
# Name: 1566, dtype: object
# EMPTY
# comparison
# indication
# findings
# impression
# orig_mesh_terms                                              [normal]
# orig_auto_term                                                     []
# image_filename       [CXR16_IM-0389-1001.png, CXR16_IM-0389-2001.png]
# filename                                                       16.xml
# n_images                                                            2
# n_orig_mesh_terms                                                   1
# n_orig_auto_terms                                                   0
# impression_sents                                                   []
# findings_sents                                                     []
# len_impression                                                      0
# len_findings                                                        0
# nsents_impression                                                   0
# nsents_findings                                                     0
# raw_text
# len_raw_text                                                        0
# nsents_raw_text                                                     0
# Name: 16, dtype: object
# EMPTY
# comparison
# indication
# findings
# impression
# orig_mesh_terms                        [normal]
# orig_auto_term                               []
# image_filename       [CXR1615_IM-0398-4004.png]
# filename                               1615.xml
# n_images                                      1
# n_orig_mesh_terms                             1
# n_orig_auto_terms                             0
# impression_sents                             []
# findings_sents                               []
# len_impression                                0
# len_findings                                  0
# nsents_impression                             0
# nsents_findings                               0
# raw_text
# len_raw_text                                  0
# nsents_raw_text                               0
# Name: 1615, dtype: object
# EMPTY
# comparison
# indication
# findings
# impression
# orig_mesh_terms                                               [normal]
# orig_auto_term                                                      []
# image_filename       [CXR1690_IM-0452-1001-0001.png, CXR1690_IM-045...
# filename                                                      1690.xml
# n_images                                                             2
# n_orig_mesh_terms                                                    1
# n_orig_auto_terms                                                    0
# impression_sents                                                    []
# findings_sents                                                      []
# len_impression                                                       0
# len_findings                                                         0
# nsents_impression                                                    0
# nsents_findings                                                      0
# raw_text
# len_raw_text                                                         0
# nsents_raw_text                                                      0
# Name: 1690, dtype: object
# EMPTY
# comparison
# indication
# findings
# impression
# orig_mesh_terms                        [normal]
# orig_auto_term                               []
# image_filename       [CXR1761_IM-0497-1001.png]
# filename                               1761.xml
# n_images                                      1
# n_orig_mesh_terms                             1
# n_orig_auto_terms                             0
# impression_sents                             []
# findings_sents                               []
# len_impression                                0
# len_findings                                  0
# nsents_impression                             0
# nsents_findings                               0
# raw_text
# len_raw_text                                  0
# nsents_raw_text                               0
# Name: 1761, dtype: object
# EMPTY
# comparison
# indication
# findings
# impression
# orig_mesh_terms                                               [normal]
# orig_auto_term                                                      []
# image_filename       [CXR1778_IM-0509-1001.png, CXR1778_IM-0509-200...
# filename                                                      1778.xml
# n_images                                                             2
# n_orig_mesh_terms                                                    1
# n_orig_auto_terms                                                    0
# impression_sents                                                    []
# findings_sents                                                      []
# len_impression                                                       0
# len_findings                                                         0
# nsents_impression                                                    0
# nsents_findings                                                      0
# raw_text
# len_raw_text                                                         0
# nsents_raw_text                                                      0
# Name: 1778, dtype: object
# EMPTY
# comparison
# indication
# findings
# impression
# orig_mesh_terms                                               [normal]
# orig_auto_term                                                      []
# image_filename       [CXR2115_IM-0744-1001.png, CXR2115_IM-0744-200...
# filename                                                      2115.xml
# n_images                                                             2
# n_orig_mesh_terms                                                    1
# n_orig_auto_terms                                                    0
# impression_sents                                                    []
# findings_sents                                                      []
# len_impression                                                       0
# len_findings                                                         0
# nsents_impression                                                    0
# nsents_findings                                                      0
# raw_text
# len_raw_text                                                         0
# nsents_raw_text                                                      0
# Name: 2115, dtype: object
# EMPTY
# comparison
# indication
# findings
# impression
# orig_mesh_terms                        [normal]
# orig_auto_term                               []
# image_filename       [CXR2601_IM-1092-4001.png]
# filename                               2601.xml
# n_images                                      1
# n_orig_mesh_terms                             1
# n_orig_auto_terms                             0
# impression_sents                             []
# findings_sents                               []
# len_impression                                0
# len_findings                                  0
# nsents_impression                             0
# nsents_findings                               0
# raw_text
# len_raw_text                                  0
# nsents_raw_text                               0
# Name: 2601, dtype: object
# EMPTY
# comparison
# indication
# findings
# impression
# orig_mesh_terms                        [normal]
# orig_auto_term                               []
# image_filename       [CXR2697_IM-1167-1001.png]
# filename                               2697.xml
# n_images                                      1
# n_orig_mesh_terms                             1
# n_orig_auto_terms                             0
# impression_sents                             []
# findings_sents                               []
# len_impression                                0
# len_findings                                  0
# nsents_impression                             0
# nsents_findings                               0
# raw_text
# len_raw_text                                  0
# nsents_raw_text                               0
# Name: 2697, dtype: object
# EMPTY
# comparison
# indication
# findings
# impression
# orig_mesh_terms                                               [normal]
# orig_auto_term                                                      []
# image_filename       [CXR2765_IM-1210-1001.png, CXR2765_IM-1210-200...
# filename                                                      2765.xml
# n_images                                                             2
# n_orig_mesh_terms                                                    1
# n_orig_auto_terms                                                    0
# impression_sents                                                    []
# findings_sents                                                      []
# len_impression                                                       0
# len_findings                                                         0
# nsents_impression                                                    0
# nsents_findings                                                      0
# raw_text
# len_raw_text                                                         0
# nsents_raw_text                                                      0
# Name: 2765, dtype: object
# EMPTY
# comparison
# indication
# findings
# impression
# orig_mesh_terms                        [normal]
# orig_auto_term                               []
# image_filename       [CXR2881_IM-1285-4004.png]
# filename                               2881.xml
# n_images                                      1
# n_orig_mesh_terms                             1
# n_orig_auto_terms                             0
# impression_sents                             []
# findings_sents                               []
# len_impression                                0
# len_findings                                  0
# nsents_impression                             0
# nsents_findings                               0
# raw_text
# len_raw_text                                  0
# nsents_raw_text                               0
# Name: 2881, dtype: object
# EMPTY
# comparison
# indication
# findings
# impression
# orig_mesh_terms                                               [normal]
# orig_auto_term                                                      []
# image_filename       [CXR3367_IM-1619-3001.png, CXR3367_IM-1619-400...
# filename                                                      3367.xml
# n_images                                                             2
# n_orig_mesh_terms                                                    1
# n_orig_auto_terms                                                    0
# impression_sents                                                    []
# findings_sents                                                      []
# len_impression                                                       0
# len_findings                                                         0
# nsents_impression                                                    0
# nsents_findings                                                      0
# raw_text
# len_raw_text                                                         0
# nsents_raw_text                                                      0
# Name: 3367, dtype: object
# EMPTY
# comparison
# indication
# findings
# impression
# orig_mesh_terms                                               [normal]
# orig_auto_term                                                      []
# image_filename       [CXR3376_IM-1625-0001-0001.png, CXR3376_IM-162...
# filename                                                      3376.xml
# n_images                                                             2
# n_orig_mesh_terms                                                    1
# n_orig_auto_terms                                                    0
# impression_sents                                                    []
# findings_sents                                                      []
# len_impression                                                       0
# len_findings                                                         0
# nsents_impression                                                    0
# nsents_findings                                                      0
# raw_text
# len_raw_text                                                         0
# nsents_raw_text                                                      0
# Name: 3376, dtype: object
# EMPTY
# comparison
# indication
# findings
# impression
# orig_mesh_terms                                               [normal]
# orig_auto_term                                                      []
# image_filename       [CXR3434_IM-1662-1001.png, CXR3434_IM-1662-200...
# filename                                                      3434.xml
# n_images                                                             2
# n_orig_mesh_terms                                                    1
# n_orig_auto_terms                                                    0
# impression_sents                                                    []
# findings_sents                                                      []
# len_impression                                                       0
# len_findings                                                         0
# nsents_impression                                                    0
# nsents_findings                                                      0
# raw_text
# len_raw_text                                                         0
# nsents_raw_text                                                      0
# Name: 3434, dtype: object
# EMPTY
# comparison
# indication
# findings
# impression
# orig_mesh_terms                        [normal]
# orig_auto_term                               []
# image_filename       [CXR3782_IM-1898-1001.png]
# filename                               3782.xml
# n_images                                      1
# n_orig_mesh_terms                             1
# n_orig_auto_terms                             0
# impression_sents                             []
# findings_sents                               []
# len_impression                                0
# len_findings                                  0
# nsents_impression                             0
# nsents_findings                               0
# raw_text
# len_raw_text                                  0
# nsents_raw_text                               0
# Name: 3782, dtype: object
# EMPTY
# comparison
# indication
# findings
# impression
# orig_mesh_terms                        [normal]
# orig_auto_term                               []
# image_filename       [CXR3973_IM-2033-1001.png]
# filename                               3973.xml
# n_images                                      1
# n_orig_mesh_terms                             1
# n_orig_auto_terms                             0
# impression_sents                             []
# findings_sents                               []
# len_impression                                0
# len_findings                                  0
# nsents_impression                             0
# nsents_findings                               0
# raw_text
# len_raw_text                                  0
# nsents_raw_text                               0
# Name: 3973, dtype: object
# EMPTY
# comparison
# indication
# findings
# impression
# orig_mesh_terms                                               [normal]
# orig_auto_term                                                      []
# image_filename       [CXR614_IM-2200-1001.png, CXR614_IM-2200-4001....
# filename                                                       614.xml
# n_images                                                             2
# n_orig_mesh_terms                                                    1
# n_orig_auto_terms                                                    0
# impression_sents                                                    []
# findings_sents                                                      []
# len_impression                                                       0
# len_findings                                                         0
# nsents_impression                                                    0
# nsents_findings                                                      0
# raw_text
# len_raw_text                                                         0
# nsents_raw_text                                                      0
# Name: 614, dtype: object
# EMPTY
# comparison
# indication
# findings
# impression
# orig_mesh_terms                       [normal]
# orig_auto_term                              []
# image_filename       [CXR673_IM-2247-3001.png]
# filename                               673.xml
# n_images                                     1
# n_orig_mesh_terms                            1
# n_orig_auto_terms                            0
# impression_sents                            []
# findings_sents                              []
# len_impression                               0
# len_findings                                 0
# nsents_impression                            0
# nsents_findings                              0
# raw_text
# len_raw_text                                 0
# nsents_raw_text                              0
# Name: 673, dtype: object
# EMPTY
# comparison
# indication
# findings
# impression
# orig_mesh_terms                                               [normal]
# orig_auto_term                                                      []
# image_filename       [CXR894_IM-2404-0001-0001.png, CXR894_IM-2404-...
# filename                                                       894.xml
# n_images                                                             2
# n_orig_mesh_terms                                                    1
# n_orig_auto_terms                                                    0
# impression_sents                                                    []
# findings_sents                                                      []
# len_impression                                                       0
# len_findings                                                         0
# nsents_impression                                                    0
# nsents_findings                                                      0
# raw_text
# len_raw_text                                                         0
# nsents_raw_text                                                      0
# Name: 894, dtype: object
# empty text: 0
# empty text: 25
# dot: 0
#      comparison indication findings impression orig_mesh_terms orig_auto_term  \
# id
# 1137                                                  [normal]             []
# 1142                                                  [normal]             []
# 1147                                                  [normal]             []
# 1293                                                  [normal]             []
# 1297                                                  [normal]             []
# 1536                                                  [normal]             []
# 1566                                                  [normal]             []
# 16                                                    [normal]             []
# 1615                                                  [normal]             []
# 1690                                                  [normal]             []
# 1761                                                  [normal]             []
# 1778                                                  [normal]             []
# 2115                                                  [normal]             []
# 2601                                                  [normal]             []
# 2697                                                  [normal]             []
# 2765                                                  [normal]             []
# 2881                                                  [normal]             []
# 3367                                                  [normal]             []
# 3376                                                  [normal]             []
# 3434                                                  [normal]             []
# 3782                                                  [normal]             []
# 3973                                                  [normal]             []
# 614                                                   [normal]             []
# 673                                                   [normal]             []
# 894                                                   [normal]             []
#
#                                          image_filename  filename  n_images  \
# id
# 1137  [CXR1137_IM-0093-12012.png, CXR1137_IM-0093-40...  1137.xml         2
# 1142  [CXR1142_IM-0096-1001.png, CXR1142_IM-0096-200...  1142.xml         2
# 1147                         [CXR1147_IM-0099-4004.png]  1147.xml         1
# 1293                         [CXR1293_IM-0192-4004.png]  1293.xml         1
# 1297  [CXR1297_IM-0195-1001.png, CXR1297_IM-0195-400...  1297.xml         2
# 1536  [CXR1536_IM-0347-0001-0001.png, CXR1536_IM-034...  1536.xml         3
# 1566                         [CXR1566_IM-0369-1001.png]  1566.xml         1
# 16     [CXR16_IM-0389-1001.png, CXR16_IM-0389-2001.png]    16.xml         2
# 1615                         [CXR1615_IM-0398-4004.png]  1615.xml         1
# 1690  [CXR1690_IM-0452-1001-0001.png, CXR1690_IM-045...  1690.xml         2
# 1761                         [CXR1761_IM-0497-1001.png]  1761.xml         1
# 1778  [CXR1778_IM-0509-1001.png, CXR1778_IM-0509-200...  1778.xml         2
# 2115  [CXR2115_IM-0744-1001.png, CXR2115_IM-0744-200...  2115.xml         2
# 2601                         [CXR2601_IM-1092-4001.png]  2601.xml         1
# 2697                         [CXR2697_IM-1167-1001.png]  2697.xml         1
# 2765  [CXR2765_IM-1210-1001.png, CXR2765_IM-1210-200...  2765.xml         2
# 2881                         [CXR2881_IM-1285-4004.png]  2881.xml         1
# 3367  [CXR3367_IM-1619-3001.png, CXR3367_IM-1619-400...  3367.xml         2
# 3376  [CXR3376_IM-1625-0001-0001.png, CXR3376_IM-162...  3376.xml         2
# 3434  [CXR3434_IM-1662-1001.png, CXR3434_IM-1662-200...  3434.xml         2
# 3782                         [CXR3782_IM-1898-1001.png]  3782.xml         1
# 3973                         [CXR3973_IM-2033-1001.png]  3973.xml         1
# 614   [CXR614_IM-2200-1001.png, CXR614_IM-2200-4001....   614.xml         2
# 673                           [CXR673_IM-2247-3001.png]   673.xml         1
# 894   [CXR894_IM-2404-0001-0001.png, CXR894_IM-2404-...   894.xml         2
#
#       n_orig_mesh_terms  n_orig_auto_terms impression_sents findings_sents  \
# id
# 1137                  1                  0               []             []
# 1142                  1                  0               []             []
# 1147                  1                  0               []             []
# 1293                  1                  0               []             []
# 1297                  1                  0               []             []
# 1536                  1                  0               []             []
# 1566                  1                  0               []             []
# 16                    1                  0               []             []
# 1615                  1                  0               []             []
# 1690                  1                  0               []             []
# 1761                  1                  0               []             []
# 1778                  1                  0               []             []
# 2115                  1                  0               []             []
# 2601                  1                  0               []             []
# 2697                  1                  0               []             []
# 2765                  1                  0               []             []
# 2881                  1                  0               []             []
# 3367                  1                  0               []             []
# 3376                  1                  0               []             []
# 3434                  1                  0               []             []
# 3782                  1                  0               []             []
# 3973                  1                  0               []             []
# 614                   1                  0               []             []
# 673                   1                  0               []             []
# 894                   1                  0               []             []
#
#       len_impression  len_findings  nsents_impression  nsents_findings  \
# id
# 1137               0             0                  0                0
# 1142               0             0                  0                0
# 1147               0             0                  0                0
# 1293               0             0                  0                0
# 1297               0             0                  0                0
# 1536               0             0                  0                0
# 1566               0             0                  0                0
# 16                 0             0                  0                0
# 1615               0             0                  0                0
# 1690               0             0                  0                0
# 1761               0             0                  0                0
# 1778               0             0                  0                0
# 2115               0             0                  0                0
# 2601               0             0                  0                0
# 2697               0             0                  0                0
# 2765               0             0                  0                0
# 2881               0             0                  0                0
# 3367               0             0                  0                0
# 3376               0             0                  0                0
# 3434               0             0                  0                0
# 3782               0             0                  0                0
# 3973               0             0                  0                0
# 614                0             0                  0                0
# 673                0             0                  0                0
# 894                0             0                  0                0
#
#      raw_text  len_raw_text  nsents_raw_text
# id
# 1137                      0                0
# 1142                      0                0
# 1147                      0                0
# 1293                      0                0
# 1297                      0                0
# 1536                      0                0
# 1566                      0                0
# 16                        0                0
# 1615                      0                0
# 1690                      0                0
# 1761                      0                0
# 1778                      0                0
# 2115                      0                0
# 2601                      0                0
# 2697                      0                0
# 2765                      0                0
# 2881                      0                0
# 3367                      0                0
# 3376                      0                0
# 3434                      0                0
# 3782                      0                0
# 3973                      0                0
# 614                       0                0
# 673                       0                0
# 894                       0                0
# text to lowercase, done

# %%
# check if there are some rows with empty text 
n_empty_impression = nnz(df.impression.str.len() == 0)
n_empty_findings = nnz(df.findings.str.len() == 0)
print("n rows with empty impression:", n_empty_impression)
print("n rows with empty findings:", n_empty_findings)

# %%
# clean MeSH terms
def clean_mesh_terms(terms):
    # e.g., terms = [ "major/minor", "major/minor/minor, ...""]
    if isinstance(terms, list):
        terms = [x.split("/")[0].strip().lower() for x in terms]  # take first element in group t1/t2/t3, make it lowercase
    elif isinstance(terms, str):
        terms = [terms.strip().lower()]
    else:
        assert False, "unexpected type: " + str(type(terms))

    # some terms contain a comma: keep only the first
    new_terms = set()
    for t in terms:
        new_terms.add(t)
    new_terms = list(new_terms)
    return new_terms
        
#
df["major_mesh"] = df["orig_mesh_terms"].apply(lambda x: clean_mesh_terms(x))
df["n_major_mesh"] = df["major_mesh"].apply(lambda l: len(l))
print(df["n_major_mesh"].value_counts())
display(df.head().T)
# Out:
# 1     2267
# 2      596
# 3      388
# 4      285
# 5      144
# 6       93
# 7       44
# 8       20
# 9        9
# 10       4
# 12       1
# Name: n_major_mesh, dtype: int64
# id                                                                 1  \
# comparison                                                     none.
# indication                                          positive tb test
# findings           the cardiac silhouette and mediastinum size ar...
# impression                                      normal chest x-xxxx.
# orig_mesh_terms                                             [normal]
# orig_auto_term                                                    []
# image_filename     [CXR1_1_IM-0001-3001.png, CXR1_1_IM-0001-4001....
# filename                                                       1.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  0
# impression_sents                              [normal chest x-xxxx.]
# findings_sents     [the cardiac silhouette and mediastinum size a...
# len_impression                                                    20
# len_findings                                                     210
# nsents_impression                                                  1
# nsents_findings                                                    5
# raw_text           the cardiac silhouette and mediastinum size ar...
# len_raw_text                                                     231
# nsents_raw_text                                                    6
# major_mesh                                                  [normal]
# n_major_mesh                                                       1
#
# id                                                                10  \
# comparison                                   chest radiographs xxxx.
# indication                           xxxx-year-old male, chest pain.
# findings           the cardiomediastinal silhouette is within nor...
# impression                         no acute cardiopulmonary process.
# orig_mesh_terms          [calcified granuloma/lung/upper lobe/right]
# orig_auto_term                                 [calcified granuloma]
# image_filename      [CXR10_IM-0002-1001.png, CXR10_IM-0002-2001.png]
# filename                                                      10.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  1
# impression_sents                 [no acute cardiopulmonary process.]
# findings_sents     [the cardiomediastinal silhouette is within no...
# len_impression                                                    33
# len_findings                                                     273
# nsents_impression                                                  1
# nsents_findings                                                    4
# raw_text           the cardiomediastinal silhouette is within nor...
# len_raw_text                                                     307
# nsents_raw_text                                                    5
# major_mesh                                     [calcified granuloma]
# n_major_mesh                                                       1
#
# id                                                               100  \
# comparison                                                     none.
# indication
# findings           both lungs are clear and expanded. heart and m...
# impression                                        no active disease.
# orig_mesh_terms                                             [normal]
# orig_auto_term                                                    []
# image_filename     [CXR100_IM-0002-1001.png, CXR100_IM-0002-2001....
# filename                                                     100.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  0
# impression_sents                                [no active disease.]
# findings_sents     [both lungs are clear and expanded., heart and...
# len_impression                                                    18
# len_findings                                                      64
# nsents_impression                                                  1
# nsents_findings                                                    2
# raw_text           both lungs are clear and expanded. heart and m...
# len_raw_text                                                      83
# nsents_raw_text                                                    3
# major_mesh                                                  [normal]
# n_major_mesh                                                       1
#
# id                                                              1000  \
# comparison                     xxxx pa and lateral chest radiographs
# indication                                 xxxx-year-old male, xxxx.
# findings           there is xxxx increased opacity within the rig...
# impression         1. increased opacity in the right upper lobe w...
# orig_mesh_terms    [opacity/lung/upper lobe/right, pulmonary atel...
# orig_auto_term     [atelectases, mass lesion, opacity, atelectasi...
# image_filename     [CXR1000_IM-0003-1001.png, CXR1000_IM-0003-200...
# filename                                                    1000.xml
# n_images                                                           3
# n_orig_mesh_terms                                                  3
# n_orig_auto_terms                                                  5
# impression_sents   [1. increased opacity in the right upper lobe ...
# findings_sents     [there is xxxx increased opacity within the ri...
# len_impression                                                   268
# len_findings                                                     357
# nsents_impression                                                  3
# nsents_findings                                                    5
# raw_text           there is xxxx increased opacity within the rig...
# len_raw_text                                                     626
# nsents_raw_text                                                    8
# major_mesh                          [pulmonary atelectasis, opacity]
# n_major_mesh                                                       2
#
# id                                                              1001
# comparison                                                      none
# indication         dyspnea, subjective fevers, arthritis, immigra...
# findings           interstitial markings are diffusely prominent ...
# impression         diffuse fibrosis. no visible focal acute disease.
# orig_mesh_terms    [markings/lung/bilateral/interstitial/diffuse/...
# orig_auto_term      [diffuse fibrosis, fibrosis, pulmonary fibrosis]
# image_filename     [CXR1001_IM-0004-1001.png, CXR1001_IM-0004-100...
# filename                                                    1001.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  2
# n_orig_auto_terms                                                  3
# impression_sents   [diffuse fibrosis., no visible focal acute dis...
# findings_sents     [interstitial markings are diffusely prominent...
# len_impression                                                    49
# len_findings                                                     113
# nsents_impression                                                  2
# nsents_findings                                                    3
# raw_text           interstitial markings are diffusely prominent ...
# len_raw_text                                                     163
# nsents_raw_text                                                    5
# major_mesh                                      [markings, fibrosis]
# n_major_mesh                                                       2

# %%
# clean auto terms
# normal when set of tags is empty
df["orig_auto_term"] = df["orig_auto_term"].apply(lambda x: ["normal"] if len(x)==0 else x)
list_of_auto = df.orig_auto_term.tolist()
u_auto = set()
for l in list_of_auto:
    for ll in l:
        u_auto.add(ll)

print("n unique auto terms:", len(u_auto))

# normalize terms
norm_terms = {}
with open(join("lightning", "auto_term_norm.txt"), "r", encoding="utf-8") as fin:
        lines = [line for line in fin.readlines() if len(line.strip()) > 0]

for line in lines:
    subst = [t.strip() for t in line.split(":") if len(t.strip()) > 0]
    norm_terms[subst[0]] = subst[1]
    # print(f"{subst[0]} -> {subst[1]}")
print(f"{len(norm_terms)} substitutions")

def perform_subst(terms):
        new_terms = set()
        for t in terms:
            new_term = norm_terms.get(t, t)
            if new_term != t:
                # print(f"{t} -> {new_term}")
                pass
            new_terms.add(new_term)
        return sorted(list(new_terms))

df["auto_term"] = df["orig_auto_term"].apply(lambda x: perform_subst(x))
display(df.T)
print("auto terms, done")
# Out:
# n unique auto terms: 572
# 49 substitutions
# id                                                                 1  \
# comparison                                                     none.
# indication                                          positive tb test
# findings           the cardiac silhouette and mediastinum size ar...
# impression                                      normal chest x-xxxx.
# orig_mesh_terms                                             [normal]
# orig_auto_term                                              [normal]
# image_filename     [CXR1_1_IM-0001-3001.png, CXR1_1_IM-0001-4001....
# filename                                                       1.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  0
# impression_sents                              [normal chest x-xxxx.]
# findings_sents     [the cardiac silhouette and mediastinum size a...
# len_impression                                                    20
# len_findings                                                     210
# nsents_impression                                                  1
# nsents_findings                                                    5
# raw_text           the cardiac silhouette and mediastinum size ar...
# len_raw_text                                                     231
# nsents_raw_text                                                    6
# major_mesh                                                  [normal]
# n_major_mesh                                                       1
# auto_term                                                   [normal]
#
# id                                                                10  \
# comparison                                   chest radiographs xxxx.
# indication                           xxxx-year-old male, chest pain.
# findings           the cardiomediastinal silhouette is within nor...
# impression                         no acute cardiopulmonary process.
# orig_mesh_terms          [calcified granuloma/lung/upper lobe/right]
# orig_auto_term                                 [calcified granuloma]
# image_filename      [CXR10_IM-0002-1001.png, CXR10_IM-0002-2001.png]
# filename                                                      10.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  1
# impression_sents                 [no acute cardiopulmonary process.]
# findings_sents     [the cardiomediastinal silhouette is within no...
# len_impression                                                    33
# len_findings                                                     273
# nsents_impression                                                  1
# nsents_findings                                                    4
# raw_text           the cardiomediastinal silhouette is within nor...
# len_raw_text                                                     307
# nsents_raw_text                                                    5
# major_mesh                                     [calcified granuloma]
# n_major_mesh                                                       1
# auto_term                                      [calcified granuloma]
#
# id                                                               100  \
# comparison                                                     none.
# indication
# findings           both lungs are clear and expanded. heart and m...
# impression                                        no active disease.
# orig_mesh_terms                                             [normal]
# orig_auto_term                                              [normal]
# image_filename     [CXR100_IM-0002-1001.png, CXR100_IM-0002-2001....
# filename                                                     100.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  0
# impression_sents                                [no active disease.]
# findings_sents     [both lungs are clear and expanded., heart and...
# len_impression                                                    18
# len_findings                                                      64
# nsents_impression                                                  1
# nsents_findings                                                    2
# raw_text           both lungs are clear and expanded. heart and m...
# len_raw_text                                                      83
# nsents_raw_text                                                    3
# major_mesh                                                  [normal]
# n_major_mesh                                                       1
# auto_term                                                   [normal]
#
# id                                                              1000  \
# comparison                     xxxx pa and lateral chest radiographs
# indication                                 xxxx-year-old male, xxxx.
# findings           there is xxxx increased opacity within the rig...
# impression         1. increased opacity in the right upper lobe w...
# orig_mesh_terms    [opacity/lung/upper lobe/right, pulmonary atel...
# orig_auto_term     [atelectases, mass lesion, opacity, atelectasi...
# image_filename     [CXR1000_IM-0003-1001.png, CXR1000_IM-0003-200...
# filename                                                    1000.xml
# n_images                                                           3
# n_orig_mesh_terms                                                  3
# n_orig_auto_terms                                                  5
# impression_sents   [1. increased opacity in the right upper lobe ...
# findings_sents     [there is xxxx increased opacity within the ri...
# len_impression                                                   268
# len_findings                                                     357
# nsents_impression                                                  3
# nsents_findings                                                    5
# raw_text           there is xxxx increased opacity within the rig...
# len_raw_text                                                     626
# nsents_raw_text                                                    8
# major_mesh                          [pulmonary atelectasis, opacity]
# n_major_mesh                                                       2
# auto_term                   [atelectasis, mass lesion, opacity, rib]
#
# id                                                              1001  \
# comparison                                                      none
# indication         dyspnea, subjective fevers, arthritis, immigra...
# findings           interstitial markings are diffusely prominent ...
# impression         diffuse fibrosis. no visible focal acute disease.
# orig_mesh_terms    [markings/lung/bilateral/interstitial/diffuse/...
# orig_auto_term      [diffuse fibrosis, fibrosis, pulmonary fibrosis]
# image_filename     [CXR1001_IM-0004-1001.png, CXR1001_IM-0004-100...
# filename                                                    1001.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  2
# n_orig_auto_terms                                                  3
# impression_sents   [diffuse fibrosis., no visible focal acute dis...
# findings_sents     [interstitial markings are diffusely prominent...
# len_impression                                                    49
# len_findings                                                     113
# nsents_impression                                                  2
# nsents_findings                                                    3
# raw_text           interstitial markings are diffusely prominent ...
# len_raw_text                                                     163
# nsents_raw_text                                                    5
# major_mesh                                      [markings, fibrosis]
# n_major_mesh                                                       2
# auto_term           [diffuse fibrosis, fibrosis, pulmonary fibrosis]
#
# id                                                              1002  \
# comparison
# indication                                     history of chest pain
# findings
# impression         status post left mastectomy. heart size normal...
# orig_mesh_terms                                    [mastectomy/left]
# orig_auto_term                   [mastectomies, mastectomy, surgery]
# image_filename     [CXR1002_IM-0004-1001.png, CXR1002_IM-0004-200...
# filename                                                    1002.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  3
# impression_sents   [status post left mastectomy., heart size norm...
# findings_sents                                                    []
# len_impression                                                    64
# len_findings                                                       0
# nsents_impression                                                  3
# nsents_findings                                                    0
# raw_text           status post left mastectomy. heart size normal...
# len_raw_text                                                      64
# nsents_raw_text                                                    3
# major_mesh                                              [mastectomy]
# n_major_mesh                                                       1
# auto_term                        [mastectomies, mastectomy, surgery]
#
# id                                                              1003  \
# comparison
# indication                                         acute bronchitis.
# findings           heart size and pulmonary vascularity appear wi...
# impression         1. retrocardiac soft tissue density. the appea...
# orig_mesh_terms    [density/retrocardiac, calcinosis/blood vessel...
# orig_auto_term     [atelectases, calcified granuloma, hiatal hern...
# image_filename                            [CXR1003_IM-0005-2002.png]
# filename                                                    1003.xml
# n_images                                                           1
# n_orig_mesh_terms                                                  5
# n_orig_auto_terms                                                  8
# impression_sents   [1. retrocardiac soft tissue density., the app...
# findings_sents     [heart size and pulmonary vascularity appear w...
# len_impression                                                   148
# len_findings                                                     458
# nsents_impression                                                  4
# nsents_findings                                                    9
# raw_text           heart size and pulmonary vascularity appear wi...
# len_raw_text                                                     607
# nsents_raw_text                                                   13
# major_mesh         [opacity, density, calcinosis, calcified granu...
# n_major_mesh                                                       5
# auto_term          [atelectasis, calcified granuloma, hiatal hern...
#
# id                                                              1004  \
# comparison                        two views of the chest dated xxxx.
# indication         xxxx-year-old with xxxx for one month. history...
# findings           the heart, pulmonary xxxx and mediastinum are ...
# impression                         no acute cardiopulmonary disease.
# orig_mesh_terms    [aorta/tortuous, shoulder/bilateral/degenerati...
# orig_auto_term                                 [degenerative change]
# image_filename     [CXR1004_IM-0005-1001.png, CXR1004_IM-0005-200...
# filename                                                    1004.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  4
# n_orig_auto_terms                                                  1
# impression_sents                 [no acute cardiopulmonary disease.]
# findings_sents     [the heart, pulmonary xxxx and mediastinum are...
# len_impression                                                    33
# len_findings                                                     346
# nsents_impression                                                  1
# nsents_findings                                                    7
# raw_text           the heart, pulmonary xxxx and mediastinum are ...
# len_raw_text                                                     380
# nsents_raw_text                                                    8
# major_mesh           [aorta, spine, catheters, indwelling, shoulder]
# n_major_mesh                                                       4
# auto_term                                      [degenerative change]
#
# id                                                              1005  \
# comparison                                                     none.
# indication                                                 pruritic.
# findings           cardiac and mediastinal contours are within no...
# impression                                        no acute findings.
# orig_mesh_terms                                             [normal]
# orig_auto_term                                              [normal]
# image_filename     [CXR1005_IM-0006-1001.png, CXR1005_IM-0006-300...
# filename                                                    1005.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  0
# impression_sents                                [no acute findings.]
# findings_sents     [cardiac and mediastinal contours are within n...
# len_impression                                                    18
# len_findings                                                     107
# nsents_impression                                                  1
# nsents_findings                                                    3
# raw_text           cardiac and mediastinal contours are within no...
# len_raw_text                                                     126
# nsents_raw_text                                                    4
# major_mesh                                                  [normal]
# n_major_mesh                                                       1
# auto_term                                                   [normal]
#
# id                                                              1006  ...  \
# comparison                                                            ...
# indication                                 ,786.05 xxxx xxxx to xxxx  ...
# findings           the lungs appear clear. there are no focal air...  ...
# impression                         no acute cardiopulmonary disease.  ...
# orig_mesh_terms                                             [normal]  ...
# orig_auto_term                                              [normal]  ...
# image_filename     [CXR1006_IM-0007-1001.png, CXR1006_IM-0007-300...  ...
# filename                                                    1006.xml  ...
# n_images                                                           2  ...
# n_orig_mesh_terms                                                  1  ...
# n_orig_auto_terms                                                  0  ...
# impression_sents                 [no acute cardiopulmonary disease.]  ...
# findings_sents     [the lungs appear clear., there are no focal a...  ...
# len_impression                                                    33  ...
# len_findings                                                     213  ...
# nsents_impression                                                  1  ...
# nsents_findings                                                    6  ...
# raw_text           the lungs appear clear. there are no focal air...  ...
# len_raw_text                                                     247  ...
# nsents_raw_text                                                    7  ...
# major_mesh                                                  [normal]  ...
# n_major_mesh                                                       1  ...
# auto_term                                                   [normal]  ...
#
# id                                                               990  \
# comparison                                 two-view chest from xxxx.
# indication            xxxx-year-old male with altered mental status.
# findings           heart size within normal limits. no focal airs...
# impression                        no acute cardiopulmonary findings.
# orig_mesh_terms                                             [normal]
# orig_auto_term                                              [normal]
# image_filename     [CXR990_IM-2476-1001.png, CXR990_IM-2476-2001....
# filename                                                     990.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  0
# impression_sents                [no acute cardiopulmonary findings.]
# findings_sents     [heart size within normal limits., no focal ai...
# len_impression                                                    34
# len_findings                                                      96
# nsents_impression                                                  1
# nsents_findings                                                    3
# raw_text           heart size within normal limits. no focal airs...
# len_raw_text                                                     131
# nsents_raw_text                                                    4
# major_mesh                                                  [normal]
# n_major_mesh                                                       1
# auto_term                                                   [normal]
#
# id                                                               991  \
# comparison                               rib radiographs dated xxxx.
# indication         xxxx-year-old with pneumonia. shortness of bre...
# findings           the heart size is upper limits of normal. the ...
# impression         minimal perihilar opacity which could indicate...
# orig_mesh_terms                    [opacity/lung/hilum/streaky/mild]
# orig_auto_term                        [atypical pneumonias, opacity]
# image_filename     [CXR991_IM-2476-1001.png, CXR991_IM-2476-2001....
# filename                                                     991.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  2
# impression_sents   [minimal perihilar opacity which could indicat...
# findings_sents     [the heart size is upper limits of normal., th...
# len_impression                                                    69
# len_findings                                                     257
# nsents_impression                                                  1
# nsents_findings                                                    4
# raw_text           the heart size is upper limits of normal. the ...
# len_raw_text                                                     327
# nsents_raw_text                                                    5
# major_mesh                                                 [opacity]
# n_major_mesh                                                       1
# auto_term                             [atypical pneumonias, opacity]
#
# id                                                               992  \
# comparison                                                      none
# indication                                                  melanoma
# findings           there are bilateral pulmonary nodules whose ap...
# impression         1. bilateral pulmonary nodules suggesting pulm...
# orig_mesh_terms    [nodule/lung/bilateral/multiple, surgical inst...
# orig_auto_term     [metastatic disease, nodule, opacity, pulmonar...
# image_filename     [CXR992_IM-2477-0001-0001.png, CXR992_IM-2477-...
# filename                                                     992.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  3
# n_orig_auto_terms                                                  9
# impression_sents   [1. bilateral pulmonary nodules suggesting pul...
# findings_sents     [there are bilateral pulmonary nodules whose a...
# len_impression                                                   142
# len_findings                                                     769
# nsents_impression                                                  1
# nsents_findings                                                   10
# raw_text           there are bilateral pulmonary nodules whose ap...
# len_raw_text                                                     912
# nsents_raw_text                                                   11
# major_mesh         [surgical instruments, catheters, indwelling, ...
# n_major_mesh                                                       3
# auto_term          [catheter, catheterization, central venous, ju...
#
# id                                                               993  \
# comparison                                                     none.
# indication                                     possible tuberculosis
# findings           heart size normal. lungs are clear. xxxx are n...
# impression                 normal chest no evidence of tuberculosis.
# orig_mesh_terms                                             [normal]
# orig_auto_term                                              [normal]
# image_filename     [CXR993_IM-2478-1001.png, CXR993_IM-2478-1002....
# filename                                                     993.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  0
# impression_sents         [normal chest no evidence of tuberculosis.]
# findings_sents     [heart size normal., lungs are clear., xxxx ar...
# len_impression                                                    41
# len_findings                                                     129
# nsents_impression                                                  1
# nsents_findings                                                    4
# raw_text           heart size normal. lungs are clear. xxxx are n...
# len_raw_text                                                     171
# nsents_raw_text                                                    5
# major_mesh                                                  [normal]
# n_major_mesh                                                       1
# auto_term                                                   [normal]
#
# id                                                               994  \
# comparison                                                      xxxx
# indication                                         xxxx for one xxxx
# findings           the lungs are clear. the cardiomediastinal sil...
# impression                                          negative chest .
# orig_mesh_terms                                             [normal]
# orig_auto_term                                              [normal]
# image_filename     [CXR994_IM-2478-1001.png, CXR994_IM-2478-2001....
# filename                                                     994.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  0
# impression_sents                                  [negative chest .]
# findings_sents     [the lungs are clear., the cardiomediastinal s...
# len_impression                                                    16
# len_findings                                                     115
# nsents_impression                                                  1
# nsents_findings                                                    3
# raw_text           the lungs are clear. the cardiomediastinal sil...
# len_raw_text                                                     132
# nsents_raw_text                                                    4
# major_mesh                                                  [normal]
# n_major_mesh                                                       1
# auto_term                                                   [normal]
#
# id                                                               995  \
# comparison                                               xxxx, xxxx.
# indication                                      sp cabg sob no rales
# findings           sternotomy sutures and bypass grafts have been...
# impression               post operative chest with no acute disease.
# orig_mesh_terms                                    [sutures/sternum]
# orig_auto_term     [bypass grafts, sternotomy, coronary artery by...
# image_filename     [CXR995_IM-2478-1001.png, CXR995_IM-2478-1002....
# filename                                                     995.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  5
# impression_sents       [post operative chest with no acute disease.]
# findings_sents     [sternotomy sutures and bypass grafts have bee...
# len_impression                                                    43
# len_findings                                                     155
# nsents_impression                                                  1
# nsents_findings                                                    3
# raw_text           sternotomy sutures and bypass grafts have been...
# len_raw_text                                                     199
# nsents_raw_text                                                    4
# major_mesh                                                 [sutures]
# n_major_mesh                                                       1
# auto_term          [bypass grafts, coronary artery bypass, postop...
#
# id                                                               996  \
# comparison
# indication                                               chest pain.
# findings
# impression         heart size is normal and lungs are clear. no p...
# orig_mesh_terms                                             [normal]
# orig_auto_term                                              [normal]
# image_filename     [CXR996_IM-2479-1001.png, CXR996_IM-2479-2001....
# filename                                                     996.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  0
# impression_sents   [heart size is normal and lungs are clear., no...
# findings_sents                                                    []
# len_impression                                                    82
# len_findings                                                       0
# nsents_impression                                                  2
# nsents_findings                                                    0
# raw_text           heart size is normal and lungs are clear. no p...
# len_raw_text                                                      82
# nsents_raw_text                                                    2
# major_mesh                                                  [normal]
# n_major_mesh                                                       1
# auto_term                                                   [normal]
#
# id                                                               997  \
# comparison                    chest x-xxxx dated xxxx at xxxx hours.
# indication                  xxxx-year-old female, transplant workup.
# findings           calcified mediastinal xxxx. no focal areas of ...
# impression                   no acute cardiopulmonary abnormality. .
# orig_mesh_terms    [calcinosis/mediastinum, thoracic vertebrae/de...
# orig_auto_term                                 [degenerative change]
# image_filename     [CXR997_IM-2479-1001.png, CXR997_IM-2479-2001....
# filename                                                     997.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  2
# n_orig_auto_terms                                                  1
# impression_sents          [no acute cardiopulmonary abnormality., .]
# findings_sents     [calcified mediastinal xxxx., no focal areas o...
# len_impression                                                    39
# len_findings                                                     181
# nsents_impression                                                  2
# nsents_findings                                                    6
# raw_text           calcified mediastinal xxxx. no focal areas of ...
# len_raw_text                                                     221
# nsents_raw_text                                                    8
# major_mesh                          [thoracic vertebrae, calcinosis]
# n_major_mesh                                                       2
# auto_term                                      [degenerative change]
#
# id                                                               998  \
# comparison                                                     none.
# indication                             xxxx-year-old xxxx with pain.
# findings           cardiomediastinal silhouette demonstrates norm...
# impression                     no acute cardiopulmonary abnormality.
# orig_mesh_terms    [atherosclerosis/aorta, thoracic, aorta, thora...
# orig_auto_term     [atheroscleroses, degenerative disc diseases, ...
# image_filename     [CXR998_IM-2479-1001.png, CXR998_IM-2479-2001....
# filename                                                     998.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  3
# n_orig_auto_terms                                                  5
# impression_sents             [no acute cardiopulmonary abnormality.]
# findings_sents     [cardiomediastinal silhouette demonstrates nor...
# len_impression                                                    37
# len_findings                                                     281
# nsents_impression                                                  1
# nsents_findings                                                    4
# raw_text           cardiomediastinal silhouette demonstrates norm...
# len_raw_text                                                     319
# nsents_raw_text                                                    5
# major_mesh         [thoracic vertebrae, atherosclerosis, aorta, t...
# n_major_mesh                                                       3
# auto_term          [atherosclerosis, degenerative disc diseases, ...
#
# id                                                               999
# comparison                                                      none
# indication                                                chest pain
# findings           lungs are clear bilaterally. there is no focal...
# impression                     no acute cardiopulmonary abnormality.
# orig_mesh_terms                                             [normal]
# orig_auto_term                                              [normal]
# image_filename     [CXR999_IM-2480-1001.png, CXR999_IM-2480-2001....
# filename                                                     999.xml
# n_images                                                           3
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  0
# impression_sents             [no acute cardiopulmonary abnormality.]
# findings_sents     [lungs are clear bilaterally., there is no foc...
# len_impression                                                    37
# len_findings                                                     175
# nsents_impression                                                  1
# nsents_findings                                                    4
# raw_text           lungs are clear bilaterally. there is no focal...
# len_raw_text                                                     213
# nsents_raw_text                                                    5
# major_mesh                                                  [normal]
# n_major_mesh                                                       1
# auto_term                                                   [normal]
#
# [23 rows x 3851 columns]
# auto terms, done

# %%
# text cleaning
import re
from nltk import word_tokenize
def clean_text_v1(text, verbose=False):
    
    def subst_numbers(token):
        s = re.sub(r"\A\d+(,|\.)\d+", "_NUM_", token)  # _DEC_ for finer texts
        s = re.sub(r"\A\d+", "_NUM_", s)
        return s

    def subst_meas(text):
        # substitute measures
        e = r"(_NUM_|_DEC_)\s?(cm|mm|in|xxxx)|_NUM_ x _MEAS_|_DEC_ x _MEAS_|_MEAS_ x _MEAS_ x _MEAS|_MEAS_ x _MEAS_"
        t1 = text
        while True:
            t2 = re.sub(e, "_MEAS_", t1)
            if t1 == t2:
                break
            else:
                t1 = t2
        return t1

    text2 = text.replace(" ", " ")
    text2 = text2.replace("..", ".")


    symbols = ",;:?)(!"

    e = "|".join([re.escape(s) for s in symbols])
    text2 = re.sub(e, " ", text2)
    # text2 = " ".join( [t.strip() for t in text2.split(" ")])
    # numbered list items
    text2 = re.sub(r"\s\d+\. ", " ", text2)
    # dash
    text2 = re.sub(r"-", "_", text2)
    # percentages
    text2 = re.sub(r"\d+%\s", "_PERC_ ", text2)
    # XXXX XXXX -> XXXX_XXX
    text2 = re.sub(r"xxxx(\sxxxx)+", "xxxx", text2)
    # ordinals
    text2 = re.sub(r"1st|2nd|3rd|[0-9]+th ", "_N_TH_ ", text2)


    sentences = []
    for sent in sent_tokenize(text2):
        new_tokens = [subst_numbers(token) for token in word_tokenize(sent)[:-1]]  # [:-1] not using last dot
        # for token in word_tokenize(sent):
        #     w = subst_numbers(token)
        #     new_tokens.append(w)
    
        sent = " ".join(new_tokens)
        sent = subst_meas(sent)
        sentences.append(sent)

    text2 = ". ".join(sentences) + "."  # dots, and in particular the last ., were not removed by word_tokenize

    if verbose and text != text2:   # and "_MEAS_" in text2:
        print("* IN (it has been modified):")
        print(text)
        print("* OUT:")
        print(text2)
        print(10 * "*** ")

    return text2


df["text"] = df.raw_text.apply(lambda text: clean_text_v1(text, verbose=False))

display(df.head().T)

out_fn = join(meta_fld, "reports_raw2.pkl")
df.to_pickle(out_fn)
print(f"saved raw reports, step2, in: {out_fn}")
# Out:
# id                                                                 1  \
# comparison                                                     none.
# indication                                          positive tb test
# findings           the cardiac silhouette and mediastinum size ar...
# impression                                      normal chest x-xxxx.
# orig_mesh_terms                                             [normal]
# orig_auto_term                                              [normal]
# image_filename     [CXR1_1_IM-0001-3001.png, CXR1_1_IM-0001-4001....
# filename                                                       1.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  0
# impression_sents                              [normal chest x-xxxx.]
# findings_sents     [the cardiac silhouette and mediastinum size a...
# len_impression                                                    20
# len_findings                                                     210
# nsents_impression                                                  1
# nsents_findings                                                    5
# raw_text           the cardiac silhouette and mediastinum size ar...
# len_raw_text                                                     231
# nsents_raw_text                                                    6
# major_mesh                                                  [normal]
# n_major_mesh                                                       1
# auto_term                                                   [normal]
# text               the cardiac silhouette and mediastinum size ar...
#
# id                                                                10  \
# comparison                                   chest radiographs xxxx.
# indication                           xxxx-year-old male, chest pain.
# findings           the cardiomediastinal silhouette is within nor...
# impression                         no acute cardiopulmonary process.
# orig_mesh_terms          [calcified granuloma/lung/upper lobe/right]
# orig_auto_term                                 [calcified granuloma]
# image_filename      [CXR10_IM-0002-1001.png, CXR10_IM-0002-2001.png]
# filename                                                      10.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  1
# impression_sents                 [no acute cardiopulmonary process.]
# findings_sents     [the cardiomediastinal silhouette is within no...
# len_impression                                                    33
# len_findings                                                     273
# nsents_impression                                                  1
# nsents_findings                                                    4
# raw_text           the cardiomediastinal silhouette is within nor...
# len_raw_text                                                     307
# nsents_raw_text                                                    5
# major_mesh                                     [calcified granuloma]
# n_major_mesh                                                       1
# auto_term                                      [calcified granuloma]
# text               the cardiomediastinal silhouette is within nor...
#
# id                                                               100  \
# comparison                                                     none.
# indication
# findings           both lungs are clear and expanded. heart and m...
# impression                                        no active disease.
# orig_mesh_terms                                             [normal]
# orig_auto_term                                              [normal]
# image_filename     [CXR100_IM-0002-1001.png, CXR100_IM-0002-2001....
# filename                                                     100.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  0
# impression_sents                                [no active disease.]
# findings_sents     [both lungs are clear and expanded., heart and...
# len_impression                                                    18
# len_findings                                                      64
# nsents_impression                                                  1
# nsents_findings                                                    2
# raw_text           both lungs are clear and expanded. heart and m...
# len_raw_text                                                      83
# nsents_raw_text                                                    3
# major_mesh                                                  [normal]
# n_major_mesh                                                       1
# auto_term                                                   [normal]
# text               both lungs are clear and expanded. heart and m...
#
# id                                                              1000  \
# comparison                     xxxx pa and lateral chest radiographs
# indication                                 xxxx-year-old male, xxxx.
# findings           there is xxxx increased opacity within the rig...
# impression         1. increased opacity in the right upper lobe w...
# orig_mesh_terms    [opacity/lung/upper lobe/right, pulmonary atel...
# orig_auto_term     [atelectases, mass lesion, opacity, atelectasi...
# image_filename     [CXR1000_IM-0003-1001.png, CXR1000_IM-0003-200...
# filename                                                    1000.xml
# n_images                                                           3
# n_orig_mesh_terms                                                  3
# n_orig_auto_terms                                                  5
# impression_sents   [1. increased opacity in the right upper lobe ...
# findings_sents     [there is xxxx increased opacity within the ri...
# len_impression                                                   268
# len_findings                                                     357
# nsents_impression                                                  3
# nsents_findings                                                    5
# raw_text           there is xxxx increased opacity within the rig...
# len_raw_text                                                     626
# nsents_raw_text                                                    8
# major_mesh                          [pulmonary atelectasis, opacity]
# n_major_mesh                                                       2
# auto_term                   [atelectasis, mass lesion, opacity, rib]
# text               there is xxxx increased opacity within the rig...
#
# id                                                              1001
# comparison                                                      none
# indication         dyspnea, subjective fevers, arthritis, immigra...
# findings           interstitial markings are diffusely prominent ...
# impression         diffuse fibrosis. no visible focal acute disease.
# orig_mesh_terms    [markings/lung/bilateral/interstitial/diffuse/...
# orig_auto_term      [diffuse fibrosis, fibrosis, pulmonary fibrosis]
# image_filename     [CXR1001_IM-0004-1001.png, CXR1001_IM-0004-100...
# filename                                                    1001.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  2
# n_orig_auto_terms                                                  3
# impression_sents   [diffuse fibrosis., no visible focal acute dis...
# findings_sents     [interstitial markings are diffusely prominent...
# len_impression                                                    49
# len_findings                                                     113
# nsents_impression                                                  2
# nsents_findings                                                    3
# raw_text           interstitial markings are diffusely prominent ...
# len_raw_text                                                     163
# nsents_raw_text                                                    5
# major_mesh                                      [markings, fibrosis]
# n_major_mesh                                                       2
# auto_term           [diffuse fibrosis, fibrosis, pulmonary fibrosis]
# text               interstitial markings are diffusely prominent ...
# saved raw reports, step2, in: /mnt/datasets/uc5/meta/iuchest_light/reports_raw2.pkl

# %% [markdown]
# # <font color="red">STEP</font>
#
# <font color="yellow">reports_raw2.pkl available here</font>
#
# <font color="green">use reports_raw2.pkl for building the vocabulary with AUTOMATIC TERMS</font>
#
# reports_raw.pkl processed in the previous cells is saved in `reports_raw2.pkl`
#
# We now produce a binary encoding of the labels.
#
# We are still using all the data available in the dataset:
#
# 1. MeSH terms: two terms are removed, `["technical quality of image unsatisfactory", "no indexing"]`.
# After removal of the tags, the reports and the images left with zero tags are removed
#     - 98 reports, 186 images are removed

# %%
# BINARY ENCODING OF THE LABELS
# M E S H 

#     #          #####  #     #
##   ##  ###### #     # #     #
# # # #  #      #       #     #
#  #  #  #####   #####  #######
#     #  #            # #     #
#     #  #      #     # #     #
#     #  ######  #####  #     #


from bs4 import BeautifulSoup
from collections import defaultdict
import numpy as np
import os
import numpy as np
from numpy import count_nonzero as nnz
import pandas as pd
import pickle
from posixpath import join
from tqdm.notebook import tqdm

import iuchest.reports as iureports
from utils.vocabulary import Vocabulary

# %load_ext autoreload
# %autoreload 2
base_path = "/mnt/datasets/uc5/std-dataset"  # subfolders image, text
reports_fld = join(base_path, "text")
images_fld = join(base_path, "image")


# 1: ALL AVAILABLE DATA
meta_fld =  "/mnt/datasets/uc5/meta/iuchest_light"
in_fn = join(meta_fld, "reports_raw2.pkl")
df = pd.read_pickle(in_fn)
print(f"read {in_fn}, shape: {df.shape}")
# display(df.T)

# encode data as binary matrix with 1-hot encoding of labels - still using all available data
# unique combinations of mesh terms
mesh_terms_s = df.orig_mesh_terms.str.join("/").tolist()
df["mesh_term_s"] = mesh_terms_s
mesh_terms_s = set(mesh_terms_s)
print("unique combos of mesh terms:", len(mesh_terms_s))

# unique mesh terms
umesh = set()
def add_terms(l: list):
    for t in l:
        umesh.add(t)
    #<

df.major_mesh.apply(lambda l: add_terms(l))
print("unique mesh terms:", len(umesh))

# encode image based binary matrix
umesh = ["normal"] + sorted([l for l in umesh if l != "normal"])
# for i, t in enumerate(umesh):
#     print(f"{i}) {t}")

# step build another file indexed by image filenames, this file will be used in training
matrix = []  # rows correspond to images
img_index = []  # used with matrix
rep_index = []
paths = []
rep_matrix = []  # rows correspond to reports

df["labels"] = df.major_mesh
df2 = df.reset_index()
for t in df2.itertuples():
    enc = []
    for term in umesh:
        enc.append(term in t.labels)
    rep_matrix.append(enc)
    rep_index.append(t.id)
    for fn in t.image_filename:
        img_index.append(fn)
        paths.append(join(images_fld, fn))
        matrix.append(enc)

rep_ds = pd.DataFrame(data=np.array(rep_matrix).astype(int), columns=umesh)
rep_ds["id"] = rep_index
rep_ds.set_index("id", inplace=True)
print(f"dataframe, index is report id: {rep_ds.shape}")
# display(rep_ds.head())

img_ds = pd.DataFrame(data=np.array(matrix).astype(int), columns=umesh)
img_ds["filename"] = img_index
img_ds.set_index("filename", inplace=True)
# display(img_ds.head())

#
# r e m o v e    s o m e     l a b e l s 
#
# some reports with "No Indxing" are actually considered to be of class "NORMAL" in the AUTOMATIC TERMS field
def remove_tags(tags, dataf):
    print("removing columns:", tags)
    nrows1 = dataf.shape[0]
    dataf = dataf.drop(columns=tags)
    # remove images left with 0 labels
    counts = dataf.sum(axis=1)
    # remove rows that are now without labels
    iii = counts == 0
    print(f"removing {nnz(iii)} rows, shape is {dataf.shape}")
    dataf = dataf.drop(index=counts[iii].index)
    nrows2= dataf.shape[0]
    assert nrows1 == nrows2 + nnz(iii)
    print(f"removed {nnz(iii)} rows: ok, shape is {dataf.shape}")
    return dataf

tags = ["technical quality of image unsatisfactory", "no indexing"]
img_ds2 = remove_tags(tags, img_ds)
rep_ds = remove_tags(tags, rep_ds)
print(f"after tag removal, img_ds, shape is {img_ds2.shape}")
print(f"after tag removal, shape is {rep_ds.shape}")

removed_reports = [id for id in df.index if id not in rep_ds.index]

# text associated to the reports with tags ["technical quality of image unsatisfactory", "no indexing"]
# Many of them seem normal
# for t in df.loc[removed_reports].raw_text:
#     print(t)
# automatic tags associated to removed reports
# print(df.loc[removed_reports, "auto_term"].value_counts())

print(f"id of removed reports {len(removed_reports)}:", removed_reports)
df3 = df.drop(labels=removed_reports)
# reports_raw3 used for pipeline using MeSH terms
df3.to_pickle(join(meta_fld, "reports_raw3.pkl"))
print("new dataframe, rows wrt previous ds2:", df3.shape[0] - df2.shape[0])
print(f"saved: {join(meta_fld, 'reports_raw3.pkl')}")

n_removed_images = img_ds.shape[0] - img_ds2.shape[0]  # [id for id in img_ds.index if id not in img2_ds.index]
print("|removed images|:", n_removed_images)
img_ds = img_ds2

def save_pkl_csv(dataframe, fn):
    out_fn = join(meta_fld, fn + ".pkl")
    img_ds.to_pickle(out_fn)
    print(f"saved {out_fn}")
    out_fn = join(meta_fld, fn + ".csv")
    img_ds.to_csv(out_fn, sep="\t")
    print(f"saved` {out_fn}")

save_pkl_csv(img_ds, "img_dataset")
save_pkl_csv(rep_ds, "rep_dataset")
print("cell MeSH terms, completed")

# %%
# BINARY ENCODING OF THE LABELS
# A U T O T E R M

   ##    #    #   #####   ####
  #  #   #    #     #    #    #
 #    #  #    #     #    #    #
 ######  #    #     #    #    #
 #    #  #    #     #    #    #
 #    #   ####      #     ####



from bs4 import BeautifulSoup
from collections import defaultdict
import numpy as np
import os
import numpy as np
from numpy import count_nonzero as nnz
import pandas as pd
import pickle
from posixpath import join
from tqdm.notebook import tqdm

from lightning.vocabulary_light import Vocabulary

# %load_ext autoreload
# %autoreload 2
base_path = "/mnt/datasets/uc5/std-dataset"  # subfolders image, text
reports_fld = join(base_path, "text")
images_fld = join(base_path, "image")


# 1: ALL AVAILABLE DATA
meta_fld =  "/mnt/datasets/uc5/meta/iuchest_light"
in_fn = join(meta_fld, "reports_raw2.pkl")
df = pd.read_pickle(in_fn)
print(f"read {in_fn}, shape: {df.shape}")
# display(df.T)

# encode data as binary matrix with 1-hot encoding of labels - still using all available data
# unique combinations of mesh terms
auto_term_s = df.auto_term.str.join("/").tolist()
df["auto_term_s"] = auto_term_s
auto_term_s = set(auto_term_s)
print("unique combos of auto terms:", len(auto_term_s))

# unique mesh terms
uterms = set()
def add_terms(l: list):
    for t in l:
        uterms.add(t)
    #<

# A U T O T E R M


df.auto_term.apply(lambda l: add_terms(l))
print("unique auto terms:", len(uterms))

# encode image based binary matrix
uterms = ["normal"] + sorted([l for l in uterms if l != "normal"])
print("number of unique auto terms:", len(uterms))
for i, t in enumerate(uterms):
    print(f"{i}) {t}")

# step build another file indexed by image filenames, this file will be used in training
matrix = []  # rows correspond to images
img_index = []  # used with matrix
rep_index = []
paths = []
rep_matrix = []  # rows correspond to reports

df["labels"] = df.auto_term
df2 = df.reset_index()
for t in df2.itertuples():
    enc = []
    for term in uterms:
        enc.append(term in t.labels)
    rep_matrix.append(enc)
    rep_index.append(t.id)
    for fn in t.image_filename:
        img_index.append(fn)
        paths.append(join(images_fld, fn))
        matrix.append(enc)

rep_ds = pd.DataFrame(data=np.array(rep_matrix).astype(int), columns=uterms)
rep_ds["id"] = rep_index
rep_ds.set_index("id", inplace=True)
print(f"dataframe, index is report id: {rep_ds.shape}")
display(rep_ds.head())

img_ds = pd.DataFrame(data=np.array(matrix).astype(int), columns=uterms)
img_ds["filename"] = img_index
img_ds.set_index("filename", inplace=True)
display(img_ds.head())

# remove some labels
def remove_tags(tags, dataf):
    print("removing columns:", tags)
    nrows1 = dataf.shape[0]
    dataf = dataf.drop(columns=tags)
    # remove images left with 0 labels
    counts = dataf.sum(axis=1)
    # remove rows that are now without labels
    iii = counts == 0
    print(f"removing {nnz(iii)} rows, shape is {dataf.shape}")
    dataf = dataf.drop(index=counts[iii].index)
    nrows2= dataf.shape[0]
    assert nrows1 == nrows2 + nnz(iii)
    print(f"removed {nnz(iii)} rows: ok, shape is {dataf.shape}")
    return dataf

#tags = ["technical quality of image unsatisfactory", "no indexing"]
#img_ds = remove_tags(tags, img_ds)
#rep_ds = remove_tags(tags, rep_ds)

#print(f"img_ds, shape is {img_ds.shape}")
#print(f"rep_ds, shape is {rep_ds.shape}")

#removed_reports = [id for id in df.index if id not in rep_ds.index]
#print(f"id of removed reports {len(removed_reports)}:", removed_reports)
#df3 = df.drop(labels=removed_reports)
#print("new dataframe, rows wrt previous ds2:", df3.shape[0] - df2.shape[0])
#df3.to_pickle(join(meta_fld, "reports_raw3.pkl"))
#print(f"saved: {join(meta_fld, 'reports_raw3.pkl')}")


def save_pkl_csv(dataframe, fn):
    out_fn = join(meta_fld, fn + ".pkl")
    img_ds.to_pickle(out_fn)
    print(f"saved {out_fn}")
    out_fn = join(meta_fld, fn + ".csv")
    img_ds.to_csv(out_fn, sep="\t")
    print(f"saved` {out_fn}")

save_pkl_csv(img_ds, "img_dataset_auto_light")
save_pkl_csv(rep_ds, "rep_dataset_auto_light")

print("cell AUTO terms completed")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# read /mnt/datasets/uc5/meta/iuchest_light/reports_raw2.pkl, shape: (3851, 24)
# unique combos of auto terms: 1270
# unique auto terms: 529
# number of unique auto terms: 529
# 0) normal
# 1) abdomen
# 2) abdominal surgery
# 3) absence of right pulmonary artery
# 4) absorptiometry, photon
# 5) acromioclavicular separation
# 6) acute pneumonia
# 7) adenopathy
# 8) adipose tissue
# 9) air
# 10) air trapping
# 11) alveolar edema
# 12) amputation
# 13) anchors
# 14) aneurysm
# 15) aneurysm, dissecting
# 16) anterior mediastinal masses
# 17) anterolisthesis
# 18) aorta
# 19) aorta tortuous
# 20) aorta, abdominal
# 21) aorta, thoracic
# 22) aortic aneurysm
# 23) aortic aneurysm, thoracic
# 24) aortic atherosclerosis
# 25) aortic calcifications
# 26) aortic disease
# 27) aortic dissection
# 28) aortic ectasia
# 29) aortic valve
# 30) aortic valve replacement
# 31) apical granuloma
# 32) artefact
# 33) arterial abnormality
# 34) arthritic changes
# 35) arthritis
# 36) arthroplasties
# 37) arthroplasty, replacement
# 38) arthroplasty, replacement, knee
# 39) asbestos exposure
# 40) asbestosis
# 41) ascending aorta
# 42) ascending aortic aneurysm
# 43) aspergilloma
# 44) aspiration
# 45) atelectasis
# 46) atherosclerosis
# 47) atherosclerotic vascular disease
# 48) atypical pneumonias
# 49) axilla
# 50) azygos lobe
# 51) azygos vein
# 52) benign cysts
# 53) bilateral breast implants
# 54) bilateral hilar adenopathy
# 55) bilateral pleural effusion
# 56) biliary stents
# 57) bochdalek hernia
# 58) bone
# 59) bone anchor
# 60) bone demineralization
# 61) bone density
# 62) bone diseases, metabolic
# 63) bone island
# 64) brain tumor
# 65) breast carcinoma
# 66) breast implants
# 67) bronchi
# 68) bronchial calcification
# 69) bronchial fistula
# 70) bronchial wall thickening
# 71) bronchiectasis
# 72) bronchiolitis
# 73) bronchiolitis, viral
# 74) bronchitis
# 75) bronchopleural fistula
# 76) bulla
# 77) bullous emphysema
# 78) bypass grafting
# 79) bypass grafts
# 80) cabg
# 81) cachexia
# 82) calcific tendinitis
# 83) calcifications of the aorta
# 84) calcified granuloma
# 85) calcified lymph nodes
# 86) calcinosis
# 87) callus
# 88) carcinoma
# 89) cardiac failure
# 90) cardiac monitor
# 91) cardiomegaly
# 92) cardiomyopathy, dilated
# 93) cardiopulmonary bypass
# 94) cardiothoracic ratio
# 95) cardiovascular diseases
# 96) catheter
# 97) catheterization
# 98) catheterization, central venous
# 99) catheterization, peripheral
# 100) catheters, indwelling
# 101) cavitation
# 102) central venous catheter
# 103) centrilobular emphysema
# 104) cervical arthritis
# 105) cervical fusion
# 106) cervical spinal fusion
# 107) cervical spine surgeries
# 108) cervical vertebrae
# 109) chest infection
# 110) chest surgery
# 111) chest tubes
# 112) chest wall
# 113) cholecystectomies
# 114) cholecystectomy
# 115) cholelithiasis
# 116) chronic atelectasis
# 117) chronic disease
# 118) chronic edema
# 119) chronic fibrosis
# 120) chronic granulomatous disease
# 121) chronic interstitial lung disease
# 122) chronic liver disease
# 123) chronic lung disease
# 124) chronic obstructive lung disease
# 125) chronic obstructive pulmonary disease
# 126) chronic pancreatitis
# 127) chronic pulmonary embolism
# 128) cicatrix
# 129) clavicle
# 130) clavicular fracture
# 131) clip
# 132) closure
# 133) collapse
# 134) colonic interposition
# 135) colonic perforation
# 136) congestion
# 137) congestive cardiac failure
# 138) congestive heart failure
# 139) contusion
# 140) copd
# 141) coronary artery bypass
# 142) coronary artery bypass graft
# 143) coronary bypass
# 144) coronary vessels
# 145) cyst
# 146) cystic fibrosis
# 147) defibrillator
# 148) deformity
# 149) degeneration
# 150) degenerative arthritis
# 151) degenerative change
# 152) degenerative disc diseases
# 153) degenerative disease
# 154) degenerative joint disease
# 155) demineralization
# 156) descending aorta
# 157) dextrocardia
# 158) dialysis
# 159) diaphragm
# 160) diaphragm eventration
# 161) diffuse fibrosis
# 162) diffuse idiopathic skeletal hyperostosis
# 163) dilatation, pathologic
# 164) dilated cardiomyopathies
# 165) dilation
# 166) discoid atelectasis
# 167) dish
# 168) dislocation
# 169) displaced fractures
# 170) displacement
# 171) dissection
# 172) distention
# 173) drainage
# 174) dyspnea
# 175) ectasia
# 176) edema
# 177) effusion
# 178) electronic cardiac device
# 179) elevated diaphragm
# 180) embolisation
# 181) emphysema
# 182) empyema
# 183) enchondroma
# 184) enlarged heart
# 185) enteral nutrition
# 186) esophagectomies
# 187) esophagectomy
# 188) esophagogastric junction
# 189) esophagus
# 190) eventration
# 191) exostoses
# 192) exudates and transudates
# 193) fat pads
# 194) femoral neck fractures
# 195) femur
# 196) fibrosis
# 197) fixation
# 198) focal atelectasis
# 199) follow-up studies
# 200) foreign bodies
# 201) foreign body
# 202) fourth rib fracture
# 203) fracture
# 204) fracture healing
# 205) fracture, pathologic
# 206) fracture-dislocation
# 207) fractures, bone
# 208) fractures, pathologic
# 209) funnel chest
# 210) fusion
# 211) fusion procedure
# 212) gallbladder
# 213) gallstones
# 214) gases
# 215) generalized osteopenia
# 216) goiter
# 217) granuloma
# 218) granulomatous disease
# 219) granulomatous disease, chronic
# 220) granulomatous infection
# 221) gunshot wounds
# 222) heart atria
# 223) heart failure
# 224) heart valve prosthesis
# 225) heart valve prosthesis implantation
# 226) heart ventricles
# 227) hematoma
# 228) hemopneumothorax
# 229) hemorrhages
# 230) hemothorax
# 231) hepatic cyst
# 232) hernia
# 233) hernia, diaphragmatic
# 234) hernia, hiatal
# 235) hernia, hiatus
# 236) hiatal hernia
# 237) hilar adenopathy
# 238) hilar calcification
# 239) hilar lymphadenopathy
# 240) hip fractures
# 241) histoplasmoma
# 242) histoplasmosis
# 243) humeral fracture
# 244) humeral head
# 245) humerus
# 246) hydropneumothorax
# 247) hyperexpansion
# 248) hyperexpansion of lung
# 249) hyperinflation
# 250) hyperinflation lungs
# 251) hyperlucent lung
# 252) hyperostosis, diffuse idiopathic skeletal
# 253) hypertension
# 254) hypertension, pulmonary
# 255) hypertrophy
# 256) hypertrophy, left ventricular
# 257) hypoventilation
# 258) in-dwelling catheter
# 259) infection
# 260) infiltrates
# 261) inflammation
# 262) internal fixation
# 263) interstitial disease
# 264) interstitial fibrosis
# 265) interstitial lung disease
# 266) interstitial pneumonitides
# 267) interstitial pulmonary edema
# 268) intervertebral disc
# 269) intervertebral disc degeneration
# 270) intervertebral disc displacement
# 271) intestinal obstruction
# 272) intestinal perforation
# 273) intestine, large
# 274) intestine, small
# 275) intubation, gastrointestinal
# 276) intubation, intratracheal
# 277) joint prosthesis
# 278) jugular veins
# 279) kidney
# 280) knee joint
# 281) knee prosthesis
# 282) kyphosis
# 283) laparoscopic surgery
# 284) large hiatal hernia
# 285) left atrial enlargement
# 286) left atrium
# 287) left lower lobe pneumonia
# 288) left upper lobe pneumonia
# 289) left ventricle
# 290) left ventricular enlargement
# 291) left-sided pleural effusion
# 292) lipoma
# 293) liver diseases
# 294) lobectomy
# 295) loculated effusion
# 296) lower lobe pneumonia
# 297) lumbar spine fusion
# 298) lumbar vertebrae
# 299) lumbosacral region
# 300) lumpectomy
# 301) lung cancer
# 302) lung carcinoma
# 303) lung consolidation
# 304) lung disease
# 305) lung diseases, interstitial
# 306) lung diseases, obstructive
# 307) lung granuloma
# 308) lung hyperinflation
# 309) lung neoplasms
# 310) lung surgeries
# 311) lung volume reduction
# 312) lungs, hyperlucent
# 313) lymph
# 314) lymph node
# 315) lymphadenopathy
# 316) lymphatic diseases
# 317) lymphoma
# 318) malignancy
# 319) mammaplasty
# 320) mass lesion
# 321) mastectomies
# 322) mastectomy
# 323) mediastinal diseases
# 324) mediastinal haematoma
# 325) mediastinal lymphadenopathy
# 326) metastases
# 327) metastatic disease
# 328) mid sternotomy
# 329) middle lobe syndrome
# 330) mitral annular calcification
# 331) mitral valve
# 332) mitral valve replacement
# 333) morgagni hernia
# 334) mucus
# 335) multilobar pneumonia
# 336) multiple fractures
# 337) multiple myeloma
# 338) multiple pulmonary nodules
# 339) muscle spasm
# 340) mycoplasma pneumonia
# 341) myocardial revascularization
# 342) nasogastric tube
# 343) neck
# 344) neoplasm
# 345) neoplastic processes
# 346) nephrostomy
# 347) nephrostomy, percutaneous
# 348) nipple
# 349) nodule
# 350) non-displaced fracture
# 351) obese
# 352) obesity, morbid
# 353) obliteration
# 354) obstruction
# 355) obstructive atelectasis
# 356) obstructive lung disease
# 357) obstructive pulmonary diseases
# 358) old injury
# 359) opacity
# 360) opportunistic infection
# 361) osteoarthritis
# 362) osteoarthritis, knee
# 363) osteopenia
# 364) osteophyte
# 365) osteoporosis
# 366) overlapping structures
# 367) pacemaker, artificial
# 368) pain
# 369) pancreatitis
# 370) pancreatitis, chronic
# 371) paralysis
# 372) paratracheal mass
# 373) patchy atelectasis
# 374) pathologic fractures
# 375) pectus carinatum
# 376) pectus excavatum
# 377) peribronchial pneumonia
# 378) pericardial effusion
# 379) pericardial fluid
# 380) peripheral vascular disease
# 381) picc
# 382) picc line
# 383) piercing
# 384) plate-like atelectasis
# 385) pleura
# 386) pleural calcification
# 387) pleural disease
# 388) pleural effusion
# 389) pleural fluid
# 390) pleural plaque
# 391) pleural thickening
# 392) pleuritis
# 393) pneumatocele
# 394) pneumonectomy
# 395) pneumonia
# 396) pneumonia right lower lobe
# 397) pneumonia, mycoplasma
# 398) pneumonia, viral
# 399) pneumonitis
# 400) pneumonitis, interstitial
# 401) pneumoperitoneum
# 402) pneumothorax
# 403) post traumatic deformity
# 404) postobstructive pneumonia
# 405) postoperative period
# 406) prostheses
# 407) prostheses and implants
# 408) prosthetic right shoulder
# 409) pulmonary arterial hypertension
# 410) pulmonary arteries
# 411) pulmonary artery
# 412) pulmonary artery hypertension
# 413) pulmonary aspergillosis
# 414) pulmonary atelectasis
# 415) pulmonary disease
# 416) pulmonary disease, chronic obstructive
# 417) pulmonary disease, chronic obstructive, severe early-onset
# 418) pulmonary disease, obstructive
# 419) pulmonary edema
# 420) pulmonary effusion
# 421) pulmonary embolism
# 422) pulmonary emphysema
# 423) pulmonary fibrosis
# 424) pulmonary granuloma
# 425) pulmonary hypertension
# 426) pulmonary metastasis
# 427) pulmonary process
# 428) pulmonary sarcoidosis
# 429) pulmonary valve
# 430) pyriform sinus
# 431) reactive airway disease
# 432) recurrent pneumonia
# 433) renal dialysis
# 434) renal osteodystrophies
# 435) resections
# 436) respiratory tract diseases
# 437) respiratory tract infections
# 438) retraction
# 439) retropulsion
# 440) rib
# 441) rib fracture
# 442) right atrial enlargement
# 443) right atrium
# 444) right lower lobe pneumonia
# 445) right upper lobe pneumonia
# 446) right ventricle
# 447) right-sided pleural effusion
# 448) rotated fracture
# 449) rotation
# 450) sacrum
# 451) sarcoid
# 452) sarcoidosis
# 453) sarcoidosis, pulmonary
# 454) scaphoid abdomen
# 455) scar
# 456) scarring
# 457) scleroses
# 458) sclerotic
# 459) scoliosis
# 460) shoulder
# 461) shoulder dislocation
# 462) skin fold
# 463) small airway disease
# 464) small bowel obstruction
# 465) solitary pulmonary nodule
# 466) spinal fractures
# 467) spinal fusion
# 468) spinal injuries
# 469) spinal osteophytosis
# 470) spine
# 471) spine curvature
# 472) spine injury
# 473) splenic calcification
# 474) spondylarthritis
# 475) spondylosis
# 476) stabilization
# 477) stable fracture
# 478) stent
# 479) sternotomy
# 480) sternum
# 481) stomach
# 482) subchondral cyst
# 483) subclavian vein
# 484) subcutaneous emphysema
# 485) superimposed infection
# 486) surgery
# 487) surgical clip
# 488) surgical instruments
# 489) surgical resection
# 490) sutures
# 491) tendinopathy
# 492) thoracentesis
# 493) thoracic aorta
# 494) thoracic spondylosis
# 495) thoracic vertebrae
# 496) thoracic wall
# 497) thoracolumbar scoliosis
# 498) thoracotomies
# 499) thoracotomy
# 500) thorax
# 501) thyroid cancer
# 502) thyroid gland
# 503) thyroid mass
# 504) tips
# 505) torso
# 506) tortuous aorta
# 507) trachea
# 508) tracheostomies
# 509) tracheostomy
# 510) traction bronchiectasis
# 511) tuberculosis
# 512) tuberculosis, pulmonary
# 513) tumor
# 514) tumor progression
# 515) vascular aneurysm
# 516) vascular calcification
# 517) vascular diseases
# 518) vena cava, superior
# 519) venous congestion
# 520) venous engorgement
# 521) venous hypertension
# 522) ventricular hypertrophy
# 523) vertebral fracture
# 524) vertebroplasty
# 525) viral bronchiolitis
# 526) viral pneumonias
# 527) volume overload
# 528) wounds, gunshot
# dataframe, index is report id: (3851, 529)
#       normal  abdomen  abdominal surgery  absence of right pulmonary artery  \
# id
# 1          1        0                  0                                  0
# 10         0        0                  0                                  0
# 100        1        0                  0                                  0
# 1000       0        0                  0                                  0
# 1001       0        0                  0                                  0
#
#       absorptiometry, photon  acromioclavicular separation  acute pneumonia  \
# id
# 1                          0                             0                0
# 10                         0                             0                0
# 100                        0                             0                0
# 1000                       0                             0                0
# 1001                       0                             0                0
#
#       adenopathy  adipose tissue  air  ...  venous congestion  \
# id                                     ...
# 1              0               0    0  ...                  0
# 10             0               0    0  ...                  0
# 100            0               0    0  ...                  0
# 1000           0               0    0  ...                  0
# 1001           0               0    0  ...                  0
#
#       venous engorgement  venous hypertension  ventricular hypertrophy  \
# id
# 1                      0                    0                        0
# 10                     0                    0                        0
# 100                    0                    0                        0
# 1000                   0                    0                        0
# 1001                   0                    0                        0
#
#       vertebral fracture  vertebroplasty  viral bronchiolitis  \
# id
# 1                      0               0                    0
# 10                     0               0                    0
# 100                    0               0                    0
# 1000                   0               0                    0
# 1001                   0               0                    0
#
#       viral pneumonias  volume overload  wounds, gunshot
# id
# 1                    0                0                0
# 10                   0                0                0
# 100                  0                0                0
# 1000                 0                0                0
# 1001                 0                0                0
#
# [5 rows x 529 columns]
#                          normal  abdomen  abdominal surgery  \
# filename
# CXR1_1_IM-0001-3001.png       1        0                  0
# CXR1_1_IM-0001-4001.png       1        0                  0
# CXR10_IM-0002-1001.png        0        0                  0
# CXR10_IM-0002-2001.png        0        0                  0
# CXR100_IM-0002-1001.png       1        0                  0
#
#                          absence of right pulmonary artery  \
# filename
# CXR1_1_IM-0001-3001.png                                  0
# CXR1_1_IM-0001-4001.png                                  0
# CXR10_IM-0002-1001.png                                   0
# CXR10_IM-0002-2001.png                                   0
# CXR100_IM-0002-1001.png                                  0
#
#                          absorptiometry, photon  acromioclavicular separation  \
# filename
# CXR1_1_IM-0001-3001.png                       0                             0
# CXR1_1_IM-0001-4001.png                       0                             0
# CXR10_IM-0002-1001.png                        0                             0
# CXR10_IM-0002-2001.png                        0                             0
# CXR100_IM-0002-1001.png                       0                             0
#
#                          acute pneumonia  adenopathy  adipose tissue  air  \
# filename
# CXR1_1_IM-0001-3001.png                0           0               0    0
# CXR1_1_IM-0001-4001.png                0           0               0    0
# CXR10_IM-0002-1001.png                 0           0               0    0
# CXR10_IM-0002-2001.png                 0           0               0    0
# CXR100_IM-0002-1001.png                0           0               0    0
#
#                          ...  venous congestion  venous engorgement  \
# filename                 ...
# CXR1_1_IM-0001-3001.png  ...                  0                   0
# CXR1_1_IM-0001-4001.png  ...                  0                   0
# CXR10_IM-0002-1001.png   ...                  0                   0
# CXR10_IM-0002-2001.png   ...                  0                   0
# CXR100_IM-0002-1001.png  ...                  0                   0
#
#                          venous hypertension  ventricular hypertrophy  \
# filename
# CXR1_1_IM-0001-3001.png                    0                        0
# CXR1_1_IM-0001-4001.png                    0                        0
# CXR10_IM-0002-1001.png                     0                        0
# CXR10_IM-0002-2001.png                     0                        0
# CXR100_IM-0002-1001.png                    0                        0
#
#                          vertebral fracture  vertebroplasty  \
# filename
# CXR1_1_IM-0001-3001.png                   0               0
# CXR1_1_IM-0001-4001.png                   0               0
# CXR10_IM-0002-1001.png                    0               0
# CXR10_IM-0002-2001.png                    0               0
# CXR100_IM-0002-1001.png                   0               0
#
#                          viral bronchiolitis  viral pneumonias  \
# filename
# CXR1_1_IM-0001-3001.png                    0                 0
# CXR1_1_IM-0001-4001.png                    0                 0
# CXR10_IM-0002-1001.png                     0                 0
# CXR10_IM-0002-2001.png                     0                 0
# CXR100_IM-0002-1001.png                    0                 0
#
#                          volume overload  wounds, gunshot
# filename
# CXR1_1_IM-0001-3001.png                0                0
# CXR1_1_IM-0001-4001.png                0                0
# CXR10_IM-0002-1001.png                 0                0
# CXR10_IM-0002-2001.png                 0                0
# CXR100_IM-0002-1001.png                0                0
#
# [5 rows x 529 columns]
# saved /mnt/datasets/uc5/meta/iuchest_light/img_dataset_auto_light.pkl
# saved` /mnt/datasets/uc5/meta/iuchest_light/img_dataset_auto_light.csv
# saved /mnt/datasets/uc5/meta/iuchest_light/rep_dataset_auto_light.pkl
# saved` /mnt/datasets/uc5/meta/iuchest_light/rep_dataset_auto_light.csv
# cell AUTO terms completed

# %%
# build vocabulary
# 1) if using auto terms, then consider all text in raw_reports2
# 2) if using mesh terms, then consider all text in raw_reports3. 
#       Raw_reports3 does not contain images with the tags "no indexing" and "technical quality of image unsatisfactory"


 #    #   ####    ####     ##    #####
 #    #  #    #  #    #   #  #   #    #
 #    #  #    #  #       #    #  #####
 #    #  #    #  #       ######  #    #
  #  #   #    #  #    #  #    #  #    #
   ##     ####    ####   #    #  #####

# 1) if using auto terms, then consider all text in raw_reports2
# 2) if using mesh terms, then consider all text in raw_reports3. 



# !   I M P O R T A N T
vocab_for_terms = "auto"  # "mesh" or "auto"


from bs4 import BeautifulSoup
from collections import defaultdict
import numpy as np
import os
import numpy as np
from numpy import count_nonzero as nnz
import pandas as pd
import pickle
from posixpath import join
from tqdm.notebook import tqdm
from nltk import sent_tokenize

from lightning.vocabulary_light import Vocabulary

# %load_ext autoreload
# %autoreload 2
base_path = "/mnt/datasets/uc5/std-dataset"  # subfolders image, text
reports_fld = join(base_path, "text")
images_fld = join(base_path, "image")


# 1:  reports_raw3: all data - mesh "technical quality of image unsatisfactory", "no indexing"

meta_fld =  "/mnt/datasets/uc5/meta/iuchest_light"

# ! IMPORTANT
in_filename = "reports_raw3.pkl" if vocab_for_terms == "mesh" else "reports_raw2.pkl"
out_filename = "all_vocab.pkl" if vocab_for_terms == "mesh" else "all_vocab_auto.pkl"


in_fn = join(meta_fld, in_filename)
df = pd.read_pickle(in_fn)
display(df.T)
print(f"{in_fn}, shape: {df.shape}")

print("--")

# step, build vocabulary
text_col = df.text
vocab = Vocabulary()
for (id, text) in text_col.iteritems():
    for sentence in sent_tokenize(text):
        if len(sentence) == 0:
            print("ERROR, sentence length == 0")
        vocab.add_sentence(sentence)

print("number of distinct words:", len(vocab.word2idx))
print("total number of words:", vocab.word_count)

out_fn = join(meta_fld, out_filename)
with open(out_fn, "wb") as fout:
    pickle.dump(vocab, fout)


# # step
# # now encode image labels as a matrix of binary vectors
# in_fn = join(meta_fld, "reports_raw2.pkl")
# df = pd.read_pickle(in_fn)
# print(f"read {in_fn}, shape: {df.shape}")
# display(df.head().T)


# label2idx = {}
# idx2label = {}
# for i, t in enumerate(umesh):
#     label2idx[t] = i
#     idx2label[i] = t

# import yaml
# with open(join(out_fld, "label2idx.yaml"), "w") as fout:
#     yaml.dump(label2idx, fout)

# with open(join(out_fld, "idx2label.yaml"), "w") as fout:
#     yaml.dump(idx2label, fout)

# # test
# with open(join(out_fld, "label2idx.yaml"), "r") as fin:
#     label2idx = yaml.safe_load(fin)

# with open(join(out_fld, "idx2label.yaml"), "r") as fin:
#     idx2label = yaml.safe_load(fin)

# for lbl, idx in label2idx.items():
#     print(f"{lbl}: {idx}, {idx2label[idx]}")


print(f"all done, saved vocabulary: {out_fn}")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# id                                                                 1  \
# comparison                                                     none.
# indication                                          positive tb test
# findings           the cardiac silhouette and mediastinum size ar...
# impression                                      normal chest x-xxxx.
# orig_mesh_terms                                             [normal]
# orig_auto_term                                              [normal]
# image_filename     [CXR1_1_IM-0001-3001.png, CXR1_1_IM-0001-4001....
# filename                                                       1.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  0
# impression_sents                              [normal chest x-xxxx.]
# findings_sents     [the cardiac silhouette and mediastinum size a...
# len_impression                                                    20
# len_findings                                                     210
# nsents_impression                                                  1
# nsents_findings                                                    5
# raw_text           the cardiac silhouette and mediastinum size ar...
# len_raw_text                                                     231
# nsents_raw_text                                                    6
# major_mesh                                                  [normal]
# n_major_mesh                                                       1
# auto_term                                                   [normal]
# text               the cardiac silhouette and mediastinum size ar...
#
# id                                                                10  \
# comparison                                   chest radiographs xxxx.
# indication                           xxxx-year-old male, chest pain.
# findings           the cardiomediastinal silhouette is within nor...
# impression                         no acute cardiopulmonary process.
# orig_mesh_terms          [calcified granuloma/lung/upper lobe/right]
# orig_auto_term                                 [calcified granuloma]
# image_filename      [CXR10_IM-0002-1001.png, CXR10_IM-0002-2001.png]
# filename                                                      10.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  1
# impression_sents                 [no acute cardiopulmonary process.]
# findings_sents     [the cardiomediastinal silhouette is within no...
# len_impression                                                    33
# len_findings                                                     273
# nsents_impression                                                  1
# nsents_findings                                                    4
# raw_text           the cardiomediastinal silhouette is within nor...
# len_raw_text                                                     307
# nsents_raw_text                                                    5
# major_mesh                                     [calcified granuloma]
# n_major_mesh                                                       1
# auto_term                                      [calcified granuloma]
# text               the cardiomediastinal silhouette is within nor...
#
# id                                                               100  \
# comparison                                                     none.
# indication
# findings           both lungs are clear and expanded. heart and m...
# impression                                        no active disease.
# orig_mesh_terms                                             [normal]
# orig_auto_term                                              [normal]
# image_filename     [CXR100_IM-0002-1001.png, CXR100_IM-0002-2001....
# filename                                                     100.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  0
# impression_sents                                [no active disease.]
# findings_sents     [both lungs are clear and expanded., heart and...
# len_impression                                                    18
# len_findings                                                      64
# nsents_impression                                                  1
# nsents_findings                                                    2
# raw_text           both lungs are clear and expanded. heart and m...
# len_raw_text                                                      83
# nsents_raw_text                                                    3
# major_mesh                                                  [normal]
# n_major_mesh                                                       1
# auto_term                                                   [normal]
# text               both lungs are clear and expanded. heart and m...
#
# id                                                              1000  \
# comparison                     xxxx pa and lateral chest radiographs
# indication                                 xxxx-year-old male, xxxx.
# findings           there is xxxx increased opacity within the rig...
# impression         1. increased opacity in the right upper lobe w...
# orig_mesh_terms    [opacity/lung/upper lobe/right, pulmonary atel...
# orig_auto_term     [atelectases, mass lesion, opacity, atelectasi...
# image_filename     [CXR1000_IM-0003-1001.png, CXR1000_IM-0003-200...
# filename                                                    1000.xml
# n_images                                                           3
# n_orig_mesh_terms                                                  3
# n_orig_auto_terms                                                  5
# impression_sents   [1. increased opacity in the right upper lobe ...
# findings_sents     [there is xxxx increased opacity within the ri...
# len_impression                                                   268
# len_findings                                                     357
# nsents_impression                                                  3
# nsents_findings                                                    5
# raw_text           there is xxxx increased opacity within the rig...
# len_raw_text                                                     626
# nsents_raw_text                                                    8
# major_mesh                          [pulmonary atelectasis, opacity]
# n_major_mesh                                                       2
# auto_term                   [atelectasis, mass lesion, opacity, rib]
# text               there is xxxx increased opacity within the rig...
#
# id                                                              1001  \
# comparison                                                      none
# indication         dyspnea, subjective fevers, arthritis, immigra...
# findings           interstitial markings are diffusely prominent ...
# impression         diffuse fibrosis. no visible focal acute disease.
# orig_mesh_terms    [markings/lung/bilateral/interstitial/diffuse/...
# orig_auto_term      [diffuse fibrosis, fibrosis, pulmonary fibrosis]
# image_filename     [CXR1001_IM-0004-1001.png, CXR1001_IM-0004-100...
# filename                                                    1001.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  2
# n_orig_auto_terms                                                  3
# impression_sents   [diffuse fibrosis., no visible focal acute dis...
# findings_sents     [interstitial markings are diffusely prominent...
# len_impression                                                    49
# len_findings                                                     113
# nsents_impression                                                  2
# nsents_findings                                                    3
# raw_text           interstitial markings are diffusely prominent ...
# len_raw_text                                                     163
# nsents_raw_text                                                    5
# major_mesh                                      [markings, fibrosis]
# n_major_mesh                                                       2
# auto_term           [diffuse fibrosis, fibrosis, pulmonary fibrosis]
# text               interstitial markings are diffusely prominent ...
#
# id                                                              1002  \
# comparison
# indication                                     history of chest pain
# findings
# impression         status post left mastectomy. heart size normal...
# orig_mesh_terms                                    [mastectomy/left]
# orig_auto_term                   [mastectomies, mastectomy, surgery]
# image_filename     [CXR1002_IM-0004-1001.png, CXR1002_IM-0004-200...
# filename                                                    1002.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  3
# impression_sents   [status post left mastectomy., heart size norm...
# findings_sents                                                    []
# len_impression                                                    64
# len_findings                                                       0
# nsents_impression                                                  3
# nsents_findings                                                    0
# raw_text           status post left mastectomy. heart size normal...
# len_raw_text                                                      64
# nsents_raw_text                                                    3
# major_mesh                                              [mastectomy]
# n_major_mesh                                                       1
# auto_term                        [mastectomies, mastectomy, surgery]
# text               status post left mastectomy. heart size normal...
#
# id                                                              1003  \
# comparison
# indication                                         acute bronchitis.
# findings           heart size and pulmonary vascularity appear wi...
# impression         1. retrocardiac soft tissue density. the appea...
# orig_mesh_terms    [density/retrocardiac, calcinosis/blood vessel...
# orig_auto_term     [atelectases, calcified granuloma, hiatal hern...
# image_filename                            [CXR1003_IM-0005-2002.png]
# filename                                                    1003.xml
# n_images                                                           1
# n_orig_mesh_terms                                                  5
# n_orig_auto_terms                                                  8
# impression_sents   [1. retrocardiac soft tissue density., the app...
# findings_sents     [heart size and pulmonary vascularity appear w...
# len_impression                                                   148
# len_findings                                                     458
# nsents_impression                                                  4
# nsents_findings                                                    9
# raw_text           heart size and pulmonary vascularity appear wi...
# len_raw_text                                                     607
# nsents_raw_text                                                   13
# major_mesh         [opacity, density, calcinosis, calcified granu...
# n_major_mesh                                                       5
# auto_term          [atelectasis, calcified granuloma, hiatal hern...
# text               heart size and pulmonary vascularity appear wi...
#
# id                                                              1004  \
# comparison                        two views of the chest dated xxxx.
# indication         xxxx-year-old with xxxx for one month. history...
# findings           the heart, pulmonary xxxx and mediastinum are ...
# impression                         no acute cardiopulmonary disease.
# orig_mesh_terms    [aorta/tortuous, shoulder/bilateral/degenerati...
# orig_auto_term                                 [degenerative change]
# image_filename     [CXR1004_IM-0005-1001.png, CXR1004_IM-0005-200...
# filename                                                    1004.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  4
# n_orig_auto_terms                                                  1
# impression_sents                 [no acute cardiopulmonary disease.]
# findings_sents     [the heart, pulmonary xxxx and mediastinum are...
# len_impression                                                    33
# len_findings                                                     346
# nsents_impression                                                  1
# nsents_findings                                                    7
# raw_text           the heart, pulmonary xxxx and mediastinum are ...
# len_raw_text                                                     380
# nsents_raw_text                                                    8
# major_mesh           [aorta, spine, catheters, indwelling, shoulder]
# n_major_mesh                                                       4
# auto_term                                      [degenerative change]
# text               the heart pulmonary xxxx and mediastinum are w...
#
# id                                                              1005  \
# comparison                                                     none.
# indication                                                 pruritic.
# findings           cardiac and mediastinal contours are within no...
# impression                                        no acute findings.
# orig_mesh_terms                                             [normal]
# orig_auto_term                                              [normal]
# image_filename     [CXR1005_IM-0006-1001.png, CXR1005_IM-0006-300...
# filename                                                    1005.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  0
# impression_sents                                [no acute findings.]
# findings_sents     [cardiac and mediastinal contours are within n...
# len_impression                                                    18
# len_findings                                                     107
# nsents_impression                                                  1
# nsents_findings                                                    3
# raw_text           cardiac and mediastinal contours are within no...
# len_raw_text                                                     126
# nsents_raw_text                                                    4
# major_mesh                                                  [normal]
# n_major_mesh                                                       1
# auto_term                                                   [normal]
# text               cardiac and mediastinal contours are within no...
#
# id                                                              1006  ...  \
# comparison                                                            ...
# indication                                 ,786.05 xxxx xxxx to xxxx  ...
# findings           the lungs appear clear. there are no focal air...  ...
# impression                         no acute cardiopulmonary disease.  ...
# orig_mesh_terms                                             [normal]  ...
# orig_auto_term                                              [normal]  ...
# image_filename     [CXR1006_IM-0007-1001.png, CXR1006_IM-0007-300...  ...
# filename                                                    1006.xml  ...
# n_images                                                           2  ...
# n_orig_mesh_terms                                                  1  ...
# n_orig_auto_terms                                                  0  ...
# impression_sents                 [no acute cardiopulmonary disease.]  ...
# findings_sents     [the lungs appear clear., there are no focal a...  ...
# len_impression                                                    33  ...
# len_findings                                                     213  ...
# nsents_impression                                                  1  ...
# nsents_findings                                                    6  ...
# raw_text           the lungs appear clear. there are no focal air...  ...
# len_raw_text                                                     247  ...
# nsents_raw_text                                                    7  ...
# major_mesh                                                  [normal]  ...
# n_major_mesh                                                       1  ...
# auto_term                                                   [normal]  ...
# text               the lungs appear clear. there are no focal air...  ...
#
# id                                                               990  \
# comparison                                 two-view chest from xxxx.
# indication            xxxx-year-old male with altered mental status.
# findings           heart size within normal limits. no focal airs...
# impression                        no acute cardiopulmonary findings.
# orig_mesh_terms                                             [normal]
# orig_auto_term                                              [normal]
# image_filename     [CXR990_IM-2476-1001.png, CXR990_IM-2476-2001....
# filename                                                     990.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  0
# impression_sents                [no acute cardiopulmonary findings.]
# findings_sents     [heart size within normal limits., no focal ai...
# len_impression                                                    34
# len_findings                                                      96
# nsents_impression                                                  1
# nsents_findings                                                    3
# raw_text           heart size within normal limits. no focal airs...
# len_raw_text                                                     131
# nsents_raw_text                                                    4
# major_mesh                                                  [normal]
# n_major_mesh                                                       1
# auto_term                                                   [normal]
# text               heart size within normal limits. no focal airs...
#
# id                                                               991  \
# comparison                               rib radiographs dated xxxx.
# indication         xxxx-year-old with pneumonia. shortness of bre...
# findings           the heart size is upper limits of normal. the ...
# impression         minimal perihilar opacity which could indicate...
# orig_mesh_terms                    [opacity/lung/hilum/streaky/mild]
# orig_auto_term                        [atypical pneumonias, opacity]
# image_filename     [CXR991_IM-2476-1001.png, CXR991_IM-2476-2001....
# filename                                                     991.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  2
# impression_sents   [minimal perihilar opacity which could indicat...
# findings_sents     [the heart size is upper limits of normal., th...
# len_impression                                                    69
# len_findings                                                     257
# nsents_impression                                                  1
# nsents_findings                                                    4
# raw_text           the heart size is upper limits of normal. the ...
# len_raw_text                                                     327
# nsents_raw_text                                                    5
# major_mesh                                                 [opacity]
# n_major_mesh                                                       1
# auto_term                             [atypical pneumonias, opacity]
# text               the heart size is upper limits of normal. the ...
#
# id                                                               992  \
# comparison                                                      none
# indication                                                  melanoma
# findings           there are bilateral pulmonary nodules whose ap...
# impression         1. bilateral pulmonary nodules suggesting pulm...
# orig_mesh_terms    [nodule/lung/bilateral/multiple, surgical inst...
# orig_auto_term     [metastatic disease, nodule, opacity, pulmonar...
# image_filename     [CXR992_IM-2477-0001-0001.png, CXR992_IM-2477-...
# filename                                                     992.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  3
# n_orig_auto_terms                                                  9
# impression_sents   [1. bilateral pulmonary nodules suggesting pul...
# findings_sents     [there are bilateral pulmonary nodules whose a...
# len_impression                                                   142
# len_findings                                                     769
# nsents_impression                                                  1
# nsents_findings                                                   10
# raw_text           there are bilateral pulmonary nodules whose ap...
# len_raw_text                                                     912
# nsents_raw_text                                                   11
# major_mesh         [surgical instruments, catheters, indwelling, ...
# n_major_mesh                                                       3
# auto_term          [catheter, catheterization, central venous, ju...
# text               there are bilateral pulmonary nodules whose ap...
#
# id                                                               993  \
# comparison                                                     none.
# indication                                     possible tuberculosis
# findings           heart size normal. lungs are clear. xxxx are n...
# impression                 normal chest no evidence of tuberculosis.
# orig_mesh_terms                                             [normal]
# orig_auto_term                                              [normal]
# image_filename     [CXR993_IM-2478-1001.png, CXR993_IM-2478-1002....
# filename                                                     993.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  0
# impression_sents         [normal chest no evidence of tuberculosis.]
# findings_sents     [heart size normal., lungs are clear., xxxx ar...
# len_impression                                                    41
# len_findings                                                     129
# nsents_impression                                                  1
# nsents_findings                                                    4
# raw_text           heart size normal. lungs are clear. xxxx are n...
# len_raw_text                                                     171
# nsents_raw_text                                                    5
# major_mesh                                                  [normal]
# n_major_mesh                                                       1
# auto_term                                                   [normal]
# text               heart size normal. lungs are clear. xxxx are n...
#
# id                                                               994  \
# comparison                                                      xxxx
# indication                                         xxxx for one xxxx
# findings           the lungs are clear. the cardiomediastinal sil...
# impression                                          negative chest .
# orig_mesh_terms                                             [normal]
# orig_auto_term                                              [normal]
# image_filename     [CXR994_IM-2478-1001.png, CXR994_IM-2478-2001....
# filename                                                     994.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  0
# impression_sents                                  [negative chest .]
# findings_sents     [the lungs are clear., the cardiomediastinal s...
# len_impression                                                    16
# len_findings                                                     115
# nsents_impression                                                  1
# nsents_findings                                                    3
# raw_text           the lungs are clear. the cardiomediastinal sil...
# len_raw_text                                                     132
# nsents_raw_text                                                    4
# major_mesh                                                  [normal]
# n_major_mesh                                                       1
# auto_term                                                   [normal]
# text               the lungs are clear. the cardiomediastinal sil...
#
# id                                                               995  \
# comparison                                               xxxx, xxxx.
# indication                                      sp cabg sob no rales
# findings           sternotomy sutures and bypass grafts have been...
# impression               post operative chest with no acute disease.
# orig_mesh_terms                                    [sutures/sternum]
# orig_auto_term     [bypass grafts, sternotomy, coronary artery by...
# image_filename     [CXR995_IM-2478-1001.png, CXR995_IM-2478-1002....
# filename                                                     995.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  5
# impression_sents       [post operative chest with no acute disease.]
# findings_sents     [sternotomy sutures and bypass grafts have bee...
# len_impression                                                    43
# len_findings                                                     155
# nsents_impression                                                  1
# nsents_findings                                                    3
# raw_text           sternotomy sutures and bypass grafts have been...
# len_raw_text                                                     199
# nsents_raw_text                                                    4
# major_mesh                                                 [sutures]
# n_major_mesh                                                       1
# auto_term          [bypass grafts, coronary artery bypass, postop...
# text               sternotomy sutures and bypass grafts have been...
#
# id                                                               996  \
# comparison
# indication                                               chest pain.
# findings
# impression         heart size is normal and lungs are clear. no p...
# orig_mesh_terms                                             [normal]
# orig_auto_term                                              [normal]
# image_filename     [CXR996_IM-2479-1001.png, CXR996_IM-2479-2001....
# filename                                                     996.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  0
# impression_sents   [heart size is normal and lungs are clear., no...
# findings_sents                                                    []
# len_impression                                                    82
# len_findings                                                       0
# nsents_impression                                                  2
# nsents_findings                                                    0
# raw_text           heart size is normal and lungs are clear. no p...
# len_raw_text                                                      82
# nsents_raw_text                                                    2
# major_mesh                                                  [normal]
# n_major_mesh                                                       1
# auto_term                                                   [normal]
# text               heart size is normal and lungs are clear. no p...
#
# id                                                               997  \
# comparison                    chest x-xxxx dated xxxx at xxxx hours.
# indication                  xxxx-year-old female, transplant workup.
# findings           calcified mediastinal xxxx. no focal areas of ...
# impression                   no acute cardiopulmonary abnormality. .
# orig_mesh_terms    [calcinosis/mediastinum, thoracic vertebrae/de...
# orig_auto_term                                 [degenerative change]
# image_filename     [CXR997_IM-2479-1001.png, CXR997_IM-2479-2001....
# filename                                                     997.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  2
# n_orig_auto_terms                                                  1
# impression_sents          [no acute cardiopulmonary abnormality., .]
# findings_sents     [calcified mediastinal xxxx., no focal areas o...
# len_impression                                                    39
# len_findings                                                     181
# nsents_impression                                                  2
# nsents_findings                                                    6
# raw_text           calcified mediastinal xxxx. no focal areas of ...
# len_raw_text                                                     221
# nsents_raw_text                                                    8
# major_mesh                          [thoracic vertebrae, calcinosis]
# n_major_mesh                                                       2
# auto_term                                      [degenerative change]
# text               calcified mediastinal xxxx. no focal areas of ...
#
# id                                                               998  \
# comparison                                                     none.
# indication                             xxxx-year-old xxxx with pain.
# findings           cardiomediastinal silhouette demonstrates norm...
# impression                     no acute cardiopulmonary abnormality.
# orig_mesh_terms    [atherosclerosis/aorta, thoracic, aorta, thora...
# orig_auto_term     [atheroscleroses, degenerative disc diseases, ...
# image_filename     [CXR998_IM-2479-1001.png, CXR998_IM-2479-2001....
# filename                                                     998.xml
# n_images                                                           2
# n_orig_mesh_terms                                                  3
# n_orig_auto_terms                                                  5
# impression_sents             [no acute cardiopulmonary abnormality.]
# findings_sents     [cardiomediastinal silhouette demonstrates nor...
# len_impression                                                    37
# len_findings                                                     281
# nsents_impression                                                  1
# nsents_findings                                                    4
# raw_text           cardiomediastinal silhouette demonstrates norm...
# len_raw_text                                                     319
# nsents_raw_text                                                    5
# major_mesh         [thoracic vertebrae, atherosclerosis, aorta, t...
# n_major_mesh                                                       3
# auto_term          [atherosclerosis, degenerative disc diseases, ...
# text               cardiomediastinal silhouette demonstrates norm...
#
# id                                                               999
# comparison                                                      none
# indication                                                chest pain
# findings           lungs are clear bilaterally. there is no focal...
# impression                     no acute cardiopulmonary abnormality.
# orig_mesh_terms                                             [normal]
# orig_auto_term                                              [normal]
# image_filename     [CXR999_IM-2480-1001.png, CXR999_IM-2480-2001....
# filename                                                     999.xml
# n_images                                                           3
# n_orig_mesh_terms                                                  1
# n_orig_auto_terms                                                  0
# impression_sents             [no acute cardiopulmonary abnormality.]
# findings_sents     [lungs are clear bilaterally., there is no foc...
# len_impression                                                    37
# len_findings                                                     175
# nsents_impression                                                  1
# nsents_findings                                                    4
# raw_text           lungs are clear bilaterally. there is no focal...
# len_raw_text                                                     213
# nsents_raw_text                                                    5
# major_mesh                                                  [normal]
# n_major_mesh                                                       1
# auto_term                                                   [normal]
# text               lungs are clear bilaterally. there is no focal...
#
# [24 rows x 3851 columns]
# /mnt/datasets/uc5/meta/iuchest_light/reports_raw2.pkl, shape: (3851, 24)
# --
# number of distinct words: 2674
# total number of words: 143372
# all done, saved vocabulary: /mnt/datasets/uc5/meta/iuchest_light/all_vocab_auto.pkl

# %%
# independent
# process vocabulary MAX WORDS

#     #    #    #     #         #     # ####### ######  ######   #####
##   ##   # #    #   #          #  #  # #     # #     # #     # #     #
# # # #  #   #    # #           #  #  # #     # #     # #     # #
#  #  # #     #    #            #  #  # #     # ######  #     #  #####
#     # #######   # #           #  #  # #     # #   #   #     #       #
#     # #     #  #   #          #  #  # #     # #    #  #     # #     #
#     # #     # #     #          ## ##  ####### #     # ######   #####


# ! important
vocab_for_terms = "auto"  # "mesh" or "auto"


from bs4 import BeautifulSoup
from collections import defaultdict
import numpy as np
import os
import numpy as np
from numpy import count_nonzero as nnz
import pandas as pd
import pickle
from posixpath import join
from tqdm.notebook import tqdm

from lightning.vocabulary_light import Vocabulary

# %load_ext autoreload
# %autoreload 2
base_path = "/mnt/datasets/uc5/std-dataset"  # subfolders image, text
reports_fld = join(base_path, "text")
images_fld = join(base_path, "image")

# dataset
meta_fld =  "/mnt/datasets/uc5/meta/iuchest_light"
in_filename = "reports_raw3.pkl" if vocab_for_terms == "mesh" else "reports_raw2.pkl"
vocab_filename = "all_vocab" if vocab_for_terms == "mesh" else "all_vocab_auto"

in_fn = join(meta_fld, in_filename)
df = pd.read_pickle(in_fn)
print(f"read {in_fn}, shape: {df.shape}")
# display(df.T)
# read vocabulary
with open( join(meta_fld, vocab_filename + ".pkl"), "rb") as fin:
    vocab = pickle.load(fin)

print("(all) num words:", len(vocab.word2idx))
print("(all) word count:", vocab.word_count)

sel_words = []
n_words = 1000
wc = list(vocab.word2count.items())
# words sorted according to their absolute frequency in the dataset
wc = sorted(wc, key=lambda elem: -elem[1])


n = 0
for w, c in wc:
    n += c
print("(all) total number of words (summed):", n)

wc2 = wc[:1000]

n2 = 0
for w, c in wc2:
    # print(f"{w}:{c}")
    n2 += c

# for word, count in vocab.word2count.items():
#     print(f"{word}: {count}")

print("(all) n:", n)
print("(filt) n2:", n2)

print("coverage after filtering:", n2 / n)
print("diff in word count:", n2 - n)
vocab.keep_n_words(1000)
print("saved word count:", vocab.word_count)
out_vocab_fn = join(meta_fld, vocab_filename + "_1000.pkl")
with open(out_vocab_fn, "wb") as fout:
    pickle.dump(vocab, fout)
print("all done, saved:", out_vocab_fn)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# read /mnt/datasets/uc5/meta/iuchest_light/reports_raw2.pkl, shape: (3851, 24)
# (all) num words: 2674
# (all) word count: 143372
# (all) total number of words (summed): 143372
# (all) n: 143372
# (filt) n2: 140148
# coverage after filtering: 0.9775130429930531
# diff in word count: -3224
# (vocabulary) initial word count (total): 143372
# (vocabulary) initial number of words: 2670
# (vocabulary) after iterating with add_word number of words: 1000
# (vocabulary) final word_count (total):  140148
# (vocabulary) final number of words: 1000
# saved word count: 140148
# all done, saved: /mnt/datasets/uc5/meta/iuchest_light/all_vocab_auto_1000.pkl

# %% [markdown]
# <font color="yellow">experiments</font>

# %%
# indipendent: can be run 
# 2: keep only label with a minimum frequency, select words and encode text
from bs4 import BeautifulSoup
from collections import defaultdict
import numpy as np
import os
import numpy as np
from numpy import count_nonzero as nnz
import pandas as pd
import pickle
from posixpath import join
from tqdm.notebook import tqdm
import yaml

from lightning.vocabulary_light import Vocabulary

#! IMPORTANT labels
LABELS = "auto"  # "mesh" or "auto"
# min frequency
# min_freq = 130 for mesh
min_freq = 100
# ! important exp_fld
exp_fld = "/opt/uc5/results/experiments_lightning/wp6_lt"
import os
os.makedirs(exp_fld, exist_ok=True)



meta_fld = "/mnt/datasets/uc5/meta/iuchest_light"
reports_fn = "reports_raw2.pkl" if LABELS == "auto" else "reports_raw3.pkl"
# * dataset
ds = pd.read_pickle(join(meta_fld, reports_fn))
print(f"read {reports_fn}, shape: {ds.shape}")
display(ds.head())


img_ds_fn = "img_dataset_auto_light.pkl" if LABELS == "auto" else "img_dataset_auto.pkl"
in_vocab_fn = "all_vocab_auto_1000.pkl" if LABELS == "auto" else "all_vocab_1000.pkl"


img_ds = pd.read_pickle(join(meta_fld, img_ds_fn))
# rep_ds = pd.read_pickle(join(meta_fld, "rep_dataset.pkl"))
display(img_ds.head().T)

counts = img_ds.sum(axis=0)
iii = counts >= min_freq
print(f"{nnz(iii)} labels have at least {min_freq} freq")

keep_labels = img_ds.columns[iii]
drop_labels = img_ds.columns[~iii]
img_ds["misc"] = 0
misc_iii = img_ds[drop_labels].sum(axis=1) > 0
img_ds.loc[misc_iii, "misc"] = 1
img_ds.drop(columns=drop_labels, inplace=True)
# display(img_ds)

def save_label_indexes(df, out_fld):
    cols = df.columns
    lab2idx = {}
    idx2lab = {}
    for i, c in enumerate(cols):
        lab2idx[c] = i
        idx2lab[i] = c
        print(f"{i}) {c}")
    with open(join(out_fld, "label2idx.yaml"), "w") as fout:
        yaml.safe_dump(lab2idx, fout)
    print(f"saved {join(out_fld, 'label2idx.yaml')}")
    print(f"lab2idx with {len(lab2idx)} labels")
    with open(join(out_fld, "idx2label.yaml"), "w") as fout:
        yaml.safe_dump(idx2lab, fout)
    print(f"saved {join(out_fld, 'idx2label.yaml')}")
#<

save_label_indexes(img_ds, exp_fld)
img_ds.to_pickle(join(exp_fld, "img_dataset.pkl"))
print(f"saved {join(exp_fld, 'img_dataset.pkl')}")

# now the text
with open(join(meta_fld, in_vocab_fn), "rb") as fin:
    vocab = pickle.load(fin)
with open(join(exp_fld, "vocab.pkl"), "wb") as fout:
    pickle.dump(vocab, fout)
print(f"vocabulary saved in exp folder, {join(exp_fld, 'vocab.pkl')}")
print(f"num words: {len(vocab.word2idx)}, including special token")

# build aux dataset with columns: report, image filename, text, encoded text


def encode_text(sentences, vocab):
    word_indexes = []
    for sent in sentences.split("."):
        tokens = sent.strip().split()
        enc_sent = []
        for t in tokens:
            enc_sent.append(vocab.word2idx.get(t, Vocabulary.OOV))
        word_indexes.append(enc_sent)

    return word_indexes


rep_ids = []
image_filenames = []
texts = []
for row in ds.reset_index().itertuples():
    for fn in row.image_filename:
        rep_ids.append(row.id)
        image_filenames.append(fn)
        texts.append(row.text)
img_text_ds = pd.DataFrame()
img_text_ds["id"] = rep_ids
img_text_ds["image_filename"] = image_filenames
img_text_ds["text"] = texts
pd.columns = ["id", "image_filename", "text"]
display(img_text_ds.head())

enc_text = img_text_ds.text.apply(encode_text, args=(vocab,))
img_text_ds["enc_text"] = enc_text

display(img_text_ds.head())
out_fn = "img_text_dataset.pkl"
img_text_ds.to_pickle(join(exp_fld, out_fn))
print(f"saved {join(exp_fld, out_fn)}")


print("done")
# Out:
# read reports_raw2.pkl, shape: (3851, 24)
#                                  comparison  \
# id
# 1                                     none.
# 10                  chest radiographs xxxx.
# 100                                   none.
# 1000  xxxx pa and lateral chest radiographs
# 1001                                   none
#
#                                              indication  \
# id
# 1                                      positive tb test
# 10                      xxxx-year-old male, chest pain.
# 100
# 1000                          xxxx-year-old male, xxxx.
# 1001  dyspnea, subjective fevers, arthritis, immigra...
#
#                                                findings  \
# id
# 1     the cardiac silhouette and mediastinum size ar...
# 10    the cardiomediastinal silhouette is within nor...
# 100   both lungs are clear and expanded. heart and m...
# 1000  there is xxxx increased opacity within the rig...
# 1001  interstitial markings are diffusely prominent ...
#
#                                              impression  \
# id
# 1                                  normal chest x-xxxx.
# 10                    no acute cardiopulmonary process.
# 100                                  no active disease.
# 1000  1. increased opacity in the right upper lobe w...
# 1001  diffuse fibrosis. no visible focal acute disease.
#
#                                         orig_mesh_terms  \
# id
# 1                                              [normal]
# 10          [calcified granuloma/lung/upper lobe/right]
# 100                                            [normal]
# 1000  [opacity/lung/upper lobe/right, pulmonary atel...
# 1001  [markings/lung/bilateral/interstitial/diffuse/...
#
#                                          orig_auto_term  \
# id
# 1                                              [normal]
# 10                                [calcified granuloma]
# 100                                            [normal]
# 1000  [atelectases, mass lesion, opacity, atelectasi...
# 1001   [diffuse fibrosis, fibrosis, pulmonary fibrosis]
#
#                                          image_filename  filename  n_images  \
# id
# 1     [CXR1_1_IM-0001-3001.png, CXR1_1_IM-0001-4001....     1.xml         2
# 10     [CXR10_IM-0002-1001.png, CXR10_IM-0002-2001.png]    10.xml         2
# 100   [CXR100_IM-0002-1001.png, CXR100_IM-0002-2001....   100.xml         2
# 1000  [CXR1000_IM-0003-1001.png, CXR1000_IM-0003-200...  1000.xml         3
# 1001  [CXR1001_IM-0004-1001.png, CXR1001_IM-0004-100...  1001.xml         2
#
#       n_orig_mesh_terms  ...  len_findings nsents_impression nsents_findings  \
# id                       ...
# 1                     1  ...           210                 1               5
# 10                    1  ...           273                 1               4
# 100                   1  ...            64                 1               2
# 1000                  3  ...           357                 3               5
# 1001                  2  ...           113                 2               3
#
#                                                raw_text  len_raw_text  \
# id
# 1     the cardiac silhouette and mediastinum size ar...           231
# 10    the cardiomediastinal silhouette is within nor...           307
# 100   both lungs are clear and expanded. heart and m...            83
# 1000  there is xxxx increased opacity within the rig...           626
# 1001  interstitial markings are diffusely prominent ...           163
#
#       nsents_raw_text                        major_mesh n_major_mesh  \
# id
# 1                   6                          [normal]            1
# 10                  5             [calcified granuloma]            1
# 100                 3                          [normal]            1
# 1000                8  [pulmonary atelectasis, opacity]            2
# 1001                5              [markings, fibrosis]            2
#
#                                              auto_term  \
# id
# 1                                             [normal]
# 10                               [calcified granuloma]
# 100                                           [normal]
# 1000          [atelectasis, mass lesion, opacity, rib]
# 1001  [diffuse fibrosis, fibrosis, pulmonary fibrosis]
#
#                                                    text
# id
# 1     the cardiac silhouette and mediastinum size ar...
# 10    the cardiomediastinal silhouette is within nor...
# 100   both lungs are clear and expanded. heart and m...
# 1000  there is xxxx increased opacity within the rig...
# 1001  interstitial markings are diffusely prominent ...
#
# [5 rows x 24 columns]
# filename                           CXR1_1_IM-0001-3001.png  \
# normal                                                   1
# abdomen                                                  0
# abdominal surgery                                        0
# absence of right pulmonary artery                        0
# absorptiometry, photon                                   0
# ...                                                    ...
# vertebroplasty                                           0
# viral bronchiolitis                                      0
# viral pneumonias                                         0
# volume overload                                          0
# wounds, gunshot                                          0
#
# filename                           CXR1_1_IM-0001-4001.png  \
# normal                                                   1
# abdomen                                                  0
# abdominal surgery                                        0
# absence of right pulmonary artery                        0
# absorptiometry, photon                                   0
# ...                                                    ...
# vertebroplasty                                           0
# viral bronchiolitis                                      0
# viral pneumonias                                         0
# volume overload                                          0
# wounds, gunshot                                          0
#
# filename                           CXR10_IM-0002-1001.png  \
# normal                                                  0
# abdomen                                                 0
# abdominal surgery                                       0
# absence of right pulmonary artery                       0
# absorptiometry, photon                                  0
# ...                                                   ...
# vertebroplasty                                          0
# viral bronchiolitis                                     0
# viral pneumonias                                        0
# volume overload                                         0
# wounds, gunshot                                         0
#
# filename                           CXR10_IM-0002-2001.png  \
# normal                                                  0
# abdomen                                                 0
# abdominal surgery                                       0
# absence of right pulmonary artery                       0
# absorptiometry, photon                                  0
# ...                                                   ...
# vertebroplasty                                          0
# viral bronchiolitis                                     0
# viral pneumonias                                        0
# volume overload                                         0
# wounds, gunshot                                         0
#
# filename                           CXR100_IM-0002-1001.png
# normal                                                   1
# abdomen                                                  0
# abdominal surgery                                        0
# absence of right pulmonary artery                        0
# absorptiometry, photon                                   0
# ...                                                    ...
# vertebroplasty                                           0
# viral bronchiolitis                                      0
# viral pneumonias                                         0
# volume overload                                          0
# wounds, gunshot                                          0
#
# [529 rows x 5 columns]
# 20 labels have at least 100 freq
# 0) normal
# 1) atelectasis
# 2) calcified granuloma
# 3) cardiomegaly
# 4) deformity
# 5) degenerative change
# 6) diaphragm
# 7) emphysema
# 8) granuloma
# 9) granulomatous disease
# 10) infiltrates
# 11) nodule
# 12) opacity
# 13) osteophyte
# 14) pleural effusion
# 15) pneumonia
# 16) pulmonary emphysema
# 17) scarring
# 18) sternotomy
# 19) thoracic aorta
# 20) misc
# saved /opt/uc5/results/experiments_lightning/auto_terms/label2idx.yaml
# lab2idx with 21 labels
# saved /opt/uc5/results/experiments_lightning/auto_terms/idx2label.yaml
# saved /opt/uc5/results/experiments_lightning/auto_terms/img_dataset.pkl
# vocabulary saved in exp folder, /opt/uc5/results/experiments_lightning/auto_terms/vocab.pkl
# num words: 1004, including special token
#     id           image_filename  \
# 0    1  CXR1_1_IM-0001-3001.png
# 1    1  CXR1_1_IM-0001-4001.png
# 2   10   CXR10_IM-0002-1001.png
# 3   10   CXR10_IM-0002-2001.png
# 4  100  CXR100_IM-0002-1001.png
#
#                                                 text
# 0  the cardiac silhouette and mediastinum size ar...
# 1  the cardiac silhouette and mediastinum size ar...
# 2  the cardiomediastinal silhouette is within nor...
# 3  the cardiomediastinal silhouette is within nor...
# 4  both lungs are clear and expanded. heart and m...
#     id           image_filename  \
# 0    1  CXR1_1_IM-0001-3001.png
# 1    1  CXR1_1_IM-0001-4001.png
# 2   10   CXR10_IM-0002-1001.png
# 3   10   CXR10_IM-0002-2001.png
# 4  100  CXR100_IM-0002-1001.png
#
#                                                 text  \
# 0  the cardiac silhouette and mediastinum size ar...
# 1  the cardiac silhouette and mediastinum size ar...
# 2  the cardiomediastinal silhouette is within nor...
# 3  the cardiomediastinal silhouette is within nor...
# 4  both lungs are clear and expanded. heart and m...
#
#                                             enc_text
# 0  [[5, 61, 39, 9, 53, 19, 7, 22, 14, 66], [15, 6...
# 1  [[5, 61, 39, 9, 53, 19, 7, 22, 14, 66], [15, 6...
# 2  [[5, 41, 39, 6, 22, 14, 66, 50, 19, 9, 87], [5...
# 3  [[5, 41, 39, 6, 22, 14, 66, 50, 19, 9, 87], [5...
# 4  [[138, 17, 7, 40, 9, 434], [16, 9, 53, 14], [4...
# saved /opt/uc5/results/experiments_lightning/auto_terms/img_text_dataset.pkl
# done

# %%
# EXP DEPENDENT

# %%
# ! BINARY NORMAL VS REST - UNBALANCED
# 2 labels
# indipendent: can be run 
# 2: keep only label with a minimum frequency, select words and encode text
from bs4 import BeautifulSoup
from collections import defaultdict
import numpy as np
import os
import numpy as np
from numpy import count_nonzero as nnz
import pandas as pd
import pickle
from posixpath import join
from tqdm.notebook import tqdm
import yaml
import os
import iuchest.reports as iureports
from utils.vocabulary import Vocabulary

#! IMPORTANT
LABELS = "mesh"  # "mesh" or "auto"
EXP_FLD = "/opt/uc5/results/sicaai/normal_vs_rest_unbal"
os.makedirs(EXP_FLD, exist_ok=True)

meta_fld = "/mnt/datasets/uc5/meta/iuchest"
reports_fn = "reports_raw3.pkl" if LABELS == "mesh" else "reports_raw2.pkl"
img_ds_fn = "img_dataset.pkl" if LABELS == "mesh" else "img_dataset_auto.pkl"
in_vocab_fn = "all_vocab_1000.pkl" if LABELS == "mesh" else "all_vocab_auto_1000.pkl"

# * dataset
ds = pd.read_pickle(join(meta_fld, reports_fn))
print(f"read {reports_fn}, shape: {ds.shape}")
display(ds.head())


# !
# ! IMAGES
# !

img_ds = pd.read_pickle(join(meta_fld, img_ds_fn))
# rep_ds = pd.read_pickle(join(meta_fld, "rep_dataset.pkl"))
display(img_ds.head().T)

# normal images
# normal_ds = img_ds[img_ds.normal == True]

drop_cols = [c for c in img_ds.columns if c != "normal"]
img_ds = img_ds.drop(columns=drop_cols)
img_ds["other"] = (img_ds.normal != True).astype(int)

display(img_ds.head().T)
ofn = join(EXP_FLD, "img_dataset.pkl")
img_ds.to_pickle( ofn )
print(f"saved image-based ds: {ofn}, {img_ds.shape}")

def save_label_indexes(df, out_fld):
    cols = df.columns
    lab2idx = {}
    idx2lab = {}
    for i, c in enumerate(cols):
        lab2idx[c] = i
        idx2lab[i] = c
        print(f"{i}) {c}")
    with open(join(out_fld, "label2idx.yaml"), "w") as fout:
        yaml.safe_dump(lab2idx, fout)
    print(f"saved {join(out_fld, 'label2idx.yaml')}")
    print(f"lab2idx with {len(lab2idx)} labels")
    with open(join(out_fld, "idx2label.yaml"), "w") as fout:
        yaml.safe_dump(idx2lab, fout)
    print(f"saved {join(out_fld, 'idx2label.yaml')}")
#<

save_label_indexes(img_ds, EXP_FLD)

# !
# !  TEXT
# !
with open(join(meta_fld, in_vocab_fn), "rb") as fin:
    vocab = pickle.load(fin)
# copy vocab to EXP_FLD
with open(join(EXP_FLD, "vocab.pkl"), "wb") as fout:
    pickle.dump(vocab, fout)
print(f"num words: {len(vocab.word2idx)}, including special tokens")

for i in range(5):
    print(f"word {i}: {vocab.idx2word[i]}")

rep_ids = []
image_filenames = []
texts = []
for row in ds.reset_index().itertuples():
    for fn in row.image_filename:
        rep_ids.append(row.id)
        image_filenames.append(fn)
        texts.append(row.text)
img_text_ds = pd.DataFrame()
img_text_ds["id"] = rep_ids
img_text_ds["image_filename"] = image_filenames
img_text_ds["text"] = texts
pd.columns = ["id", "image_filename", "text"]

def encode_text(sentences, vocab):
    word_indexes = []
    for sent in sentences.split("."):
        tokens = sent.strip().split()
        enc_sent = []
        for t in tokens:
            enc_sent.append(vocab.word2idx.get(t, Vocabulary.OOV))
        word_indexes.append(enc_sent)

    return word_indexes
enc_text = img_text_ds.text.apply(encode_text, args=(vocab,))
img_text_ds["enc_text"] = enc_text

display(img_text_ds.head())

ofn = join( EXP_FLD, "img_text_dataset.pkl")
img_text_ds.to_pickle(ofn)
print("saved aux dataset for text:", ofn)
print("done with 'normal vs others', unbalanced")
# Out:
# read reports_raw3.pkl, shape: (3753, 26)
#                                  comparison  \
# id
# 1                                     none.
# 10                  chest radiographs xxxx.
# 100                                   none.
# 1000  xxxx pa and lateral chest radiographs
# 1001                                   none
#
#                                              indication  \
# id
# 1                                      positive tb test
# 10                      xxxx-year-old male, chest pain.
# 100
# 1000                          xxxx-year-old male, xxxx.
# 1001  dyspnea, subjective fevers, arthritis, immigra...
#
#                                                findings  \
# id
# 1     the cardiac silhouette and mediastinum size ar...
# 10    the cardiomediastinal silhouette is within nor...
# 100   both lungs are clear and expanded. heart and m...
# 1000  there is xxxx increased opacity within the rig...
# 1001  interstitial markings are diffusely prominent ...
#
#                                              impression  \
# id
# 1                                  normal chest x-xxxx.
# 10                    no acute cardiopulmonary process.
# 100                                  no active disease.
# 1000  1. increased opacity in the right upper lobe w...
# 1001  diffuse fibrosis. no visible focal acute disease.
#
#                                         orig_mesh_terms  \
# id
# 1                                              [normal]
# 10          [calcified granuloma/lung/upper lobe/right]
# 100                                            [normal]
# 1000  [opacity/lung/upper lobe/right, pulmonary atel...
# 1001  [markings/lung/bilateral/interstitial/diffuse/...
#
#                                          orig_auto_term  \
# id
# 1                                              [normal]
# 10                                [calcified granuloma]
# 100                                            [normal]
# 1000  [atelectases, mass lesion, opacity, atelectasi...
# 1001   [diffuse fibrosis, fibrosis, pulmonary fibrosis]
#
#                                          image_filename  filename  n_images  \
# id
# 1     [CXR1_1_IM-0001-3001.png, CXR1_1_IM-0001-4001....     1.xml         2
# 10     [CXR10_IM-0002-1001.png, CXR10_IM-0002-2001.png]    10.xml         2
# 100   [CXR100_IM-0002-1001.png, CXR100_IM-0002-2001....   100.xml         2
# 1000  [CXR1000_IM-0003-1001.png, CXR1000_IM-0003-200...  1000.xml         3
# 1001  [CXR1001_IM-0004-1001.png, CXR1001_IM-0004-100...  1001.xml         2
#
#       n_orig_mesh_terms  ...  nsents_findings  \
# id                       ...
# 1                     1  ...                5
# 10                    1  ...                4
# 100                   1  ...                2
# 1000                  3  ...                5
# 1001                  2  ...                3
#
#                                                raw_text len_raw_text  \
# id
# 1     the cardiac silhouette and mediastinum size ar...          231
# 10    the cardiomediastinal silhouette is within nor...          307
# 100   both lungs are clear and expanded. heart and m...           83
# 1000  there is xxxx increased opacity within the rig...          626
# 1001  interstitial markings are diffusely prominent ...          163
#
#       nsents_raw_text                        major_mesh  n_major_mesh  \
# id
# 1                   6                          [normal]             1
# 10                  5             [calcified granuloma]             1
# 100                 3                          [normal]             1
# 1000                8  [pulmonary atelectasis, opacity]             2
# 1001                5              [fibrosis, markings]             2
#
#                                              auto_term  \
# id
# 1                                             [normal]
# 10                               [calcified granuloma]
# 100                                           [normal]
# 1000          [atelectasis, mass lesion, opacity, rib]
# 1001  [diffuse fibrosis, fibrosis, pulmonary fibrosis]
#
#                                                    text  \
# id
# 1     the cardiac silhouette and mediastinum size ar...
# 10    the cardiomediastinal silhouette is within nor...
# 100   both lungs are clear and expanded. heart and m...
# 1000  there is xxxx increased opacity within the rig...
# 1001  interstitial markings are diffusely prominent ...
#
#                                             mesh_term_s  \
# id
# 1                                                normal
# 10            calcified granuloma/lung/upper lobe/right
# 100                                              normal
# 1000  opacity/lung/upper lobe/right/pulmonary atelec...
# 1001  markings/lung/bilateral/interstitial/diffuse/p...
#
#                                 labels
# id
# 1                             [normal]
# 10               [calcified granuloma]
# 100                           [normal]
# 1000  [pulmonary atelectasis, opacity]
# 1001              [fibrosis, markings]
#
# [5 rows x 26 columns]
# filename          CXR1_1_IM-0001-3001.png  CXR1_1_IM-0001-4001.png  \
# normal                                  1                        1
# abdomen                                 0                        0
# adipose tissue                          0                        0
# airspace disease                        0                        0
# aorta                                   0                        0
# ...                                   ...                      ...
# trachea                                 0                        0
# trachea, carina                         0                        0
# tube, inserted                          0                        0
# tuberculosis                            0                        0
# volume loss                             0                        0
#
# filename          CXR10_IM-0002-1001.png  CXR10_IM-0002-2001.png  \
# normal                                 0                       0
# abdomen                                0                       0
# adipose tissue                         0                       0
# airspace disease                       0                       0
# aorta                                  0                       0
# ...                                  ...                     ...
# trachea                                0                       0
# trachea, carina                        0                       0
# tube, inserted                         0                       0
# tuberculosis                           0                       0
# volume loss                            0                       0
#
# filename          CXR100_IM-0002-1001.png
# normal                                  1
# abdomen                                 0
# adipose tissue                          0
# airspace disease                        0
# aorta                                   0
# ...                                   ...
# trachea                                 0
# trachea, carina                         0
# tube, inserted                          0
# tuberculosis                            0
# volume loss                             0
#
# [117 rows x 5 columns]
# filename  CXR1_1_IM-0001-3001.png  CXR1_1_IM-0001-4001.png  \
# normal                          1                        1
# other                           0                        0
#
# filename  CXR10_IM-0002-1001.png  CXR10_IM-0002-2001.png  \
# normal                         0                       0
# other                          1                       1
#
# filename  CXR100_IM-0002-1001.png
# normal                          1
# other                           0
# saved image-based ds: /opt/uc5/results/sicaai/normal_vs_rest_unbal/img_dataset.pkl, (7284, 2)
# 0) normal
# 1) other
# saved /opt/uc5/results/sicaai/normal_vs_rest_unbal/label2idx.yaml
# lab2idx with 2 labels
# saved /opt/uc5/results/sicaai/normal_vs_rest_unbal/idx2label.yaml
# num words: 1004, including special tokens
# word 0: <pad>
# word 1: <oov>
# word 2: <bos>
# word 3: <eos>
# word 4: no
#     id           image_filename  \
# 0    1  CXR1_1_IM-0001-3001.png
# 1    1  CXR1_1_IM-0001-4001.png
# 2   10   CXR10_IM-0002-1001.png
# 3   10   CXR10_IM-0002-2001.png
# 4  100  CXR100_IM-0002-1001.png
#
#                                                 text  \
# 0  the cardiac silhouette and mediastinum size ar...
# 1  the cardiac silhouette and mediastinum size ar...
# 2  the cardiomediastinal silhouette is within nor...
# 3  the cardiomediastinal silhouette is within nor...
# 4  both lungs are clear and expanded. heart and m...
#
#                                             enc_text
# 0  [[5, 62, 39, 9, 55, 19, 7, 21, 13, 66], [15, 6...
# 1  [[5, 62, 39, 9, 55, 19, 7, 21, 13, 66], [15, 6...
# 2  [[5, 40, 39, 6, 21, 13, 66, 50, 19, 9, 87], [5...
# 3  [[5, 40, 39, 6, 21, 13, 66, 50, 19, 9, 87], [5...
# 4  [[186, 17, 7, 41, 9, 432], [16, 9, 55, 13], [4...
# saved aux dataset for text: /opt/uc5/results/sicaai/normal_vs_rest_unbal/img_text_dataset.pkl
# done with 'normal vs others', unbalanced

# %%
#! BINARY NORMAL VS REST - BALANCED

# indipendent: can be run 
# 2: keep only label with a minimum frequency, select words and encode text
from bs4 import BeautifulSoup
from collections import defaultdict
import numpy as np
import os
import numpy as np
from numpy import count_nonzero as nnz
import pandas as pd
import pickle
from posixpath import join
from tqdm.notebook import tqdm
import yaml
import os
import iuchest.reports as iureports
from utils.vocabulary import Vocabulary

#! IMPORTANT
LABELS = "mesh"  # "mesh" or "auto"
EXP_FLD = "/opt/uc5/results/sicaai/normal_vs_rest_bal"
os.makedirs(EXP_FLD, exist_ok=True)

meta_fld = "/mnt/datasets/uc5/meta/iuchest"
reports_fn = "reports_raw3.pkl" if LABELS == "mesh" else "reports_raw2.pkl"
img_ds_fn = "img_dataset.pkl" if LABELS == "mesh" else "img_dataset_auto.pkl"
in_vocab_fn = "all_vocab_1000.pkl" if LABELS == "mesh" else "all_vocab_auto_1000.pkl"

# * dataset
ds = pd.read_pickle(join(meta_fld, reports_fn))
print(f"read {reports_fn}, shape: {ds.shape}")
display(ds.head())


# !
# ! IMAGES
# !

img_ds = pd.read_pickle(join(meta_fld, img_ds_fn))
# rep_ds = pd.read_pickle(join(meta_fld, "rep_dataset.pkl"))
display(img_ds.head().T)

# normal images
iii = img_ds.normal == True
print(f"num normal: {nnz(iii)}")
print(f"num rest: {nnz(~iii)}")
half = min([nnz(iii), nnz(~iii)])
print(f"balanced, {half} examples per class")

balanced = img_ds.groupby("normal").sample(half)
print(f"balanced, {len(balanced)} examples")

assert nnz(balanced.normal == True) == nnz(balanced.normal ==False)
img_ds = balanced

drop_cols = [c for c in img_ds.columns if c != "normal"]
img_ds = img_ds.drop(columns=drop_cols)
img_ds["other"] = (img_ds.normal != True).astype(int)
display(img_ds.head().T)
ofn = join(EXP_FLD, "img_dataset.pkl")
img_ds.to_pickle( ofn )
print(f"saved image-based ds: {ofn}")

def save_label_indexes(df, out_fld):
    cols = df.columns
    lab2idx = {}
    idx2lab = {}
    for i, c in enumerate(cols):
        lab2idx[c] = i
        idx2lab[i] = c
        print(f"{i}) {c}")
    with open(join(out_fld, "label2idx.yaml"), "w") as fout:
        yaml.safe_dump(lab2idx, fout)
    print(f"saved {join(out_fld, 'label2idx.yaml')}")
    print(f"lab2idx with |labels|: {len(lab2idx)}")
    with open(join(out_fld, "idx2label.yaml"), "w") as fout:
        yaml.safe_dump(idx2lab, fout)
    print(f"saved {join(out_fld, 'idx2label.yaml')}")
#<

save_label_indexes(img_ds, EXP_FLD)

# !
# !  TEXT
# !
with open(join(meta_fld, in_vocab_fn), "rb") as fin:
    vocab = pickle.load(fin)
# copy vocab to EXP_FLD
with open(join(EXP_FLD, "vocab.pkl"), "wb") as fout:
    pickle.dump(vocab, fout)
print(f"num words: {len(vocab.word2idx)}, including special tokens")

for i in range(5):
    print(f"word {i}: {vocab.idx2word[i]}")

rep_ids = []
image_filenames = []
texts = []
for row in ds.reset_index().itertuples():
    for fn in row.image_filename:
        rep_ids.append(row.id)
        image_filenames.append(fn)
        texts.append(row.text)
img_text_ds = pd.DataFrame()
img_text_ds["id"] = rep_ids
img_text_ds["image_filename"] = image_filenames
img_text_ds["text"] = texts
pd.columns = ["id", "image_filename", "text"]

def encode_text(sentences, vocab):
    word_indexes = []
    for sent in sentences.split("."):
        tokens = sent.strip().split()
        enc_sent = []
        for t in tokens:
            enc_sent.append(vocab.word2idx.get(t, Vocabulary.OOV))
        word_indexes.append(enc_sent)

    return word_indexes
enc_text = img_text_ds.text.apply(encode_text, args=(vocab,))
img_text_ds["enc_text"] = enc_text

display(img_text_ds.head())

ofn = join( EXP_FLD, "img_text_dataset.pkl")
img_text_ds.to_pickle(ofn)
print("saved aux dataset for text:", ofn)

print("done with 'normal vs rest', balanced")
# Out:
# read reports_raw3.pkl, shape: (3753, 26)
#                                  comparison  \
# id
# 1                                     none.
# 10                  chest radiographs xxxx.
# 100                                   none.
# 1000  xxxx pa and lateral chest radiographs
# 1001                                   none
#
#                                              indication  \
# id
# 1                                      positive tb test
# 10                      xxxx-year-old male, chest pain.
# 100
# 1000                          xxxx-year-old male, xxxx.
# 1001  dyspnea, subjective fevers, arthritis, immigra...
#
#                                                findings  \
# id
# 1     the cardiac silhouette and mediastinum size ar...
# 10    the cardiomediastinal silhouette is within nor...
# 100   both lungs are clear and expanded. heart and m...
# 1000  there is xxxx increased opacity within the rig...
# 1001  interstitial markings are diffusely prominent ...
#
#                                              impression  \
# id
# 1                                  normal chest x-xxxx.
# 10                    no acute cardiopulmonary process.
# 100                                  no active disease.
# 1000  1. increased opacity in the right upper lobe w...
# 1001  diffuse fibrosis. no visible focal acute disease.
#
#                                         orig_mesh_terms  \
# id
# 1                                              [normal]
# 10          [calcified granuloma/lung/upper lobe/right]
# 100                                            [normal]
# 1000  [opacity/lung/upper lobe/right, pulmonary atel...
# 1001  [markings/lung/bilateral/interstitial/diffuse/...
#
#                                          orig_auto_term  \
# id
# 1                                              [normal]
# 10                                [calcified granuloma]
# 100                                            [normal]
# 1000  [atelectases, mass lesion, opacity, atelectasi...
# 1001   [diffuse fibrosis, fibrosis, pulmonary fibrosis]
#
#                                          image_filename  filename  n_images  \
# id
# 1     [CXR1_1_IM-0001-3001.png, CXR1_1_IM-0001-4001....     1.xml         2
# 10     [CXR10_IM-0002-1001.png, CXR10_IM-0002-2001.png]    10.xml         2
# 100   [CXR100_IM-0002-1001.png, CXR100_IM-0002-2001....   100.xml         2
# 1000  [CXR1000_IM-0003-1001.png, CXR1000_IM-0003-200...  1000.xml         3
# 1001  [CXR1001_IM-0004-1001.png, CXR1001_IM-0004-100...  1001.xml         2
#
#       n_orig_mesh_terms  ...  nsents_findings  \
# id                       ...
# 1                     1  ...                5
# 10                    1  ...                4
# 100                   1  ...                2
# 1000                  3  ...                5
# 1001                  2  ...                3
#
#                                                raw_text len_raw_text  \
# id
# 1     the cardiac silhouette and mediastinum size ar...          231
# 10    the cardiomediastinal silhouette is within nor...          307
# 100   both lungs are clear and expanded. heart and m...           83
# 1000  there is xxxx increased opacity within the rig...          626
# 1001  interstitial markings are diffusely prominent ...          163
#
#       nsents_raw_text                        major_mesh  n_major_mesh  \
# id
# 1                   6                          [normal]             1
# 10                  5             [calcified granuloma]             1
# 100                 3                          [normal]             1
# 1000                8  [pulmonary atelectasis, opacity]             2
# 1001                5              [fibrosis, markings]             2
#
#                                              auto_term  \
# id
# 1                                             [normal]
# 10                               [calcified granuloma]
# 100                                           [normal]
# 1000          [atelectasis, mass lesion, opacity, rib]
# 1001  [diffuse fibrosis, fibrosis, pulmonary fibrosis]
#
#                                                    text  \
# id
# 1     the cardiac silhouette and mediastinum size ar...
# 10    the cardiomediastinal silhouette is within nor...
# 100   both lungs are clear and expanded. heart and m...
# 1000  there is xxxx increased opacity within the rig...
# 1001  interstitial markings are diffusely prominent ...
#
#                                             mesh_term_s  \
# id
# 1                                                normal
# 10            calcified granuloma/lung/upper lobe/right
# 100                                              normal
# 1000  opacity/lung/upper lobe/right/pulmonary atelec...
# 1001  markings/lung/bilateral/interstitial/diffuse/p...
#
#                                 labels
# id
# 1                             [normal]
# 10               [calcified granuloma]
# 100                           [normal]
# 1000  [pulmonary atelectasis, opacity]
# 1001              [fibrosis, markings]
#
# [5 rows x 26 columns]
# filename          CXR1_1_IM-0001-3001.png  CXR1_1_IM-0001-4001.png  \
# normal                                  1                        1
# abdomen                                 0                        0
# adipose tissue                          0                        0
# airspace disease                        0                        0
# aorta                                   0                        0
# ...                                   ...                      ...
# trachea                                 0                        0
# trachea, carina                         0                        0
# tube, inserted                          0                        0
# tuberculosis                            0                        0
# volume loss                             0                        0
#
# filename          CXR10_IM-0002-1001.png  CXR10_IM-0002-2001.png  \
# normal                                 0                       0
# abdomen                                0                       0
# adipose tissue                         0                       0
# airspace disease                       0                       0
# aorta                                  0                       0
# ...                                  ...                     ...
# trachea                                0                       0
# trachea, carina                        0                       0
# tube, inserted                         0                       0
# tuberculosis                           0                       0
# volume loss                            0                       0
#
# filename          CXR100_IM-0002-1001.png
# normal                                  1
# abdomen                                 0
# adipose tissue                          0
# airspace disease                        0
# aorta                                   0
# ...                                   ...
# trachea                                 0
# trachea, carina                         0
# tube, inserted                          0
# tuberculosis                            0
# volume loss                             0
#
# [117 rows x 5 columns]
# num normal: 2696
# num rest: 4588
# balanced, 2696 examples per class
# balanced, 5392 examples
# filename  CXR3013_IM-1391-0001-0001.png  CXR3448_IM-1671-3001.png  \
# normal                                0                         0
# other                                 1                         1
#
# filename  CXR1767_IM-0501-0001-0002.png  CXR2121_IM-0747-2001.png  \
# normal                                0                         0
# other                                 1                         1
#
# filename  CXR1819_IM-0530-1001-0001.png
# normal                                0
# other                                 1
# saved image-based ds: /opt/uc5/results/sicaai/normal_vs_rest_bal/img_dataset.pkl
# 0) normal
# 1) other
# saved /opt/uc5/results/sicaai/normal_vs_rest_bal/label2idx.yaml
# lab2idx with |labels|: 2
# saved /opt/uc5/results/sicaai/normal_vs_rest_bal/idx2label.yaml
# num words: 1004, including special tokens
# word 0: <pad>
# word 1: <oov>
# word 2: <bos>
# word 3: <eos>
# word 4: no
#     id           image_filename  \
# 0    1  CXR1_1_IM-0001-3001.png
# 1    1  CXR1_1_IM-0001-4001.png
# 2   10   CXR10_IM-0002-1001.png
# 3   10   CXR10_IM-0002-2001.png
# 4  100  CXR100_IM-0002-1001.png
#
#                                                 text  \
# 0  the cardiac silhouette and mediastinum size ar...
# 1  the cardiac silhouette and mediastinum size ar...
# 2  the cardiomediastinal silhouette is within nor...
# 3  the cardiomediastinal silhouette is within nor...
# 4  both lungs are clear and expanded. heart and m...
#
#                                             enc_text
# 0  [[5, 62, 39, 9, 55, 19, 7, 21, 13, 66], [15, 6...
# 1  [[5, 62, 39, 9, 55, 19, 7, 21, 13, 66], [15, 6...
# 2  [[5, 40, 39, 6, 21, 13, 66, 50, 19, 9, 87], [5...
# 3  [[5, 40, 39, 6, 21, 13, 66, 50, 19, 9, 87], [5...
# 4  [[186, 17, 7, 41, 9, 432], [16, 9, 55, 13], [4...
# saved aux dataset for text: /opt/uc5/results/sicaai/normal_vs_rest_bal/img_text_dataset.pkl
# done with 'normal vs rest', balanced

# %%
#! BINARY NORMAL VS REST - BALANCED - 1 output unit

# indipendent: can be run 
# 2: keep only label with a minimum frequency, select words and encode text
from bs4 import BeautifulSoup
from collections import defaultdict
import numpy as np
import os
import numpy as np
from numpy import count_nonzero as nnz
import pandas as pd
import pickle
from posixpath import join
from tqdm.notebook import tqdm
import yaml
import os
import iuchest.reports as iureports
from utils.vocabulary import Vocabulary

#! IMPORTANT
LABELS = "mesh"  # "mesh" or "auto"
EXP_FLD = "/mnt/datasets/uc5/EXPS/siccai/normal_vs_rest_bal_1unit"
os.makedirs(EXP_FLD, exist_ok=True)

meta_fld = "/mnt/datasets/uc5/meta/iuchest"
reports_fn = "reports_raw3.pkl" if LABELS == "mesh" else "reports_raw2.pkl"
img_ds_fn = "img_dataset.pkl" if LABELS == "mesh" else "img_dataset_auto.pkl"
in_vocab_fn = "all_vocab_1000.pkl" if LABELS == "mesh" else "all_vocab_auto_1000.pkl"

# * dataset
ds = pd.read_pickle(join(meta_fld, reports_fn))
print(f"read {reports_fn}, shape: {ds.shape}")
display(ds.head())


# !
# ! IMAGES
# !

img_ds = pd.read_pickle(join(meta_fld, img_ds_fn))
# rep_ds = pd.read_pickle(join(meta_fld, "rep_dataset.pkl"))
display(img_ds.head().T)

# normal images
iii = img_ds.normal == True
print(f"num normal: {nnz(iii)}")
print(f"num rest: {nnz(~iii)}")
half = min([nnz(iii), nnz(~iii)])
print(f"balanced, {half} examples per class")

balanced = img_ds.groupby("normal").sample(half)
print(f"balanced, {len(balanced)} examples")

assert nnz(balanced.normal == True) == nnz(balanced.normal ==False)
img_ds = balanced

drop_cols = [c for c in img_ds.columns if c != "normal"]
img_ds = img_ds.drop(columns=drop_cols)
img_ds["other"] = (img_ds.normal != True).astype(int)
display(img_ds.head().T)
ofn = join(EXP_FLD, "img_dataset.pkl")
img_ds.to_pickle( ofn )
print(f"saved image-based ds: {ofn}")

def save_label_indexes(df, out_fld):
    cols = df.columns
    lab2idx = {}
    idx2lab = {}
    for i, c in enumerate(cols):
        lab2idx[c] = i
        idx2lab[i] = c
        print(f"{i}) {c}")
    with open(join(out_fld, "label2idx.yaml"), "w") as fout:
        yaml.safe_dump(lab2idx, fout)
    print(f"saved {join(out_fld, 'label2idx.yaml')}")
    print(f"lab2idx with |labels|: {len(lab2idx)}")
    with open(join(out_fld, "idx2label.yaml"), "w") as fout:
        yaml.safe_dump(idx2lab, fout)
    print(f"saved {join(out_fld, 'idx2label.yaml')}")
#<

save_label_indexes(img_ds, EXP_FLD)

# !
# !  TEXT
# !
with open(join(meta_fld, in_vocab_fn), "rb") as fin:
    vocab = pickle.load(fin)
# copy vocab to EXP_FLD
with open(join(EXP_FLD, "vocab.pkl"), "wb") as fout:
    pickle.dump(vocab, fout)
print(f"num words: {len(vocab.word2idx)}, including special tokens")

for i in range(5):
    print(f"word {i}: {vocab.idx2word[i]}")

rep_ids = []
image_filenames = []
texts = []
for row in ds.reset_index().itertuples():
    for fn in row.image_filename:
        rep_ids.append(row.id)
        image_filenames.append(fn)
        texts.append(row.text)
img_text_ds = pd.DataFrame()
img_text_ds["id"] = rep_ids
img_text_ds["image_filename"] = image_filenames
img_text_ds["text"] = texts
pd.columns = ["id", "image_filename", "text"]

def encode_text(sentences, vocab):
    word_indexes = []
    for sent in sentences.split("."):
        tokens = sent.strip().split()
        enc_sent = []
        for t in tokens:
            enc_sent.append(vocab.word2idx.get(t, Vocabulary.OOV))
        word_indexes.append(enc_sent)

    return word_indexes
enc_text = img_text_ds.text.apply(encode_text, args=(vocab,))
img_text_ds["enc_text"] = enc_text

display(img_text_ds.head())

ofn = join( EXP_FLD, "img_text_dataset.pkl")
img_text_ds.to_pickle(ofn)
print("saved aux dataset for text:", ofn)

print("done with 'normal vs rest', balanced")
# Out:
# read reports_raw3.pkl, shape: (3753, 26)
#                                  comparison  \
# id
# 1                                     none.
# 10                  chest radiographs xxxx.
# 100                                   none.
# 1000  xxxx pa and lateral chest radiographs
# 1001                                   none
#
#                                              indication  \
# id
# 1                                      positive tb test
# 10                      xxxx-year-old male, chest pain.
# 100
# 1000                          xxxx-year-old male, xxxx.
# 1001  dyspnea, subjective fevers, arthritis, immigra...
#
#                                                findings  \
# id
# 1     the cardiac silhouette and mediastinum size ar...
# 10    the cardiomediastinal silhouette is within nor...
# 100   both lungs are clear and expanded. heart and m...
# 1000  there is xxxx increased opacity within the rig...
# 1001  interstitial markings are diffusely prominent ...
#
#                                              impression  \
# id
# 1                                  normal chest x-xxxx.
# 10                    no acute cardiopulmonary process.
# 100                                  no active disease.
# 1000  1. increased opacity in the right upper lobe w...
# 1001  diffuse fibrosis. no visible focal acute disease.
#
#                                         orig_mesh_terms  \
# id
# 1                                              [normal]
# 10          [calcified granuloma/lung/upper lobe/right]
# 100                                            [normal]
# 1000  [opacity/lung/upper lobe/right, pulmonary atel...
# 1001  [markings/lung/bilateral/interstitial/diffuse/...
#
#                                          orig_auto_term  \
# id
# 1                                              [normal]
# 10                                [calcified granuloma]
# 100                                            [normal]
# 1000  [atelectases, mass lesion, opacity, atelectasi...
# 1001   [diffuse fibrosis, fibrosis, pulmonary fibrosis]
#
#                                          image_filename  filename  n_images  \
# id
# 1     [CXR1_1_IM-0001-3001.png, CXR1_1_IM-0001-4001....     1.xml         2
# 10     [CXR10_IM-0002-1001.png, CXR10_IM-0002-2001.png]    10.xml         2
# 100   [CXR100_IM-0002-1001.png, CXR100_IM-0002-2001....   100.xml         2
# 1000  [CXR1000_IM-0003-1001.png, CXR1000_IM-0003-200...  1000.xml         3
# 1001  [CXR1001_IM-0004-1001.png, CXR1001_IM-0004-100...  1001.xml         2
#
#       n_orig_mesh_terms  ...  nsents_findings  \
# id                       ...
# 1                     1  ...                5
# 10                    1  ...                4
# 100                   1  ...                2
# 1000                  3  ...                5
# 1001                  2  ...                3
#
#                                                raw_text len_raw_text  \
# id
# 1     the cardiac silhouette and mediastinum size ar...          231
# 10    the cardiomediastinal silhouette is within nor...          307
# 100   both lungs are clear and expanded. heart and m...           83
# 1000  there is xxxx increased opacity within the rig...          626
# 1001  interstitial markings are diffusely prominent ...          163
#
#       nsents_raw_text                        major_mesh  n_major_mesh  \
# id
# 1                   6                          [normal]             1
# 10                  5             [calcified granuloma]             1
# 100                 3                          [normal]             1
# 1000                8  [pulmonary atelectasis, opacity]             2
# 1001                5              [fibrosis, markings]             2
#
#                                              auto_term  \
# id
# 1                                             [normal]
# 10                               [calcified granuloma]
# 100                                           [normal]
# 1000          [atelectasis, mass lesion, opacity, rib]
# 1001  [diffuse fibrosis, fibrosis, pulmonary fibrosis]
#
#                                                    text  \
# id
# 1     the cardiac silhouette and mediastinum size ar...
# 10    the cardiomediastinal silhouette is within nor...
# 100   both lungs are clear and expanded. heart and m...
# 1000  there is xxxx increased opacity within the rig...
# 1001  interstitial markings are diffusely prominent ...
#
#                                             mesh_term_s  \
# id
# 1                                                normal
# 10            calcified granuloma/lung/upper lobe/right
# 100                                              normal
# 1000  opacity/lung/upper lobe/right/pulmonary atelec...
# 1001  markings/lung/bilateral/interstitial/diffuse/p...
#
#                                 labels
# id
# 1                             [normal]
# 10               [calcified granuloma]
# 100                           [normal]
# 1000  [pulmonary atelectasis, opacity]
# 1001              [fibrosis, markings]
#
# [5 rows x 26 columns]
# filename          CXR1_1_IM-0001-3001.png  CXR1_1_IM-0001-4001.png  \
# normal                                  1                        1
# abdomen                                 0                        0
# adipose tissue                          0                        0
# airspace disease                        0                        0
# aorta                                   0                        0
# ...                                   ...                      ...
# trachea                                 0                        0
# trachea, carina                         0                        0
# tube, inserted                          0                        0
# tuberculosis                            0                        0
# volume loss                             0                        0
#
# filename          CXR10_IM-0002-1001.png  CXR10_IM-0002-2001.png  \
# normal                                 0                       0
# abdomen                                0                       0
# adipose tissue                         0                       0
# airspace disease                       0                       0
# aorta                                  0                       0
# ...                                  ...                     ...
# trachea                                0                       0
# trachea, carina                        0                       0
# tube, inserted                         0                       0
# tuberculosis                           0                       0
# volume loss                            0                       0
#
# filename          CXR100_IM-0002-1001.png
# normal                                  1
# abdomen                                 0
# adipose tissue                          0
# airspace disease                        0
# aorta                                   0
# ...                                   ...
# trachea                                 0
# trachea, carina                         0
# tube, inserted                          0
# tuberculosis                            0
# volume loss                             0
#
# [117 rows x 5 columns]
# num normal: 2696
# num rest: 4588
# balanced, 2696 examples per class
# balanced, 5392 examples
# filename  CXR2695_IM-1166-1001.png  CXR938_IM-2434-1001.png  \
# normal                           0                        0
# other                            1                        1
#
# filename  CXR3581_IM-1761-3001.png  CXR396_IM-2024-2002.png  \
# normal                           0                        0
# other                            1                        1
#
# filename  CXR3417_IM-1652-2001.png
# normal                           0
# other                            1
# saved image-based ds: /mnt/datasets/uc5/EXPS/siccai/normal_vs_rest_bal_1unit/img_dataset.pkl
# 0) normal
# 1) other
# saved /mnt/datasets/uc5/EXPS/siccai/normal_vs_rest_bal_1unit/label2idx.yaml
# lab2idx with |labels|: 2
# saved /mnt/datasets/uc5/EXPS/siccai/normal_vs_rest_bal_1unit/idx2label.yaml
# num words: 1004, including special tokens
# word 0: <pad>
# word 1: <oov>
# word 2: <bos>
# word 3: <eos>
# word 4: no
#     id           image_filename  \
# 0    1  CXR1_1_IM-0001-3001.png
# 1    1  CXR1_1_IM-0001-4001.png
# 2   10   CXR10_IM-0002-1001.png
# 3   10   CXR10_IM-0002-2001.png
# 4  100  CXR100_IM-0002-1001.png
#
#                                                 text  \
# 0  the cardiac silhouette and mediastinum size ar...
# 1  the cardiac silhouette and mediastinum size ar...
# 2  the cardiomediastinal silhouette is within nor...
# 3  the cardiomediastinal silhouette is within nor...
# 4  both lungs are clear and expanded. heart and m...
#
#                                             enc_text
# 0  [[5, 62, 39, 9, 55, 19, 7, 21, 13, 66], [15, 6...
# 1  [[5, 62, 39, 9, 55, 19, 7, 21, 13, 66], [15, 6...
# 2  [[5, 40, 39, 6, 21, 13, 66, 50, 19, 9, 87], [5...
# 3  [[5, 40, 39, 6, 21, 13, 66, 50, 19, 9, 87], [5...
# 4  [[186, 17, 7, 41, 9, 432], [16, 9, 55, 13], [4...
# saved aux dataset for text: /mnt/datasets/uc5/EXPS/siccai/normal_vs_rest_bal_1unit/img_text_dataset.pkl
# done with 'normal vs rest', balanced

# %%
# EXPERIMENT 
# experiment: labels with minium frequency 130, balanced on normal across splits

import numpy as np
import pandas as pd
import pickle
from posixpath import join
import os
from sklearn.model_selection import train_test_split

in_fld = "/opt/uc5/results/experiments_lightning/wp6last_lt"
df = pd.read_pickle(join(in_fld, "img_dataset.pkl"))
print("dataset read, shape: ", df.shape)

display(df.head())
display(df.reset_index().groupby("normal").count())
display( df.reset_index()[["filename", "normal"]].groupby("normal").count() / len(df))

df = pd.read_pickle(join(in_fld, "img_dataset.pkl"))

n_bootstrap = 3
shuffle_seed = 10

train_p = 0.7
valid_p = 0.1
test_p = 1 - train_p - valid_p
print(f"expected |train| = {train_p * len(df)}")
print(f"expected |valid| = {valid_p * len(df)}")
print(f"expected |test| = {test_p * len(df)}")


filenames = np.array(df.index.values)
labels = np.array(df.normal)
df_splits = pd.DataFrame(columns=["filename", "split"])
#df_splits["filename"] = None
#df_splits["split"] = None

for i in range(n_bootstrap):
    x_train, x_test, y_train, y_test = train_test_split(
        filenames, labels, stratify=labels, 
        train_size=train_p, test_size=test_p, 
        random_state=shuffle_seed + i, shuffle=True)
    x_valid = np.array([x for x in filenames if ((x not in x_train) and (x not in x_test))])
    y_valid = np.array([df.loc[x, "normal"] for x in x_valid])
    assert len(x_train) + len(x_valid) + len(x_test) == len(filenames)
    
    print(f"bootstrap {i}/{n_bootstrap}")
    print(f"\ttrain: {len(x_train)}, normal {sum(y_train)/len(y_train)}")
    print(f"\tvalid: {len(x_valid)}, normal {sum(y_valid)/len(y_valid)}")
    print(f"\ttest: {len(x_test)}, normal {sum(y_test)/len(y_test)}")
    dfs = [pd.DataFrame({"filename": x_train, "split": "train"}), 
        pd.DataFrame({"filename": x_valid, "split": "valid"}),
        pd.DataFrame({"filename": x_test, "split": "test"})]
    out_df = pd.concat(dfs, axis=0)
    display(out_df.head())
    print(out_df.shape)
    out_df.to_pickle(join(in_fld, f"split_{i}.pkl"))
    print(f"saved to {join(in_fld, f'split_{i}.pkl')}")
# Out:
# dataset read, shape:  (7470, 21)
#                          normal  atelectasis  calcified granuloma  \
# filename
# CXR1_1_IM-0001-3001.png       1            0                    0
# CXR1_1_IM-0001-4001.png       1            0                    0
# CXR10_IM-0002-1001.png        0            0                    1
# CXR10_IM-0002-2001.png        0            0                    1
# CXR100_IM-0002-1001.png       1            0                    0
#
#                          cardiomegaly  deformity  degenerative change  \
# filename
# CXR1_1_IM-0001-3001.png             0          0                    0
# CXR1_1_IM-0001-4001.png             0          0                    0
# CXR10_IM-0002-1001.png              0          0                    0
# CXR10_IM-0002-2001.png              0          0                    0
# CXR100_IM-0002-1001.png             0          0                    0
#
#                          diaphragm  emphysema  granuloma  \
# filename
# CXR1_1_IM-0001-3001.png          0          0          0
# CXR1_1_IM-0001-4001.png          0          0          0
# CXR10_IM-0002-1001.png           0          0          0
# CXR10_IM-0002-2001.png           0          0          0
# CXR100_IM-0002-1001.png          0          0          0
#
#                          granulomatous disease  ...  nodule  opacity  \
# filename                                        ...
# CXR1_1_IM-0001-3001.png                      0  ...       0        0
# CXR1_1_IM-0001-4001.png                      0  ...       0        0
# CXR10_IM-0002-1001.png                       0  ...       0        0
# CXR10_IM-0002-2001.png                       0  ...       0        0
# CXR100_IM-0002-1001.png                      0  ...       0        0
#
#                          osteophyte  pleural effusion  pneumonia  \
# filename
# CXR1_1_IM-0001-3001.png           0                 0          0
# CXR1_1_IM-0001-4001.png           0                 0          0
# CXR10_IM-0002-1001.png            0                 0          0
# CXR10_IM-0002-2001.png            0                 0          0
# CXR100_IM-0002-1001.png           0                 0          0
#
#                          pulmonary emphysema  scarring  sternotomy  \
# filename
# CXR1_1_IM-0001-3001.png                    0         0           0
# CXR1_1_IM-0001-4001.png                    0         0           0
# CXR10_IM-0002-1001.png                     0         0           0
# CXR10_IM-0002-2001.png                     0         0           0
# CXR100_IM-0002-1001.png                    0         0           0
#
#                          thoracic aorta  misc
# filename
# CXR1_1_IM-0001-3001.png               0     0
# CXR1_1_IM-0001-4001.png               0     0
# CXR10_IM-0002-1001.png                0     0
# CXR10_IM-0002-2001.png                0     0
# CXR100_IM-0002-1001.png               0     0
#
# [5 rows x 21 columns]
#         filename  atelectasis  calcified granuloma  cardiomegaly  deformity  \
# normal
# 0           4062         4062                 4062          4062       4062
# 1           3408         3408                 3408          3408       3408
#
#         degenerative change  diaphragm  emphysema  granuloma  \
# normal
# 0                      4062       4062       4062       4062
# 1                      3408       3408       3408       3408
#
#         granulomatous disease  ...  nodule  opacity  osteophyte  \
# normal                         ...
# 0                        4062  ...    4062     4062        4062
# 1                        3408  ...    3408     3408        3408
#
#         pleural effusion  pneumonia  pulmonary emphysema  scarring  \
# normal
# 0                   4062       4062                 4062      4062
# 1                   3408       3408                 3408      3408
#
#         sternotomy  thoracic aorta  misc
# normal
# 0             4062            4062  4062
# 1             3408            3408  3408
#
# [2 rows x 21 columns]
#         filename
# normal
# 0       0.543775
# 1       0.456225
# expected |train| = 5229.0
# expected |valid| = 747.0
# expected |test| = 1494.0000000000002
# bootstrap 0/3
# 	train: 5229, normal 0.4563013960604322
# 	valid: 746, normal 0.45576407506702415
# 	test: 1495, normal 0.4561872909698997
#                    filename  split
# 0  CXR1575_IM-0374-2001.png  train
# 1  CXR1448_IM-0289-2001.png  train
# 2  CXR3729_IM-1864-1002.png  train
# 3  CXR1971_IM-0633-1001.png  train
# 4  CXR2944_IM-1344-2002.png  train
# (7470, 2)
# saved to /opt/uc5/results/experiments_lightning/wp6last_lt/split_0.pkl
# bootstrap 1/3
# 	train: 5229, normal 0.4563013960604322
# 	valid: 746, normal 0.45576407506702415
# 	test: 1495, normal 0.4561872909698997
#                        filename  split
# 0        CXR59_IM-2184-2001.png  train
# 1  CXR657_IM-2233-0001-0001.png  train
# 2       CXR207_IM-0703-2001.png  train
# 3      CXR1677_IM-0446-1001.png  train
# 4      CXR1403_IM-0258-1001.png  train
# (7470, 2)
# saved to /opt/uc5/results/experiments_lightning/wp6last_lt/split_1.pkl
# bootstrap 2/3
# 	train: 5229, normal 0.4563013960604322
# 	valid: 746, normal 0.45576407506702415
# 	test: 1495, normal 0.4561872909698997
#                    filename  split
# 0   CXR881_IM-2396-2001.png  train
# 1  CXR3078_IM-1438-2001.png  train
# 2  CXR3628_IM-1796-1001.png  train
# 3  CXR3551_IM-1740-1001.png  train
# 4   CXR842_IM-2366-2001.png  train
# (7470, 2)
# saved to /opt/uc5/results/experiments_lightning/wp6last_lt/split_2.pkl

# %%
import pandas as pd
import pickle
from posixpath import join

fn = "/mnt/datasets/uc5/UC5_pipeline_forked/experiments_lightning/wp6last_lt/split_0.pkl"
split = pd.read_pickle(fn)
display(split.head())
ds = pd.read_pickle("/mnt/datasets/uc5/UC5_pipeline_forked/experiments_lightning/wp6last_lt/img_dataset.pkl")
display(ds.head())
train_ids = split.loc[split.split == "train", "filename"].values
print(split[split.split == "train"].filename)
# print(train_ids)

train = ds.loc[train_ids]

display(train.head())
# Out:
#                    filename  split
# 0  CXR1575_IM-0374-2001.png  train
# 1  CXR1448_IM-0289-2001.png  train
# 2  CXR3729_IM-1864-1002.png  train
# 3  CXR1971_IM-0633-1001.png  train
# 4  CXR2944_IM-1344-2002.png  train
#                          normal  atelectasis  calcified granuloma  \
# filename
# CXR1_1_IM-0001-3001.png       1            0                    0
# CXR1_1_IM-0001-4001.png       1            0                    0
# CXR10_IM-0002-1001.png        0            0                    1
# CXR10_IM-0002-2001.png        0            0                    1
# CXR100_IM-0002-1001.png       1            0                    0
#
#                          cardiomegaly  deformity  degenerative change  \
# filename
# CXR1_1_IM-0001-3001.png             0          0                    0
# CXR1_1_IM-0001-4001.png             0          0                    0
# CXR10_IM-0002-1001.png              0          0                    0
# CXR10_IM-0002-2001.png              0          0                    0
# CXR100_IM-0002-1001.png             0          0                    0
#
#                          diaphragm  emphysema  granuloma  \
# filename
# CXR1_1_IM-0001-3001.png          0          0          0
# CXR1_1_IM-0001-4001.png          0          0          0
# CXR10_IM-0002-1001.png           0          0          0
# CXR10_IM-0002-2001.png           0          0          0
# CXR100_IM-0002-1001.png          0          0          0
#
#                          granulomatous disease  ...  nodule  opacity  \
# filename                                        ...
# CXR1_1_IM-0001-3001.png                      0  ...       0        0
# CXR1_1_IM-0001-4001.png                      0  ...       0        0
# CXR10_IM-0002-1001.png                       0  ...       0        0
# CXR10_IM-0002-2001.png                       0  ...       0        0
# CXR100_IM-0002-1001.png                      0  ...       0        0
#
#                          osteophyte  pleural effusion  pneumonia  \
# filename
# CXR1_1_IM-0001-3001.png           0                 0          0
# CXR1_1_IM-0001-4001.png           0                 0          0
# CXR10_IM-0002-1001.png            0                 0          0
# CXR10_IM-0002-2001.png            0                 0          0
# CXR100_IM-0002-1001.png           0                 0          0
#
#                          pulmonary emphysema  scarring  sternotomy  \
# filename
# CXR1_1_IM-0001-3001.png                    0         0           0
# CXR1_1_IM-0001-4001.png                    0         0           0
# CXR10_IM-0002-1001.png                     0         0           0
# CXR10_IM-0002-2001.png                     0         0           0
# CXR100_IM-0002-1001.png                    0         0           0
#
#                          thoracic aorta  misc
# filename
# CXR1_1_IM-0001-3001.png               0     0
# CXR1_1_IM-0001-4001.png               0     0
# CXR10_IM-0002-1001.png                0     0
# CXR10_IM-0002-2001.png                0     0
# CXR100_IM-0002-1001.png               0     0
#
# [5 rows x 21 columns]
# 0            CXR1575_IM-0374-2001.png
# 1            CXR1448_IM-0289-2001.png
# 2            CXR3729_IM-1864-1002.png
# 3            CXR1971_IM-0633-1001.png
# 4            CXR2944_IM-1344-2002.png
#                     ...
# 5224    CXR3892_IM-1974-0001-0002.png
# 5225         CXR3775_IM-1893-1001.png
# 5226         CXR2884_IM-1286-2001.png
# 5227          CXR780_IM-2323-2001.png
# 5228          CXR227_IM-0859-4004.png
# Name: filename, Length: 5229, dtype: object
#                           normal  atelectasis  calcified granuloma  \
# filename
# CXR1575_IM-0374-2001.png       0            0                    0
# CXR1448_IM-0289-2001.png       1            0                    0
# CXR3729_IM-1864-1002.png       1            0                    0
# CXR1971_IM-0633-1001.png       1            0                    0
# CXR2944_IM-1344-2002.png       0            0                    1
#
#                           cardiomegaly  deformity  degenerative change  \
# filename
# CXR1575_IM-0374-2001.png             0          0                    0
# CXR1448_IM-0289-2001.png             0          0                    0
# CXR3729_IM-1864-1002.png             0          0                    0
# CXR1971_IM-0633-1001.png             0          0                    0
# CXR2944_IM-1344-2002.png             0          0                    0
#
#                           diaphragm  emphysema  granuloma  \
# filename
# CXR1575_IM-0374-2001.png          0          0          1
# CXR1448_IM-0289-2001.png          0          0          0
# CXR3729_IM-1864-1002.png          0          0          0
# CXR1971_IM-0633-1001.png          0          0          0
# CXR2944_IM-1344-2002.png          0          0          1
#
#                           granulomatous disease  ...  nodule  opacity  \
# filename                                         ...
# CXR1575_IM-0374-2001.png                      0  ...       0        0
# CXR1448_IM-0289-2001.png                      0  ...       0        0
# CXR3729_IM-1864-1002.png                      0  ...       0        0
# CXR1971_IM-0633-1001.png                      0  ...       0        0
# CXR2944_IM-1344-2002.png                      0  ...       0        1
#
#                           osteophyte  pleural effusion  pneumonia  \
# filename
# CXR1575_IM-0374-2001.png           0                 0          0
# CXR1448_IM-0289-2001.png           0                 0          0
# CXR3729_IM-1864-1002.png           0                 0          0
# CXR1971_IM-0633-1001.png           0                 0          0
# CXR2944_IM-1344-2002.png           0                 0          0
#
#                           pulmonary emphysema  scarring  sternotomy  \
# filename
# CXR1575_IM-0374-2001.png                    0         0           0
# CXR1448_IM-0289-2001.png                    0         0           0
# CXR3729_IM-1864-1002.png                    0         0           0
# CXR1971_IM-0633-1001.png                    0         0           0
# CXR2944_IM-1344-2002.png                    0         0           0
#
#                           thoracic aorta  misc
# filename
# CXR1575_IM-0374-2001.png               0     1
# CXR1448_IM-0289-2001.png               0     0
# CXR3729_IM-1864-1002.png               0     0
# CXR1971_IM-0633-1001.png               0     0
# CXR2944_IM-1344-2002.png               0     1
#
# [5 rows x 21 columns]
