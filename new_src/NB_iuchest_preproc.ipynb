# %%
from bs4 import BeautifulSoup
from collections import defaultdict

import numpy as np
import os
import pandas as pd
from posixpath import join
from tqdm.notebook import tqdm


import iuchest.reports as iureports

# %%
base_path = "/mnt/datasets/uc5/std-dataset"  # subfolders image, text
out_fld = "/mnt/datasets/uc5/meta/iuchest"

# %%
def filename_from_path(path, keep_extension=True):
    base = os.path.basename(path)
    if keep_extension:
        return base

    pre, _ = os.path.splitext(base)
    return pre
    
def parse_id(soup):
    keys = ['pmcid', 'iuxrid', 'uid']
    d = defaultdict(None)
    selected_id = None
    for k in keys:
        if soup(k):
            # since: soup(k) returns:
            #        [<pmcid id="3315"></pmcid>]
            # 1) soup(k)[0] takes the first element of the result set: <pmcid id="3315"></pmcid>
            # 2) soup(k)[0].get('id') reads the value of the property 'id': 3315
            v = soup(k)[0].get('id')
            d[k] = v
            selected_id = v
            if k == keys[0] or k == keys[1]:
                # prefer pmcid or uixrid, that are simple integers. uid starts with 'CXR'
                # example: pmcid=3700, uixrid=3700, uid=CXR3700
                # break as soon as you find one of the first two keys
                break
    assert selected_id  # is not None and is not empty, fail otherwise
    return {"id": selected_id}

def parse_medical_texts(soup):
    a = soup.abstract
    ats = a.find_all('abstracttext')
    res = {}
    valid_labels = ["impression", "indication", "findings", "comparison"]
    for at in ats:
        label = at.get('label').lower()
        if label in valid_labels:
            res[label] = at.text
    return res

def parse_mesh_terms(soup):
    mt = soup.mesh
    res = {}
    if mt:
        mt_major = mt.find_all('major')
        mt_minor = mt.find_all('minor')
        if mt_major:
            res["major_mesh"] = [major.text for major in mt_major if major.text]
        if mt_minor:
            res["minor_mesh"] = [minor.text for minor in mt_minor if minor.text]
    return res

def parse_automatic_terms(soup):
    mt = soup.mesh
    res = {}
    terms = []
    if mt:
        mt_auto = mt.find_all('automatic')
        if mt_auto:
            terms = [term.text for term in mt_auto if term.text]
    res["auto_term"] = terms
    return res

def parse_images(soup):
    res = []
    imgs = soup.find_all('parentimage')
    for img in imgs:
        d = {}
        if img.caption:
            d["image_caption"] = img.caption.text
        if img.url:
            p = img.url.text  # this is an absolute path
            fn = filename_from_path(p, keep_extension=False)
            # dataset contains png images, but paths in reports point to (old) jpeg versions
            d["image_filename"] = fn + '.png'
        else:
            print('FATAL: NO img.url')
            exit()
        res.append(d)
    return res  # {"images": res}


def parse_single_report(filepath, verbose=False):
    with open(filepath, "r", encoding="utf-8") as fin:
        xml = fin.read()
    soup = BeautifulSoup(xml, "lxml")
    parsed = {}
    parsed.update(parse_id(soup))
    parsed.update(parse_medical_texts(soup))
    parsed.update(parse_mesh_terms(soup))
    parsed.update(parse_automatic_terms(soup))
    images = parse_images(soup)
    parsed["image_filename"] = [d["image_filename"] for d in images]
    parsed["filename"] = os.path.basename(filepath)
    return parsed

def parse_reports(txt_fld, ext="xml", verbose=False, dev=False):
    reports = []
    for i, fn in enumerate(tqdm( [ join(txt_fld, fn) for fn in os.listdir(txt_fld) if (ext is None or fn.endswith(ext)) ])):
        reports.append(parse_single_report(fn))
    return reports


reports_fld = join(base_path, "text")
images_fld = join(base_path, "image")

reports = parse_reports(reports_fld)
reports = pd.DataFrame.from_records(reports).set_index("id")
reports.sort_index(inplace=True)

reports["n_images"] = reports["image_filename"].apply(lambda l: len(l))
reports["n_mesh_terms"] = reports["major_mesh"].apply(lambda l: len(l))
reports["n_auto_terms"] = reports["auto_term"].apply(lambda l: len(l))

reports.to_csv( join(out_fld, "reports_raw.tsv"), sep="\t")

# %% [markdown]
# READ RAW REPORTS AND CLEAN IT

# %%
raw_reports = pd.read_csv( (join(out_fld, "reports_raw.tsv")), sep="\t", na_filter=False)
display(raw_reports.T)
# Out:
#                                                              0     \
# id                                                              1
# comparison                                                  None.
# indication                                       Positive TB test
# findings        The cardiac silhouette and mediastinum size ar...
# impression                                   Normal chest x-XXXX.
# major_mesh                                             ['normal']
# auto_term                                                      []
# image_filename  ['CXR1_1_IM-0001-3001.png', 'CXR1_1_IM-0001-40...
# filename                                                    1.xml
# n_images                                                        2
# n_mesh_terms                                                    1
# n_auto_terms                                                    0
#
#                                                              1     \
# id                                                             10
# comparison                                Chest radiographs XXXX.
# indication                        XXXX-year-old male, chest pain.
# findings        The cardiomediastinal silhouette is within nor...
# impression                      No acute cardiopulmonary process.
# major_mesh          ['Calcified Granuloma/lung/upper lobe/right']
# auto_term                                 ['calcified granuloma']
# image_filename  ['CXR10_IM-0002-1001.png', 'CXR10_IM-0002-2001...
# filename                                                   10.xml
# n_images                                                        2
# n_mesh_terms                                                    1
# n_auto_terms                                                    1
#
#                                                              2     \
# id                                                            100
# comparison                                                  None.
# indication
# findings        Both lungs are clear and expanded. Heart and m...
# impression                                     No active disease.
# major_mesh                                             ['normal']
# auto_term                                                      []
# image_filename  ['CXR100_IM-0002-1001.png', 'CXR100_IM-0002-20...
# filename                                                  100.xml
# n_images                                                        2
# n_mesh_terms                                                    1
# n_auto_terms                                                    0
#
#                                                              3     \
# id                                                           1000
# comparison                  XXXX PA and lateral chest radiographs
# indication                              XXXX-year-old male, XXXX.
# findings        There is XXXX increased opacity within the rig...
# impression      1. Increased opacity in the right upper lobe w...
# major_mesh      ['Opacity/lung/upper lobe/right', 'Pulmonary A...
# auto_term       ['atelectases', 'mass lesion', 'opacity', 'Ate...
# image_filename  ['CXR1000_IM-0003-1001.png', 'CXR1000_IM-0003-...
# filename                                                 1000.xml
# n_images                                                        3
# n_mesh_terms                                                    3
# n_auto_terms                                                    5
#
#                                                              4     \
# id                                                           1001
# comparison                                                   None
# indication      dyspnea, subjective fevers, arthritis, immigra...
# findings        Interstitial markings are diffusely prominent ...
# impression      Diffuse fibrosis. No visible focal acute disease.
# major_mesh      ['Markings/lung/bilateral/interstitial/diffuse...
# auto_term       ['diffuse fibrosis', 'Fibrosis', 'Pulmonary Fi...
# image_filename  ['CXR1001_IM-0004-1001.png', 'CXR1001_IM-0004-...
# filename                                                 1001.xml
# n_images                                                        2
# n_mesh_terms                                                    2
# n_auto_terms                                                    3
#
#                                                              5     \
# id                                                           1002
# comparison
# indication                                  History of chest pain
# findings
# impression      Status post left mastectomy. Heart size normal...
# major_mesh                                    ['Mastectomy/left']
# auto_term               ['mastectomies', 'Mastectomy', 'surgery']
# image_filename  ['CXR1002_IM-0004-1001.png', 'CXR1002_IM-0004-...
# filename                                                 1002.xml
# n_images                                                        2
# n_mesh_terms                                                    1
# n_auto_terms                                                    3
#
#                                                              6     \
# id                                                           1003
# comparison
# indication                                      Acute bronchitis.
# findings        Heart size and pulmonary vascularity appear wi...
# impression      1. Retrocardiac soft tissue density. The appea...
# major_mesh      ['Density/retrocardiac', 'Calcinosis/blood ves...
# auto_term       ['atelectases', 'calcified granuloma', 'hiatal...
# image_filename                       ['CXR1003_IM-0005-2002.png']
# filename                                                 1003.xml
# n_images                                                        1
# n_mesh_terms                                                    5
# n_auto_terms                                                    8
#
#                                                              7     \
# id                                                           1004
# comparison                     Two views of the chest dated XXXX.
# indication      XXXX-year-old with XXXX for one month. History...
# findings        The heart, pulmonary XXXX and mediastinum are ...
# impression                      No acute cardiopulmonary disease.
# major_mesh      ['Aorta/tortuous', 'Shoulder/bilateral/degener...
# auto_term                                 ['degenerative change']
# image_filename  ['CXR1004_IM-0005-1001.png', 'CXR1004_IM-0005-...
# filename                                                 1004.xml
# n_images                                                        2
# n_mesh_terms                                                    4
# n_auto_terms                                                    1
#
#                                                              8     \
# id                                                           1005
# comparison                                                  None.
# indication                                              Pruritic.
# findings        Cardiac and mediastinal contours are within no...
# impression                                     No acute findings.
# major_mesh                                             ['normal']
# auto_term                                                      []
# image_filename  ['CXR1005_IM-0006-1001.png', 'CXR1005_IM-0006-...
# filename                                                 1005.xml
# n_images                                                        2
# n_mesh_terms                                                    1
# n_auto_terms                                                    0
#
#                                                              9     ...  \
# id                                                           1006  ...
# comparison                                                         ...
# indication                              ,786.05 XXXX XXXX to XXXX  ...
# findings        The lungs appear clear. There are no focal air...  ...
# impression                      No acute cardiopulmonary disease.  ...
# major_mesh                                             ['normal']  ...
# auto_term                                                      []  ...
# image_filename  ['CXR1006_IM-0007-1001.png', 'CXR1006_IM-0007-...  ...
# filename                                                 1006.xml  ...
# n_images                                                        2  ...
# n_mesh_terms                                                    1  ...
# n_auto_terms                                                    0  ...
#
#                                                              3945  \
# id                                                            990
# comparison                              Two-view chest from XXXX.
# indication         XXXX-year-old male with altered mental status.
# findings        Heart size within normal limits. No focal airs...
# impression                     No acute cardiopulmonary findings.
# major_mesh                                             ['normal']
# auto_term                                                      []
# image_filename  ['CXR990_IM-2476-1001.png', 'CXR990_IM-2476-20...
# filename                                                  990.xml
# n_images                                                        2
# n_mesh_terms                                                    1
# n_auto_terms                                                    0
#
#                                                              3946  \
# id                                                            991
# comparison                            Rib radiographs dated XXXX.
# indication      XXXX-year-old with pneumonia. Shortness of bre...
# findings        The heart size is upper limits of normal. The ...
# impression      Minimal perihilar opacity which could indicate...
# major_mesh                    ['Opacity/lung/hilum/streaky/mild']
# auto_term                      ['atypical pneumonias', 'opacity']
# image_filename  ['CXR991_IM-2476-1001.png', 'CXR991_IM-2476-20...
# filename                                                  991.xml
# n_images                                                        2
# n_mesh_terms                                                    1
# n_auto_terms                                                    2
#
#                                                              3947  \
# id                                                            992
# comparison                                                   None
# indication                                               MELANOMA
# findings        There are bilateral pulmonary nodules whose ap...
# impression      1. Bilateral pulmonary nodules suggesting pulm...
# major_mesh      ['Nodule/lung/bilateral/multiple', 'Surgical I...
# auto_term       ['metastatic disease', 'nodule', 'opacity', 'p...
# image_filename  ['CXR992_IM-2477-0001-0001.png', 'CXR992_IM-24...
# filename                                                  992.xml
# n_images                                                        2
# n_mesh_terms                                                    3
# n_auto_terms                                                    9
#
#                                                              3948  \
# id                                                            993
# comparison                                                  None.
# indication                                  possible tuberculosis
# findings        Heart size normal. Lungs are clear. XXXX are n...
# impression               Normal chest No evidence of tuberculosis
# major_mesh                                             ['normal']
# auto_term                                                      []
# image_filename  ['CXR993_IM-2478-1001.png', 'CXR993_IM-2478-10...
# filename                                                  993.xml
# n_images                                                        2
# n_mesh_terms                                                    1
# n_auto_terms                                                    0
#
#                                                              3949  \
# id                                                            994
# comparison                                                   XXXX
# indication                                      XXXX for one XXXX
# findings        The lungs are clear. The cardiomediastinal sil...
# impression                                       Negative chest .
# major_mesh                                             ['normal']
# auto_term                                                      []
# image_filename  ['CXR994_IM-2478-1001.png', 'CXR994_IM-2478-20...
# filename                                                  994.xml
# n_images                                                        2
# n_mesh_terms                                                    1
# n_auto_terms                                                    0
#
#                                                              3950  \
# id                                                            995
# comparison                                            XXXX, XXXX.
# indication                                   SP CABG SOB NO RALES
# findings        Sternotomy sutures and bypass grafts have been...
# impression            Post operative chest with no acute disease.
# major_mesh                                    ['Sutures/sternum']
# auto_term       ['bypass grafts', 'sternotomy', 'Coronary Arte...
# image_filename  ['CXR995_IM-2478-1001.png', 'CXR995_IM-2478-10...
# filename                                                  995.xml
# n_images                                                        2
# n_mesh_terms                                                    1
# n_auto_terms                                                    5
#
#                                                              3951  \
# id                                                            996
# comparison
# indication                                            chest pain.
# findings
# impression      Heart size is normal and lungs are clear. No p...
# major_mesh                                             ['normal']
# auto_term                                                      []
# image_filename  ['CXR996_IM-2479-1001.png', 'CXR996_IM-2479-20...
# filename                                                  996.xml
# n_images                                                        2
# n_mesh_terms                                                    1
# n_auto_terms                                                    0
#
#                                                              3952  \
# id                                                            997
# comparison                 Chest x-XXXX dated XXXX at XXXX hours.
# indication               XXXX-year-old female, transplant workup.
# findings        Calcified mediastinal XXXX. No focal areas of ...
# impression                No acute cardiopulmonary abnormality. .
# major_mesh      ['Calcinosis/mediastinum', 'Thoracic Vertebrae...
# auto_term                                 ['degenerative change']
# image_filename  ['CXR997_IM-2479-1001.png', 'CXR997_IM-2479-20...
# filename                                                  997.xml
# n_images                                                        2
# n_mesh_terms                                                    2
# n_auto_terms                                                    1
#
#                                                              3953  \
# id                                                            998
# comparison                                                  None.
# indication                          XXXX-year-old XXXX with pain.
# findings        Cardiomediastinal silhouette demonstrates norm...
# impression                  No acute cardiopulmonary abnormality.
# major_mesh      ['Atherosclerosis/aorta, thoracic', 'Aorta, Th...
# auto_term       ['atheroscleroses', 'degenerative disc disease...
# image_filename  ['CXR998_IM-2479-1001.png', 'CXR998_IM-2479-20...
# filename                                                  998.xml
# n_images                                                        2
# n_mesh_terms                                                    3
# n_auto_terms                                                    5
#
#                                                              3954
# id                                                            999
# comparison                                                   None
# indication                                             Chest pain
# findings        Lungs are clear bilaterally. There is no focal...
# impression                  No acute cardiopulmonary abnormality.
# major_mesh                                             ['normal']
# auto_term                                                      []
# image_filename  ['CXR999_IM-2480-1001.png', 'CXR999_IM-2480-20...
# filename                                                  999.xml
# n_images                                                        3
# n_mesh_terms                                                    1
# n_auto_terms                                                    0
#
# [12 rows x 3955 columns]

# %%
# all to lowercase:
columns = ["comparison", "indication", "findings", "impression", "major_mesh", "auto_term"]

def to_lowercase(s):
    if isinstance(s, str):
        return s.lower()
    elif isinstance(s, list):
        return [to_lowercase(x) for x in s]
    else:
        print("errors, unexpected type:", type(s))

for c in columns:
    raw_reports[c] = raw_reports[c].apply(to_lowercase)

# remove empty images
raw_reports = raw_reports[raw_reports["n_images"] > 0]

# split text in sentences


def join_findings_impression(findings, impression):
    from nltk import sent_tokenize
    fi = []
    im = []
    if (findings is not None) and (len(findings) > 0):
        sents = sent_tokenize(findings)

    

raw_reports["text"] = pd.Seris([join_findings_impression(f, v) for ])

# %%
# apply correction from excel file provided by the dataset authors

# %%
for r in reports.itertuples():
