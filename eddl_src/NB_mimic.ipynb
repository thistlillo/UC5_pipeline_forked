# %% [markdown]
# ### MIMIC-CXR (dcm & jpg)
# <font color="yellow">0. IMPORT AND DATA</font>

# %%
import pandas as pd

import numpy as np
from numpy import count_nonzero as nnz
import os
from posixpath import join
from IPython.display import display
from IPython.display import Image

# ! random seed

jpg_fld = "/mnt/datasets/mimic-cxr/mimic-cxr-jpg/physionet.org/files/mimic-cxr-jpg/2.0.0"
dcm_fld = "/mnt/datasets/mimic-cxr/mimic-cxr-dcm/physionet.org/files/mimic-cxr/2.0.0"

# all the following files are split between the DCM and JPG versions

filename_records = join(dcm_fld, "cxr-record-list.csv") # path to dmc images (jpg are basically mirrored)
filename_reports = join(dcm_fld, "cxr-study-list.csv")  # text reports
filename_metadata = join(jpg_fld, "mimic-cxr-2.0.0-metadata.csv") 
filename_chexpert = join(jpg_fld, "mimic-cxr-2.0.0-chexpert.csv") #labels
filename_negbio = join(jpg_fld, "mimic-cxr-2.0.0-negbio.csv") #labels
filename_split = join(jpg_fld, "mimic-cxr-2.0.0-split.csv") #suggested training-test split
filename_sections = join(dcm_fld, "mimic-cxr-sections", "mimic_cxr_sectioned.csv")
# preprocessing code from: https://github.com/MIT-LCP/mimic-cxr/tree/master/notebooks
df = pd.read_csv(filename_records, header=0, sep=',')

n = df.shape[0]
print(f'{n} DICOMs in MIMIC-CXR v2.0.0.')

n = df['study_id'].nunique()
print(f'  {n} studies.')

n = df['subject_id'].nunique()
print(f'  {n} subjects.')

dicoms = set(df['dicom_id'].tolist())

df_split = pd.read_csv(filename_split)
df_metadata = pd.read_csv(filename_metadata)

display(df_metadata.T)

cx = pd.read_csv(filename_chexpert)
nb = pd.read_csv(filename_negbio)

print("chexpert")
display(cx.T)
print("negbio")
display(nb.T)

cols = [col for col in cx.columns if col not in nb.columns]
cols = cols + [col for col in nb.columns if col not in cx.columns]

assert len(cols) == 0
# Out:
# 377110 DICOMs in MIMIC-CXR v2.0.0.
#   227835 studies.
#   65379 subjects.
#                                                                                   0       \
# dicom_id                                    02aa804e-bde0afdd-112c0b34-7bc16630-4e384014
# subject_id                                                                      10000032
# study_id                                                                        50414267
# PerformedProcedureStepDescription                                     CHEST (PA AND LAT)
# ViewPosition                                                                          PA
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21800506
# StudyTime                                                                     213014.531
# ProcedureCodeSequence_CodeMeaning                                     CHEST (PA AND LAT)
# ViewCodeSequence_CodeMeaning                                            postero-anterior
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
#
#                                                                                   1       \
# dicom_id                                    174413ec-4ec4c1f7-34ea26b7-c5f994f8-79ef1962
# subject_id                                                                      10000032
# study_id                                                                        50414267
# PerformedProcedureStepDescription                                     CHEST (PA AND LAT)
# ViewPosition                                                                     LATERAL
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21800506
# StudyTime                                                                     213014.531
# ProcedureCodeSequence_CodeMeaning                                     CHEST (PA AND LAT)
# ViewCodeSequence_CodeMeaning                                                     lateral
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
#
#                                                                                   2       \
# dicom_id                                    2a2277a9-b0ded155-c0de8eb9-c124d10e-82c5caab
# subject_id                                                                      10000032
# study_id                                                                        53189527
# PerformedProcedureStepDescription                                     CHEST (PA AND LAT)
# ViewPosition                                                                          PA
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21800626
# StudyTime                                                                     165500.312
# ProcedureCodeSequence_CodeMeaning                                     CHEST (PA AND LAT)
# ViewCodeSequence_CodeMeaning                                            postero-anterior
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
#
#                                                                                   3       \
# dicom_id                                    e084de3b-be89b11e-20fe3f9f-9c8d8dfe-4cfd202c
# subject_id                                                                      10000032
# study_id                                                                        53189527
# PerformedProcedureStepDescription                                     CHEST (PA AND LAT)
# ViewPosition                                                                     LATERAL
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21800626
# StudyTime                                                                     165500.312
# ProcedureCodeSequence_CodeMeaning                                     CHEST (PA AND LAT)
# ViewCodeSequence_CodeMeaning                                                     lateral
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
#
#                                                                                   4       \
# dicom_id                                    68b5c4b1-227d0485-9cc38c3f-7b84ab51-4b472714
# subject_id                                                                      10000032
# study_id                                                                        53911762
# PerformedProcedureStepDescription                                    CHEST (PORTABLE AP)
# ViewPosition                                                                          AP
# Rows                                                                                2705
# Columns                                                                             2539
# StudyDate                                                                       21800723
# StudyTime                                                                      80556.875
# ProcedureCodeSequence_CodeMeaning                                    CHEST (PORTABLE AP)
# ViewCodeSequence_CodeMeaning                                            antero-posterior
# PatientOrientationCodeSequence_CodeMeaning                                           NaN
#
#                                                                                   5       \
# dicom_id                                    fffabebf-74fd3a1f-673b6b41-96ec0ac9-2ab69818
# subject_id                                                                      10000032
# study_id                                                                        53911762
# PerformedProcedureStepDescription                                    CHEST (PORTABLE AP)
# ViewPosition                                                                          AP
# Rows                                                                                2906
# Columns                                                                             2258
# StudyDate                                                                       21800723
# StudyTime                                                                      80556.875
# ProcedureCodeSequence_CodeMeaning                                    CHEST (PORTABLE AP)
# ViewCodeSequence_CodeMeaning                                            antero-posterior
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
#
#                                                                                   6       \
# dicom_id                                    ea030e7a-2e3b1346-bc518786-7a8fd698-f673b44c
# subject_id                                                                      10000032
# study_id                                                                        56699142
# PerformedProcedureStepDescription                                    CHEST (PORTABLE AP)
# ViewPosition                                                                          AP
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21800805
# StudyTime                                                                     234424.765
# ProcedureCodeSequence_CodeMeaning                                    CHEST (PORTABLE AP)
# ViewCodeSequence_CodeMeaning                                            antero-posterior
# PatientOrientationCodeSequence_CodeMeaning                                           NaN
#
#                                                                                   7       \
# dicom_id                                    096052b7-d256dc40-453a102b-fa7d01c6-1b22c6b4
# subject_id                                                                      10000764
# study_id                                                                        57375967
# PerformedProcedureStepDescription                                     CHEST (PA AND LAT)
# ViewPosition                                                                          AP
# Rows                                                                                2544
# Columns                                                                             3056
# StudyDate                                                                       21321015
# StudyTime                                                                      84047.984
# ProcedureCodeSequence_CodeMeaning                                     CHEST (PA AND LAT)
# ViewCodeSequence_CodeMeaning                                            antero-posterior
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
#
#                                                                                   8       \
# dicom_id                                    b79e55c3-735ce5ac-64412506-cdc9ea79-f1af521f
# subject_id                                                                      10000764
# study_id                                                                        57375967
# PerformedProcedureStepDescription                                     CHEST (PA AND LAT)
# ViewPosition                                                                     LATERAL
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21321015
# StudyTime                                                                      84047.984
# ProcedureCodeSequence_CodeMeaning                                     CHEST (PA AND LAT)
# ViewCodeSequence_CodeMeaning                                                     lateral
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
#
#                                                                                   9       \
# dicom_id                                    dcfeeac4-1597e318-d0e6736a-8b2c2238-47ac3f1b
# subject_id                                                                      10000764
# study_id                                                                        57375967
# PerformedProcedureStepDescription                                     CHEST (PA AND LAT)
# ViewPosition                                                                     LATERAL
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21321015
# StudyTime                                                                      84047.984
# ProcedureCodeSequence_CodeMeaning                                     CHEST (PA AND LAT)
# ViewCodeSequence_CodeMeaning                                                     lateral
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
#
#                                             ...  \
# dicom_id                                    ...
# subject_id                                  ...
# study_id                                    ...
# PerformedProcedureStepDescription           ...
# ViewPosition                                ...
# Rows                                        ...
# Columns                                     ...
# StudyDate                                   ...
# StudyTime                                   ...
# ProcedureCodeSequence_CodeMeaning           ...
# ViewCodeSequence_CodeMeaning                ...
# PatientOrientationCodeSequence_CodeMeaning  ...
#
#                                                                                   377100  \
# dicom_id                                    2eb70dfe-52fa728e-a36e09be-ec0ed3cf-0a2ea7f0
# subject_id                                                                      19999287
# study_id                                                                        58938059
# PerformedProcedureStepDescription                                    CHEST (PORTABLE AP)
# ViewPosition                                                                          AP
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21970805
# StudyTime                                                                      93746.343
# ProcedureCodeSequence_CodeMeaning                                    CHEST (PORTABLE AP)
# ViewCodeSequence_CodeMeaning                                            antero-posterior
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
#
#                                                                                   377101  \
# dicom_id                                    53e9b6d0-5d5317f5-f1a4c031-01d40558-fd14a425
# subject_id                                                                      19999376
# study_id                                                                        57540554
# PerformedProcedureStepDescription                                    CHEST (PORTABLE AP)
# ViewPosition                                                                          AP
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21450731
# StudyTime                                                                      45417.656
# ProcedureCodeSequence_CodeMeaning                                    CHEST (PORTABLE AP)
# ViewCodeSequence_CodeMeaning                                            antero-posterior
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
#
#                                                                                   377102  \
# dicom_id                                    ee9155f3-944c056b-c76c73d0-3f792f2c-92ae461e
# subject_id                                                                      19999442
# study_id                                                                        58497551
# PerformedProcedureStepDescription                                    CHEST (PORTABLE AP)
# ViewPosition                                                                          AP
# Rows                                                                                2544
# Columns                                                                             3056
# StudyDate                                                                       21481128
# StudyTime                                                                     133244.093
# ProcedureCodeSequence_CodeMeaning                                    CHEST (PORTABLE AP)
# ViewCodeSequence_CodeMeaning                                            antero-posterior
# PatientOrientationCodeSequence_CodeMeaning                                           NaN
#
#                                                                                   377103  \
# dicom_id                                    16b6c70f-6d36bd77-89d2fef4-9c4b8b0a-79c69135
# subject_id                                                                      19999442
# study_id                                                                        58708861
# PerformedProcedureStepDescription                                    CHEST (PORTABLE AP)
# ViewPosition                                                                          AP
# Rows                                                                                2544
# Columns                                                                             3056
# StudyDate                                                                       21481119
# StudyTime                                                                     224703.375
# ProcedureCodeSequence_CodeMeaning                                    CHEST (PORTABLE AP)
# ViewCodeSequence_CodeMeaning                                            antero-posterior
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
#
#                                                                                   377104  \
# dicom_id                                    3fcd0406-9b111603-feae7033-96632b3a-111333e5
# subject_id                                                                      19999733
# study_id                                                                        57132437
# PerformedProcedureStepDescription                                     CHEST (PA AND LAT)
# ViewPosition                                                                          PA
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21520708
# StudyTime                                                                     224550.171
# ProcedureCodeSequence_CodeMeaning                                     CHEST (PA AND LAT)
# ViewCodeSequence_CodeMeaning                                            postero-anterior
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
#
#                                                                                   377105  \
# dicom_id                                    428e2c18-5721d8f3-35a05001-36f3d080-9053b83c
# subject_id                                                                      19999733
# study_id                                                                        57132437
# PerformedProcedureStepDescription                                     CHEST (PA AND LAT)
# ViewPosition                                                                          PA
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21520708
# StudyTime                                                                     224550.171
# ProcedureCodeSequence_CodeMeaning                                     CHEST (PA AND LAT)
# ViewCodeSequence_CodeMeaning                                            postero-anterior
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
#
#                                                                                   377106  \
# dicom_id                                    58c403aa-35ff8bd9-73e39f54-8dc9cc5d-e0ec3fa9
# subject_id                                                                      19999733
# study_id                                                                        57132437
# PerformedProcedureStepDescription                                     CHEST (PA AND LAT)
# ViewPosition                                                                     LATERAL
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21520708
# StudyTime                                                                     224550.171
# ProcedureCodeSequence_CodeMeaning                                     CHEST (PA AND LAT)
# ViewCodeSequence_CodeMeaning                                                     lateral
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
#
#                                                                                   377107  \
# dicom_id                                    58766883-376a15ce-3b323a28-6af950a0-16b793bd
# subject_id                                                                      19999987
# study_id                                                                        55368167
# PerformedProcedureStepDescription                                    CHEST (PORTABLE AP)
# ViewPosition                                                                          AP
# Rows                                                                                2544
# Columns                                                                             3056
# StudyDate                                                                       21451104
# StudyTime                                                                      51448.218
# ProcedureCodeSequence_CodeMeaning                                    CHEST (PORTABLE AP)
# ViewCodeSequence_CodeMeaning                                            antero-posterior
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
#
#                                                                                   377108  \
# dicom_id                                    7ba273af-3d290f8d-e28d0ab4-484b7a86-7fc12b08
# subject_id                                                                      19999987
# study_id                                                                        58621812
# PerformedProcedureStepDescription                                    CHEST (PORTABLE AP)
# ViewPosition                                                                          AP
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21451102
# StudyTime                                                                     202809.234
# ProcedureCodeSequence_CodeMeaning                                    CHEST (PORTABLE AP)
# ViewCodeSequence_CodeMeaning                                            antero-posterior
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
#
#                                                                                   377109
# dicom_id                                    1a1fe7e3-cbac5d93-b339aeda-86bb86b5-4f31e82e
# subject_id                                                                      19999987
# study_id                                                                        58971208
# PerformedProcedureStepDescription                                    CHEST (PORTABLE AP)
# ViewPosition                                                                          AP
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21451103
# StudyTime                                                                      50507.625
# ProcedureCodeSequence_CodeMeaning                                    CHEST (PORTABLE AP)
# ViewCodeSequence_CodeMeaning                                            antero-posterior
# PatientOrientationCodeSequence_CodeMeaning                                     Recumbent
#
# [12 rows x 377110 columns]
# chexpert
#                                 0           1           2           3       \
# subject_id                  10000032.0  10000032.0  10000032.0  10000032.0
# study_id                    50414267.0  53189527.0  53911762.0  56699142.0
# Atelectasis                        NaN         NaN         NaN         NaN
# Cardiomegaly                       NaN         NaN         NaN         NaN
# Consolidation                      NaN         NaN         NaN         NaN
# Edema                              NaN         NaN         NaN         NaN
# Enlarged Cardiomediastinum         NaN         NaN         NaN         NaN
# Fracture                           NaN         NaN         NaN         NaN
# Lung Lesion                        NaN         NaN         NaN         NaN
# Lung Opacity                       NaN         NaN         NaN         NaN
# No Finding                         1.0         1.0         1.0         1.0
# Pleural Effusion                   NaN         NaN         NaN         NaN
# Pleural Other                      NaN         NaN         NaN         NaN
# Pneumonia                          NaN         NaN         NaN         NaN
# Pneumothorax                       NaN         NaN         NaN         NaN
# Support Devices                    NaN         NaN         NaN         NaN
#
#                                 4           5           6           7       \
# subject_id                  10000764.0  10000898.0  10000898.0  10000935.0
# study_id                    57375967.0  50771383.0  54205396.0  50578979.0
# Atelectasis                        NaN         NaN         NaN         NaN
# Cardiomegaly                       NaN         NaN         NaN         NaN
# Consolidation                      1.0         NaN         NaN         NaN
# Edema                              NaN         NaN         NaN        -1.0
# Enlarged Cardiomediastinum         NaN         NaN         NaN         NaN
# Fracture                           NaN         NaN         NaN         NaN
# Lung Lesion                        NaN         NaN         NaN         NaN
# Lung Opacity                       NaN         NaN         NaN        -1.0
# No Finding                         NaN         1.0         1.0         NaN
# Pleural Effusion                   NaN         NaN         NaN         1.0
# Pleural Other                      NaN         NaN         NaN         NaN
# Pneumonia                         -1.0         NaN         NaN         1.0
# Pneumothorax                       NaN         NaN         NaN         NaN
# Support Devices                    NaN         NaN         NaN         NaN
#
#                                 8           9       ...      227817  \
# subject_id                  10000935.0  10000935.0  ...  19999287.0
# study_id                    51178377.0  55697293.0  ...  53255195.0
# Atelectasis                        NaN         NaN  ...         NaN
# Cardiomegaly                       NaN         NaN  ...         NaN
# Consolidation                      NaN         NaN  ...         NaN
# Edema                              NaN         NaN  ...         NaN
# Enlarged Cardiomediastinum         NaN         NaN  ...         NaN
# Fracture                           NaN         NaN  ...         NaN
# Lung Lesion                        NaN         NaN  ...         1.0
# Lung Opacity                       1.0         NaN  ...         1.0
# No Finding                         NaN         1.0  ...         NaN
# Pleural Effusion                   NaN         NaN  ...         NaN
# Pleural Other                      NaN         NaN  ...         NaN
# Pneumonia                         -1.0         NaN  ...         NaN
# Pneumothorax                       NaN         NaN  ...         NaN
# Support Devices                    NaN         NaN  ...         NaN
#
#                                 227818      227819      227820      227821  \
# subject_id                  19999287.0  19999287.0  19999376.0  19999442.0
# study_id                    53282218.0  58938059.0  57540554.0  58497551.0
# Atelectasis                        NaN         NaN         NaN         1.0
# Cardiomegaly                       0.0         NaN         NaN         NaN
# Consolidation                      NaN         NaN         NaN         NaN
# Edema                              NaN         NaN         NaN         NaN
# Enlarged Cardiomediastinum         NaN         NaN         NaN         NaN
# Fracture                           NaN         NaN         NaN         NaN
# Lung Lesion                       -1.0         NaN         NaN         NaN
# Lung Opacity                       1.0         1.0         NaN         1.0
# No Finding                         NaN         NaN         1.0         NaN
# Pleural Effusion                   0.0         NaN         NaN        -1.0
# Pleural Other                      NaN         NaN         NaN         NaN
# Pneumonia                          NaN         NaN         NaN         NaN
# Pneumothorax                       NaN         NaN         NaN         0.0
# Support Devices                    NaN         NaN         NaN         NaN
#
#                                 227822      227823      227824      227825  \
# subject_id                  19999442.0  19999733.0  19999987.0  19999987.0
# study_id                    58708861.0  57132437.0  55368167.0  58621812.0
# Atelectasis                        NaN         NaN         1.0         1.0
# Cardiomegaly                       NaN         NaN        -1.0         NaN
# Consolidation                      NaN         NaN         NaN         NaN
# Edema                              NaN         NaN         NaN         NaN
# Enlarged Cardiomediastinum         NaN         NaN         NaN         NaN
# Fracture                           NaN         NaN         NaN         NaN
# Lung Lesion                        NaN         NaN         0.0         NaN
# Lung Opacity                       NaN         NaN         NaN         NaN
# No Finding                         1.0         1.0         NaN         NaN
# Pleural Effusion                   NaN         NaN         0.0         NaN
# Pleural Other                      NaN         NaN         NaN         NaN
# Pneumonia                          NaN         NaN         NaN         NaN
# Pneumothorax                       NaN         NaN         0.0         NaN
# Support Devices                    1.0         NaN         NaN         1.0
#
#                                 227826
# subject_id                  19999987.0
# study_id                    58971208.0
# Atelectasis                        1.0
# Cardiomegaly                       NaN
# Consolidation                      NaN
# Edema                              NaN
# Enlarged Cardiomediastinum         NaN
# Fracture                           NaN
# Lung Lesion                        NaN
# Lung Opacity                       NaN
# No Finding                         NaN
# Pleural Effusion                   NaN
# Pleural Other                      NaN
# Pneumonia                          NaN
# Pneumothorax                       NaN
# Support Devices                    NaN
#
# [16 rows x 227827 columns]
# negbio
#                                 0           1           2           3       \
# subject_id                  10000032.0  10000032.0  10000032.0  10000032.0
# study_id                    50414267.0  53189527.0  53911762.0  56699142.0
# Atelectasis                        NaN         NaN         NaN         NaN
# Cardiomegaly                       NaN         NaN         NaN         NaN
# Consolidation                      NaN         NaN         NaN         NaN
# Edema                              NaN         NaN         NaN         NaN
# Enlarged Cardiomediastinum         NaN         NaN         NaN         NaN
# Fracture                           NaN         NaN         NaN         NaN
# Lung Lesion                        NaN         NaN         NaN         NaN
# Lung Opacity                       NaN         NaN         NaN         NaN
# No Finding                         1.0         1.0         1.0         1.0
# Pleural Effusion                   NaN         NaN         NaN         NaN
# Pleural Other                      NaN         NaN         NaN         NaN
# Pneumonia                          NaN         NaN         NaN         NaN
# Pneumothorax                       NaN         NaN         NaN         NaN
# Support Devices                    NaN         NaN         NaN         NaN
#
#                                 4           5           6           7       \
# subject_id                  10000764.0  10000898.0  10000898.0  10000935.0
# study_id                    57375967.0  50771383.0  54205396.0  50578979.0
# Atelectasis                        NaN         NaN         NaN         NaN
# Cardiomegaly                       NaN         NaN         NaN         NaN
# Consolidation                      1.0         NaN         NaN         NaN
# Edema                              NaN         NaN         NaN        -1.0
# Enlarged Cardiomediastinum         NaN         NaN         NaN         NaN
# Fracture                           NaN         NaN         NaN         NaN
# Lung Lesion                        NaN         NaN         NaN         NaN
# Lung Opacity                       NaN         NaN         NaN         0.0
# No Finding                         NaN         1.0         1.0         NaN
# Pleural Effusion                   NaN         NaN         NaN         1.0
# Pleural Other                      NaN         NaN         NaN         NaN
# Pneumonia                         -1.0         NaN         NaN         1.0
# Pneumothorax                       NaN         NaN         NaN         NaN
# Support Devices                    NaN         NaN         NaN         NaN
#
#                                 8           9       ...      227817  \
# subject_id                  10000935.0  10000935.0  ...  19999287.0
# study_id                    51178377.0  55697293.0  ...  53255195.0
# Atelectasis                        NaN         NaN  ...         NaN
# Cardiomegaly                       NaN         NaN  ...         NaN
# Consolidation                      NaN         NaN  ...         NaN
# Edema                              NaN         NaN  ...         NaN
# Enlarged Cardiomediastinum         NaN         NaN  ...         NaN
# Fracture                           NaN         NaN  ...         NaN
# Lung Lesion                        NaN         NaN  ...         1.0
# Lung Opacity                       1.0         NaN  ...         1.0
# No Finding                         NaN         1.0  ...         NaN
# Pleural Effusion                   NaN         NaN  ...         NaN
# Pleural Other                      NaN         NaN  ...         NaN
# Pneumonia                         -1.0         NaN  ...         NaN
# Pneumothorax                       NaN         NaN  ...         NaN
# Support Devices                    NaN         NaN  ...         NaN
#
#                                 227818      227819      227820      227821  \
# subject_id                  19999287.0  19999287.0  19999376.0  19999442.0
# study_id                    53282218.0  58938059.0  57540554.0  58497551.0
# Atelectasis                        NaN         NaN         NaN         1.0
# Cardiomegaly                       0.0         NaN         NaN         NaN
# Consolidation                      NaN         NaN         NaN         NaN
# Edema                              NaN         NaN         NaN         NaN
# Enlarged Cardiomediastinum         NaN         NaN         NaN         NaN
# Fracture                           NaN         NaN         NaN         NaN
# Lung Lesion                       -1.0         NaN         NaN         NaN
# Lung Opacity                       1.0         1.0         NaN         1.0
# No Finding                         NaN         NaN         1.0         NaN
# Pleural Effusion                   0.0         NaN         NaN        -1.0
# Pleural Other                      NaN         NaN         NaN         NaN
# Pneumonia                          NaN         NaN         NaN         NaN
# Pneumothorax                       NaN         NaN         NaN         0.0
# Support Devices                    NaN         NaN         NaN         NaN
#
#                                 227822      227823      227824      227825  \
# subject_id                  19999442.0  19999733.0  19999987.0  19999987.0
# study_id                    58708861.0  57132437.0  55368167.0  58621812.0
# Atelectasis                        NaN         NaN         1.0         1.0
# Cardiomegaly                       NaN         NaN        -1.0         NaN
# Consolidation                      NaN         NaN         NaN         NaN
# Edema                              NaN         NaN         NaN         NaN
# Enlarged Cardiomediastinum         NaN         NaN         NaN         NaN
# Fracture                           NaN         NaN         NaN         NaN
# Lung Lesion                        NaN         NaN         0.0         NaN
# Lung Opacity                       NaN         NaN         NaN         NaN
# No Finding                         1.0         1.0         NaN         NaN
# Pleural Effusion                   NaN         NaN         0.0         NaN
# Pleural Other                      NaN         NaN         NaN         NaN
# Pneumonia                          NaN         NaN         NaN         NaN
# Pneumothorax                       NaN         NaN         0.0         NaN
# Support Devices                    1.0         NaN         NaN         1.0
#
#                                 227826
# subject_id                  19999987.0
# study_id                    58971208.0
# Atelectasis                        1.0
# Cardiomegaly                       NaN
# Consolidation                      NaN
# Edema                              NaN
# Enlarged Cardiomediastinum         NaN
# Fracture                           NaN
# Lung Lesion                        NaN
# Lung Opacity                       NaN
# No Finding                         NaN
# Pleural Effusion                   NaN
# Pleural Other                      NaN
# Pneumonia                          NaN
# Pneumothorax                       NaN
# Support Devices                    NaN
#
# [16 rows x 227827 columns]

# %% [markdown]
# <font color="yellow">1. VIEW</font> correct "view" field

# %%
# initialize view with a mapping from ViewPosition
VIEW_MAP = {
    'AP': 'frontal',
    'PA': 'frontal',
    'LATERAL': 'lateral',
    'LL': 'lateral',
    'LPO': 'other',
    'RAO': 'other',
    'RPO': 'other',
    'LAO': 'other',
    # the below are overwritten in some instances by manual review
    'AP AXIAL': 'other',
    'XTABLE LATERAL': 'other',
    'AP LLD': 'other',
    'PA LLD': 'other',
    'L5 S1': 'other',
    'SWIMMERS': 'other',
    'AP RLD': 'other',
    'PA RLD': 'other',
}

df_metadata['view'] = df_metadata['ViewPosition'].map(VIEW_MAP)

# for 'other' category, currently many of these are simply unknown
# so try to update them with acq device map
ADPD_MAP = {
    'CHEST, LATERAL': 'lateral',
    'CHEST, PA': 'frontal',
    # manually checked 100 records, below is always frontal
    'CHEST, PORTABLE': 'frontal',
    'CHEST, PA X-WISE': 'frontal',
    'CHEST, AP (GRID)': 'frontal',
    'CHEST LAT': 'lateral',
    'CHEST PA': 'frontal',
    'CHEST, AP NON-GRID': 'frontal',
    'CHEST AP NON GRID': 'frontal',
    'CHEST PA X-WISE': 'frontal',
    'CHEST AP GRID': 'frontal',
    'CHEST, PORTABLE X-WISE': 'other',
    # below have < 25 samples each
    'CHEST PORT': 'frontal',
    'CHEST PORT X-WISE': 'frontal',
    # manually classified below
    'SHOULDER': 'other',
    'CHEST, PEDI (4-10 YRS)': 'other',
    'LOWER RIBS': 'other',
    'CHEST, DECUB.': 'other',
    'ABDOMEN, PORTABLE': 'other',
    'UPPER RIBS': 'frontal',
    'STERNUM, LATERAL': 'lateral',
    'KNEE, AP/OBL': 'other',
    'STERNUM, PA/OBL.': 'other',
    'CLAVICLE/ AC JOINTS': 'other',
    'ABDOMEN,GENERAL': 'other',
    'LOWER RIB': 'other',
    'SCOLIOSIS AP': 'frontal'
}

good_view = ['frontal', 'lateral']
idxUpdate = ~df_metadata['view'].isin(good_view)

# ! this field is not present in current file
c = 'AcquisitionDeviceProcessingDescription'
# idx = (df_metadata[c].notnull()) & idxUpdate
# df_metadata.loc[idx, 'view'] = df_metadata.loc[idx, c].map(ADPD_MAP)

DICOM_TO_VIEW = {
    '2164992c-f4abb30a-7aaaf4f4-383cab47-4e3eb1c8': ['PA', 'frontal'],
    '5e6881e2-ff4254e0-b99f0c2f-8964482a-031364db': ['LL', 'lateral'],
    'fcdf7a30-3236b74e-65b97587-cdd4cfde-63cd1de0': ['PA', 'frontal'],
    'fb074ec1-6715839c-84fa75e6-adc3f026-448b1481': ['PA', 'frontal'],
    'dfb8080a-8506e43e-840d9d58-0f738f41-82c120b0': ['PA', 'frontal'],
    '4b32608b-c2ead7c4-1fe5565f-42f7ab80-9dad30de': ['LL', 'lateral'],
    '53663e89-8f9ca9bb-df1bf434-8d6b1283-2b612609': ['LL', 'lateral'],
    # below are AP, but incorrectly in View Position
    '8672a4e7-366801a0-26cf2395-9344335c-aac8d728': ['AP', 'frontal'],
    '9800b28e-3ff3b417-18473be2-1a66131d-aca88488': ['AP', 'frontal'],
    '598cfe48-33a8643e-843e27e2-5dd584e7-3cd5f1c0': ['AP', 'frontal']
}

# we manually reviewed a few DICOMs to keep them in
for dcm, row in DICOM_TO_VIEW.items():
    view = row[1]
    idx = df_metadata['dicom_id'] == dcm
    if idx.any():
        df_metadata.loc[idx, 'view'] = view

# remove rows that do not have a good view
idxUpdate = ~df_metadata['view'].isin(good_view)
print(f"removing {nnz(idxUpdate)} rows")
n_rows = df_metadata.shape[0]
df_metadata.drop(df[idxUpdate].index, inplace=True)
assert nnz(idxUpdate) == n_rows - df_metadata.shape[0]

print(f"using {df_metadata.shape[0]} examples")
# Out:
# removing 15784 rows
# using 361326 examples

# %% [markdown]
# <font color="yellow">2. SPLIT & FINDINGS</font>

# %%
# merge dataframes
# METADATA + SPLIT
df = df_split.merge(df_metadata.drop(['study_id', 'subject_id'], axis=1),
                   on='dicom_id', how='inner')

nb = pd.read_csv(filename_negbio)
cx = pd.read_csv(filename_chexpert)

nb.drop('subject_id', axis=1, inplace=True)
cx.drop('subject_id', axis=1, inplace=True)

nb_findings = [x for x in nb.columns if x != 'study_id']
cx_findings = [x for x in cx.columns if x != 'study_id']

# METADATA + SPLIT + LABELS
df = df.merge(cx, how='left', on='study_id')

# indicator flag for the study having a Chexpert/NegBio finding
df['has_chexpert_finding'] = df[[x for x in cx_findings if x != 'No Finding']].notnull().sum(axis=1) > 0
df['has_chexpert_pos_finding'] = df[[x for x in cx_findings if x != 'No Finding']].gt(0).sum(axis=1) > 0
df['is_chexpert_normal'] = df[['No Finding']].gt(0).sum(axis=1) > 0
df['has_chexpert_neg_finding'] = df[[x for x in cx_findings if x != 'No Finding']].lt(0).sum(axis=1) > 0
# df['has_chexpert_pos_neg'] = df[[x for x in cx_findings if x != 'No Finding']].lt(0).sum(axis=1) > 0 & df[[x for x in cx_findings if x != 'No Finding']].gt(0).sum(axis=1) > 0
# df['has_negbio_finding'] = df[[x for x in nb_findings if x != 'No Finding']].notnull().sum(axis=1) > 0
# df['has_negbio_pos_finding'] = df[[x for x in nb_findings if x != 'No Finding']].notnull().sum(axis=1) > 0

df.drop(df[~df.view.isin(["frontal", "lateral"])].index, inplace=True)
print("view")
print(df["view"].value_counts())

# df[['dicom_id', 'split', 'view'] + findings].head().T

print("metadata + split + chexpert:", df.shape)
display(df.T)
# Out:
# view
# frontal    243337
# lateral    117989
# Name: view, dtype: int64
# metadata + split + chexpert: (361326, 32)
#                                                                                   0       \
# dicom_id                                    02aa804e-bde0afdd-112c0b34-7bc16630-4e384014
# study_id                                                                        50414267
# subject_id                                                                      10000032
# split                                                                              train
# PerformedProcedureStepDescription                                     CHEST (PA AND LAT)
# ViewPosition                                                                          PA
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21800506
# StudyTime                                                                     213014.531
# ProcedureCodeSequence_CodeMeaning                                     CHEST (PA AND LAT)
# ViewCodeSequence_CodeMeaning                                            postero-anterior
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
# view                                                                             frontal
# Atelectasis                                                                          NaN
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        NaN
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         NaN
# No Finding                                                                           1.0
# Pleural Effusion                                                                     NaN
# Pleural Other                                                                        NaN
# Pneumonia                                                                            NaN
# Pneumothorax                                                                         NaN
# Support Devices                                                                      NaN
# has_chexpert_finding                                                               False
# has_chexpert_pos_finding                                                           False
# is_chexpert_normal                                                                  True
# has_chexpert_neg_finding                                                           False
#
#                                                                                   1       \
# dicom_id                                    174413ec-4ec4c1f7-34ea26b7-c5f994f8-79ef1962
# study_id                                                                        50414267
# subject_id                                                                      10000032
# split                                                                              train
# PerformedProcedureStepDescription                                     CHEST (PA AND LAT)
# ViewPosition                                                                     LATERAL
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21800506
# StudyTime                                                                     213014.531
# ProcedureCodeSequence_CodeMeaning                                     CHEST (PA AND LAT)
# ViewCodeSequence_CodeMeaning                                                     lateral
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
# view                                                                             lateral
# Atelectasis                                                                          NaN
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        NaN
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         NaN
# No Finding                                                                           1.0
# Pleural Effusion                                                                     NaN
# Pleural Other                                                                        NaN
# Pneumonia                                                                            NaN
# Pneumothorax                                                                         NaN
# Support Devices                                                                      NaN
# has_chexpert_finding                                                               False
# has_chexpert_pos_finding                                                           False
# is_chexpert_normal                                                                  True
# has_chexpert_neg_finding                                                           False
#
#                                                                                   2       \
# dicom_id                                    2a2277a9-b0ded155-c0de8eb9-c124d10e-82c5caab
# study_id                                                                        53189527
# subject_id                                                                      10000032
# split                                                                              train
# PerformedProcedureStepDescription                                     CHEST (PA AND LAT)
# ViewPosition                                                                          PA
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21800626
# StudyTime                                                                     165500.312
# ProcedureCodeSequence_CodeMeaning                                     CHEST (PA AND LAT)
# ViewCodeSequence_CodeMeaning                                            postero-anterior
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
# view                                                                             frontal
# Atelectasis                                                                          NaN
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        NaN
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         NaN
# No Finding                                                                           1.0
# Pleural Effusion                                                                     NaN
# Pleural Other                                                                        NaN
# Pneumonia                                                                            NaN
# Pneumothorax                                                                         NaN
# Support Devices                                                                      NaN
# has_chexpert_finding                                                               False
# has_chexpert_pos_finding                                                           False
# is_chexpert_normal                                                                  True
# has_chexpert_neg_finding                                                           False
#
#                                                                                   3       \
# dicom_id                                    e084de3b-be89b11e-20fe3f9f-9c8d8dfe-4cfd202c
# study_id                                                                        53189527
# subject_id                                                                      10000032
# split                                                                              train
# PerformedProcedureStepDescription                                     CHEST (PA AND LAT)
# ViewPosition                                                                     LATERAL
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21800626
# StudyTime                                                                     165500.312
# ProcedureCodeSequence_CodeMeaning                                     CHEST (PA AND LAT)
# ViewCodeSequence_CodeMeaning                                                     lateral
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
# view                                                                             lateral
# Atelectasis                                                                          NaN
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        NaN
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         NaN
# No Finding                                                                           1.0
# Pleural Effusion                                                                     NaN
# Pleural Other                                                                        NaN
# Pneumonia                                                                            NaN
# Pneumothorax                                                                         NaN
# Support Devices                                                                      NaN
# has_chexpert_finding                                                               False
# has_chexpert_pos_finding                                                           False
# is_chexpert_normal                                                                  True
# has_chexpert_neg_finding                                                           False
#
#                                                                                   4       \
# dicom_id                                    68b5c4b1-227d0485-9cc38c3f-7b84ab51-4b472714
# study_id                                                                        53911762
# subject_id                                                                      10000032
# split                                                                              train
# PerformedProcedureStepDescription                                    CHEST (PORTABLE AP)
# ViewPosition                                                                          AP
# Rows                                                                                2705
# Columns                                                                             2539
# StudyDate                                                                       21800723
# StudyTime                                                                      80556.875
# ProcedureCodeSequence_CodeMeaning                                    CHEST (PORTABLE AP)
# ViewCodeSequence_CodeMeaning                                            antero-posterior
# PatientOrientationCodeSequence_CodeMeaning                                           NaN
# view                                                                             frontal
# Atelectasis                                                                          NaN
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        NaN
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         NaN
# No Finding                                                                           1.0
# Pleural Effusion                                                                     NaN
# Pleural Other                                                                        NaN
# Pneumonia                                                                            NaN
# Pneumothorax                                                                         NaN
# Support Devices                                                                      NaN
# has_chexpert_finding                                                               False
# has_chexpert_pos_finding                                                           False
# is_chexpert_normal                                                                  True
# has_chexpert_neg_finding                                                           False
#
#                                                                                   5       \
# dicom_id                                    fffabebf-74fd3a1f-673b6b41-96ec0ac9-2ab69818
# study_id                                                                        53911762
# subject_id                                                                      10000032
# split                                                                              train
# PerformedProcedureStepDescription                                    CHEST (PORTABLE AP)
# ViewPosition                                                                          AP
# Rows                                                                                2906
# Columns                                                                             2258
# StudyDate                                                                       21800723
# StudyTime                                                                      80556.875
# ProcedureCodeSequence_CodeMeaning                                    CHEST (PORTABLE AP)
# ViewCodeSequence_CodeMeaning                                            antero-posterior
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
# view                                                                             frontal
# Atelectasis                                                                          NaN
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        NaN
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         NaN
# No Finding                                                                           1.0
# Pleural Effusion                                                                     NaN
# Pleural Other                                                                        NaN
# Pneumonia                                                                            NaN
# Pneumothorax                                                                         NaN
# Support Devices                                                                      NaN
# has_chexpert_finding                                                               False
# has_chexpert_pos_finding                                                           False
# is_chexpert_normal                                                                  True
# has_chexpert_neg_finding                                                           False
#
#                                                                                   6       \
# dicom_id                                    ea030e7a-2e3b1346-bc518786-7a8fd698-f673b44c
# study_id                                                                        56699142
# subject_id                                                                      10000032
# split                                                                              train
# PerformedProcedureStepDescription                                    CHEST (PORTABLE AP)
# ViewPosition                                                                          AP
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21800805
# StudyTime                                                                     234424.765
# ProcedureCodeSequence_CodeMeaning                                    CHEST (PORTABLE AP)
# ViewCodeSequence_CodeMeaning                                            antero-posterior
# PatientOrientationCodeSequence_CodeMeaning                                           NaN
# view                                                                             frontal
# Atelectasis                                                                          NaN
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        NaN
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         NaN
# No Finding                                                                           1.0
# Pleural Effusion                                                                     NaN
# Pleural Other                                                                        NaN
# Pneumonia                                                                            NaN
# Pneumothorax                                                                         NaN
# Support Devices                                                                      NaN
# has_chexpert_finding                                                               False
# has_chexpert_pos_finding                                                           False
# is_chexpert_normal                                                                  True
# has_chexpert_neg_finding                                                           False
#
#                                                                                   7       \
# dicom_id                                    096052b7-d256dc40-453a102b-fa7d01c6-1b22c6b4
# study_id                                                                        57375967
# subject_id                                                                      10000764
# split                                                                              train
# PerformedProcedureStepDescription                                     CHEST (PA AND LAT)
# ViewPosition                                                                          AP
# Rows                                                                                2544
# Columns                                                                             3056
# StudyDate                                                                       21321015
# StudyTime                                                                      84047.984
# ProcedureCodeSequence_CodeMeaning                                     CHEST (PA AND LAT)
# ViewCodeSequence_CodeMeaning                                            antero-posterior
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
# view                                                                             frontal
# Atelectasis                                                                          NaN
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        1.0
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         NaN
# No Finding                                                                           NaN
# Pleural Effusion                                                                     NaN
# Pleural Other                                                                        NaN
# Pneumonia                                                                           -1.0
# Pneumothorax                                                                         NaN
# Support Devices                                                                      NaN
# has_chexpert_finding                                                                True
# has_chexpert_pos_finding                                                            True
# is_chexpert_normal                                                                 False
# has_chexpert_neg_finding                                                            True
#
#                                                                                   8       \
# dicom_id                                    b79e55c3-735ce5ac-64412506-cdc9ea79-f1af521f
# study_id                                                                        57375967
# subject_id                                                                      10000764
# split                                                                              train
# PerformedProcedureStepDescription                                     CHEST (PA AND LAT)
# ViewPosition                                                                     LATERAL
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21321015
# StudyTime                                                                      84047.984
# ProcedureCodeSequence_CodeMeaning                                     CHEST (PA AND LAT)
# ViewCodeSequence_CodeMeaning                                                     lateral
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
# view                                                                             lateral
# Atelectasis                                                                          NaN
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        1.0
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         NaN
# No Finding                                                                           NaN
# Pleural Effusion                                                                     NaN
# Pleural Other                                                                        NaN
# Pneumonia                                                                           -1.0
# Pneumothorax                                                                         NaN
# Support Devices                                                                      NaN
# has_chexpert_finding                                                                True
# has_chexpert_pos_finding                                                            True
# is_chexpert_normal                                                                 False
# has_chexpert_neg_finding                                                            True
#
#                                                                                   9       \
# dicom_id                                    dcfeeac4-1597e318-d0e6736a-8b2c2238-47ac3f1b
# study_id                                                                        57375967
# subject_id                                                                      10000764
# split                                                                              train
# PerformedProcedureStepDescription                                     CHEST (PA AND LAT)
# ViewPosition                                                                     LATERAL
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21321015
# StudyTime                                                                      84047.984
# ProcedureCodeSequence_CodeMeaning                                     CHEST (PA AND LAT)
# ViewCodeSequence_CodeMeaning                                                     lateral
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
# view                                                                             lateral
# Atelectasis                                                                          NaN
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        1.0
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         NaN
# No Finding                                                                           NaN
# Pleural Effusion                                                                     NaN
# Pleural Other                                                                        NaN
# Pneumonia                                                                           -1.0
# Pneumothorax                                                                         NaN
# Support Devices                                                                      NaN
# has_chexpert_finding                                                                True
# has_chexpert_pos_finding                                                            True
# is_chexpert_normal                                                                 False
# has_chexpert_neg_finding                                                            True
#
#                                             ...  \
# dicom_id                                    ...
# study_id                                    ...
# subject_id                                  ...
# split                                       ...
# PerformedProcedureStepDescription           ...
# ViewPosition                                ...
# Rows                                        ...
# Columns                                     ...
# StudyDate                                   ...
# StudyTime                                   ...
# ProcedureCodeSequence_CodeMeaning           ...
# ViewCodeSequence_CodeMeaning                ...
# PatientOrientationCodeSequence_CodeMeaning  ...
# view                                        ...
# Atelectasis                                 ...
# Cardiomegaly                                ...
# Consolidation                               ...
# Edema                                       ...
# Enlarged Cardiomediastinum                  ...
# Fracture                                    ...
# Lung Lesion                                 ...
# Lung Opacity                                ...
# No Finding                                  ...
# Pleural Effusion                            ...
# Pleural Other                               ...
# Pneumonia                                   ...
# Pneumothorax                                ...
# Support Devices                             ...
# has_chexpert_finding                        ...
# has_chexpert_pos_finding                    ...
# is_chexpert_normal                          ...
# has_chexpert_neg_finding                    ...
#
#                                                                                   361316  \
# dicom_id                                    2eb70dfe-52fa728e-a36e09be-ec0ed3cf-0a2ea7f0
# study_id                                                                        58938059
# subject_id                                                                      19999287
# split                                                                              train
# PerformedProcedureStepDescription                                    CHEST (PORTABLE AP)
# ViewPosition                                                                          AP
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21970805
# StudyTime                                                                      93746.343
# ProcedureCodeSequence_CodeMeaning                                    CHEST (PORTABLE AP)
# ViewCodeSequence_CodeMeaning                                            antero-posterior
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
# view                                                                             frontal
# Atelectasis                                                                          NaN
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        NaN
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         1.0
# No Finding                                                                           NaN
# Pleural Effusion                                                                     NaN
# Pleural Other                                                                        NaN
# Pneumonia                                                                            NaN
# Pneumothorax                                                                         NaN
# Support Devices                                                                      NaN
# has_chexpert_finding                                                                True
# has_chexpert_pos_finding                                                            True
# is_chexpert_normal                                                                 False
# has_chexpert_neg_finding                                                           False
#
#                                                                                   361317  \
# dicom_id                                    53e9b6d0-5d5317f5-f1a4c031-01d40558-fd14a425
# study_id                                                                        57540554
# subject_id                                                                      19999376
# split                                                                              train
# PerformedProcedureStepDescription                                    CHEST (PORTABLE AP)
# ViewPosition                                                                          AP
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21450731
# StudyTime                                                                      45417.656
# ProcedureCodeSequence_CodeMeaning                                    CHEST (PORTABLE AP)
# ViewCodeSequence_CodeMeaning                                            antero-posterior
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
# view                                                                             frontal
# Atelectasis                                                                          NaN
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        NaN
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         NaN
# No Finding                                                                           1.0
# Pleural Effusion                                                                     NaN
# Pleural Other                                                                        NaN
# Pneumonia                                                                            NaN
# Pneumothorax                                                                         NaN
# Support Devices                                                                      NaN
# has_chexpert_finding                                                               False
# has_chexpert_pos_finding                                                           False
# is_chexpert_normal                                                                  True
# has_chexpert_neg_finding                                                           False
#
#                                                                                   361318  \
# dicom_id                                    ee9155f3-944c056b-c76c73d0-3f792f2c-92ae461e
# study_id                                                                        58497551
# subject_id                                                                      19999442
# split                                                                              train
# PerformedProcedureStepDescription                                    CHEST (PORTABLE AP)
# ViewPosition                                                                          AP
# Rows                                                                                2544
# Columns                                                                             3056
# StudyDate                                                                       21481128
# StudyTime                                                                     133244.093
# ProcedureCodeSequence_CodeMeaning                                    CHEST (PORTABLE AP)
# ViewCodeSequence_CodeMeaning                                            antero-posterior
# PatientOrientationCodeSequence_CodeMeaning                                           NaN
# view                                                                             frontal
# Atelectasis                                                                          1.0
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        NaN
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         1.0
# No Finding                                                                           NaN
# Pleural Effusion                                                                    -1.0
# Pleural Other                                                                        NaN
# Pneumonia                                                                            NaN
# Pneumothorax                                                                         0.0
# Support Devices                                                                      NaN
# has_chexpert_finding                                                                True
# has_chexpert_pos_finding                                                            True
# is_chexpert_normal                                                                 False
# has_chexpert_neg_finding                                                            True
#
#                                                                                   361319  \
# dicom_id                                    16b6c70f-6d36bd77-89d2fef4-9c4b8b0a-79c69135
# study_id                                                                        58708861
# subject_id                                                                      19999442
# split                                                                              train
# PerformedProcedureStepDescription                                    CHEST (PORTABLE AP)
# ViewPosition                                                                          AP
# Rows                                                                                2544
# Columns                                                                             3056
# StudyDate                                                                       21481119
# StudyTime                                                                     224703.375
# ProcedureCodeSequence_CodeMeaning                                    CHEST (PORTABLE AP)
# ViewCodeSequence_CodeMeaning                                            antero-posterior
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
# view                                                                             frontal
# Atelectasis                                                                          NaN
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        NaN
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         NaN
# No Finding                                                                           1.0
# Pleural Effusion                                                                     NaN
# Pleural Other                                                                        NaN
# Pneumonia                                                                            NaN
# Pneumothorax                                                                         NaN
# Support Devices                                                                      1.0
# has_chexpert_finding                                                                True
# has_chexpert_pos_finding                                                            True
# is_chexpert_normal                                                                  True
# has_chexpert_neg_finding                                                           False
#
#                                                                                   361320  \
# dicom_id                                    3fcd0406-9b111603-feae7033-96632b3a-111333e5
# study_id                                                                        57132437
# subject_id                                                                      19999733
# split                                                                              train
# PerformedProcedureStepDescription                                     CHEST (PA AND LAT)
# ViewPosition                                                                          PA
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21520708
# StudyTime                                                                     224550.171
# ProcedureCodeSequence_CodeMeaning                                     CHEST (PA AND LAT)
# ViewCodeSequence_CodeMeaning                                            postero-anterior
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
# view                                                                             frontal
# Atelectasis                                                                          NaN
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        NaN
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         NaN
# No Finding                                                                           1.0
# Pleural Effusion                                                                     NaN
# Pleural Other                                                                        NaN
# Pneumonia                                                                            NaN
# Pneumothorax                                                                         NaN
# Support Devices                                                                      NaN
# has_chexpert_finding                                                               False
# has_chexpert_pos_finding                                                           False
# is_chexpert_normal                                                                  True
# has_chexpert_neg_finding                                                           False
#
#                                                                                   361321  \
# dicom_id                                    428e2c18-5721d8f3-35a05001-36f3d080-9053b83c
# study_id                                                                        57132437
# subject_id                                                                      19999733
# split                                                                              train
# PerformedProcedureStepDescription                                     CHEST (PA AND LAT)
# ViewPosition                                                                          PA
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21520708
# StudyTime                                                                     224550.171
# ProcedureCodeSequence_CodeMeaning                                     CHEST (PA AND LAT)
# ViewCodeSequence_CodeMeaning                                            postero-anterior
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
# view                                                                             frontal
# Atelectasis                                                                          NaN
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        NaN
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         NaN
# No Finding                                                                           1.0
# Pleural Effusion                                                                     NaN
# Pleural Other                                                                        NaN
# Pneumonia                                                                            NaN
# Pneumothorax                                                                         NaN
# Support Devices                                                                      NaN
# has_chexpert_finding                                                               False
# has_chexpert_pos_finding                                                           False
# is_chexpert_normal                                                                  True
# has_chexpert_neg_finding                                                           False
#
#                                                                                   361322  \
# dicom_id                                    58c403aa-35ff8bd9-73e39f54-8dc9cc5d-e0ec3fa9
# study_id                                                                        57132437
# subject_id                                                                      19999733
# split                                                                              train
# PerformedProcedureStepDescription                                     CHEST (PA AND LAT)
# ViewPosition                                                                     LATERAL
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21520708
# StudyTime                                                                     224550.171
# ProcedureCodeSequence_CodeMeaning                                     CHEST (PA AND LAT)
# ViewCodeSequence_CodeMeaning                                                     lateral
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
# view                                                                             lateral
# Atelectasis                                                                          NaN
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        NaN
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         NaN
# No Finding                                                                           1.0
# Pleural Effusion                                                                     NaN
# Pleural Other                                                                        NaN
# Pneumonia                                                                            NaN
# Pneumothorax                                                                         NaN
# Support Devices                                                                      NaN
# has_chexpert_finding                                                               False
# has_chexpert_pos_finding                                                           False
# is_chexpert_normal                                                                  True
# has_chexpert_neg_finding                                                           False
#
#                                                                                   361323  \
# dicom_id                                    58766883-376a15ce-3b323a28-6af950a0-16b793bd
# study_id                                                                        55368167
# subject_id                                                                      19999987
# split                                                                              train
# PerformedProcedureStepDescription                                    CHEST (PORTABLE AP)
# ViewPosition                                                                          AP
# Rows                                                                                2544
# Columns                                                                             3056
# StudyDate                                                                       21451104
# StudyTime                                                                      51448.218
# ProcedureCodeSequence_CodeMeaning                                    CHEST (PORTABLE AP)
# ViewCodeSequence_CodeMeaning                                            antero-posterior
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
# view                                                                             frontal
# Atelectasis                                                                          1.0
# Cardiomegaly                                                                        -1.0
# Consolidation                                                                        NaN
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          0.0
# Lung Opacity                                                                         NaN
# No Finding                                                                           NaN
# Pleural Effusion                                                                     0.0
# Pleural Other                                                                        NaN
# Pneumonia                                                                            NaN
# Pneumothorax                                                                         0.0
# Support Devices                                                                      NaN
# has_chexpert_finding                                                                True
# has_chexpert_pos_finding                                                            True
# is_chexpert_normal                                                                 False
# has_chexpert_neg_finding                                                            True
#
#                                                                                   361324  \
# dicom_id                                    7ba273af-3d290f8d-e28d0ab4-484b7a86-7fc12b08
# study_id                                                                        58621812
# subject_id                                                                      19999987
# split                                                                              train
# PerformedProcedureStepDescription                                    CHEST (PORTABLE AP)
# ViewPosition                                                                          AP
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21451102
# StudyTime                                                                     202809.234
# ProcedureCodeSequence_CodeMeaning                                    CHEST (PORTABLE AP)
# ViewCodeSequence_CodeMeaning                                            antero-posterior
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
# view                                                                             frontal
# Atelectasis                                                                          1.0
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        NaN
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         NaN
# No Finding                                                                           NaN
# Pleural Effusion                                                                     NaN
# Pleural Other                                                                        NaN
# Pneumonia                                                                            NaN
# Pneumothorax                                                                         NaN
# Support Devices                                                                      1.0
# has_chexpert_finding                                                                True
# has_chexpert_pos_finding                                                            True
# is_chexpert_normal                                                                 False
# has_chexpert_neg_finding                                                           False
#
#                                                                                   361325
# dicom_id                                    1a1fe7e3-cbac5d93-b339aeda-86bb86b5-4f31e82e
# study_id                                                                        58971208
# subject_id                                                                      19999987
# split                                                                              train
# PerformedProcedureStepDescription                                    CHEST (PORTABLE AP)
# ViewPosition                                                                          AP
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21451103
# StudyTime                                                                      50507.625
# ProcedureCodeSequence_CodeMeaning                                    CHEST (PORTABLE AP)
# ViewCodeSequence_CodeMeaning                                            antero-posterior
# PatientOrientationCodeSequence_CodeMeaning                                     Recumbent
# view                                                                             frontal
# Atelectasis                                                                          1.0
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        NaN
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         NaN
# No Finding                                                                           NaN
# Pleural Effusion                                                                     NaN
# Pleural Other                                                                        NaN
# Pneumonia                                                                            NaN
# Pneumothorax                                                                         NaN
# Support Devices                                                                      NaN
# has_chexpert_finding                                                                True
# has_chexpert_pos_finding                                                            True
# is_chexpert_normal                                                                 False
# has_chexpert_neg_finding                                                           False
#
# [32 rows x 361326 columns]

# %%
# EXP: 1 use the entire training set VIEW

target = "view"

df["target"] = df[target]
df.loc[df.view == "frontal", "target"] = 1
df.loc[~(df.view=="frontal"), "target"] = 0
display(df.T)

# df.loc[df["target"].isna(), "target"] = 0  # No Finding is 1

display(df[['dicom_id', 'view']].groupby(['view']).count() / len(df))
display(df[['dicom_id', 'target']].groupby(['target']).count() / len(df))

sub_columns = ["study_id", "dicom_id", "view", "target", "split"]
training_set = df.loc[df.split=="train", sub_columns]  # .groupby(["study_id", "target"]).sample(1)
validation_set = df.loc[df.split=="validate", sub_columns]
test_set = df.loc[df.split == "test", sub_columns]

print(f"* training set {len(training_set)}")
print(  training_set[["dicom_id", "target"]].groupby(  ["target"]  ).count() / len(training_set)  )

print(f"* validation set {len(validation_set)}")
print(  validation_set[["dicom_id", "target"]].groupby(  ["target"]  ).count() / len(validation_set)  )

print(f"* test set {len(test_set)}")
print(  test_set[["dicom_id", "target"]].groupby(  ["target"]  ).count() / len(test_set)  )

sub_columns = ["dicom_id", "target", "split"]
dataset = pd.concat(  [training_set[sub_columns], validation_set[sub_columns], test_set[sub_columns]], axis=0  )
print(dataset.shape)

paths = pd.read_csv(filename_records)
display(paths)

dataset = dataset.merge(paths[["dicom_id", "path"]], on="dicom_id", how="left")
display(dataset.T)

out_fld = "/mnt/datasets/mimic-cxr/training_data/mimic"
dataset.to_csv( join(out_fld, "frontal_lateral_mimic.tsv"), sep="\t", index=False)
# Out:
#                                                                                   0       \
# dicom_id                                    02aa804e-bde0afdd-112c0b34-7bc16630-4e384014
# study_id                                                                        50414267
# subject_id                                                                      10000032
# split                                                                              train
# PerformedProcedureStepDescription                                     CHEST (PA AND LAT)
# ViewPosition                                                                          PA
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21800506
# StudyTime                                                                     213014.531
# ProcedureCodeSequence_CodeMeaning                                     CHEST (PA AND LAT)
# ViewCodeSequence_CodeMeaning                                            postero-anterior
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
# view                                                                             frontal
# Atelectasis                                                                          NaN
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        NaN
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         NaN
# No Finding                                                                           1.0
# Pleural Effusion                                                                     NaN
# Pleural Other                                                                        NaN
# Pneumonia                                                                            NaN
# Pneumothorax                                                                         NaN
# Support Devices                                                                      NaN
# has_chexpert_finding                                                               False
# has_chexpert_pos_finding                                                           False
# is_chexpert_normal                                                                  True
# has_chexpert_neg_finding                                                           False
# target                                                                                 1
#
#                                                                                   1       \
# dicom_id                                    174413ec-4ec4c1f7-34ea26b7-c5f994f8-79ef1962
# study_id                                                                        50414267
# subject_id                                                                      10000032
# split                                                                              train
# PerformedProcedureStepDescription                                     CHEST (PA AND LAT)
# ViewPosition                                                                     LATERAL
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21800506
# StudyTime                                                                     213014.531
# ProcedureCodeSequence_CodeMeaning                                     CHEST (PA AND LAT)
# ViewCodeSequence_CodeMeaning                                                     lateral
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
# view                                                                             lateral
# Atelectasis                                                                          NaN
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        NaN
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         NaN
# No Finding                                                                           1.0
# Pleural Effusion                                                                     NaN
# Pleural Other                                                                        NaN
# Pneumonia                                                                            NaN
# Pneumothorax                                                                         NaN
# Support Devices                                                                      NaN
# has_chexpert_finding                                                               False
# has_chexpert_pos_finding                                                           False
# is_chexpert_normal                                                                  True
# has_chexpert_neg_finding                                                           False
# target                                                                                 0
#
#                                                                                   2       \
# dicom_id                                    2a2277a9-b0ded155-c0de8eb9-c124d10e-82c5caab
# study_id                                                                        53189527
# subject_id                                                                      10000032
# split                                                                              train
# PerformedProcedureStepDescription                                     CHEST (PA AND LAT)
# ViewPosition                                                                          PA
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21800626
# StudyTime                                                                     165500.312
# ProcedureCodeSequence_CodeMeaning                                     CHEST (PA AND LAT)
# ViewCodeSequence_CodeMeaning                                            postero-anterior
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
# view                                                                             frontal
# Atelectasis                                                                          NaN
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        NaN
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         NaN
# No Finding                                                                           1.0
# Pleural Effusion                                                                     NaN
# Pleural Other                                                                        NaN
# Pneumonia                                                                            NaN
# Pneumothorax                                                                         NaN
# Support Devices                                                                      NaN
# has_chexpert_finding                                                               False
# has_chexpert_pos_finding                                                           False
# is_chexpert_normal                                                                  True
# has_chexpert_neg_finding                                                           False
# target                                                                                 1
#
#                                                                                   3       \
# dicom_id                                    e084de3b-be89b11e-20fe3f9f-9c8d8dfe-4cfd202c
# study_id                                                                        53189527
# subject_id                                                                      10000032
# split                                                                              train
# PerformedProcedureStepDescription                                     CHEST (PA AND LAT)
# ViewPosition                                                                     LATERAL
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21800626
# StudyTime                                                                     165500.312
# ProcedureCodeSequence_CodeMeaning                                     CHEST (PA AND LAT)
# ViewCodeSequence_CodeMeaning                                                     lateral
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
# view                                                                             lateral
# Atelectasis                                                                          NaN
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        NaN
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         NaN
# No Finding                                                                           1.0
# Pleural Effusion                                                                     NaN
# Pleural Other                                                                        NaN
# Pneumonia                                                                            NaN
# Pneumothorax                                                                         NaN
# Support Devices                                                                      NaN
# has_chexpert_finding                                                               False
# has_chexpert_pos_finding                                                           False
# is_chexpert_normal                                                                  True
# has_chexpert_neg_finding                                                           False
# target                                                                                 0
#
#                                                                                   4       \
# dicom_id                                    68b5c4b1-227d0485-9cc38c3f-7b84ab51-4b472714
# study_id                                                                        53911762
# subject_id                                                                      10000032
# split                                                                              train
# PerformedProcedureStepDescription                                    CHEST (PORTABLE AP)
# ViewPosition                                                                          AP
# Rows                                                                                2705
# Columns                                                                             2539
# StudyDate                                                                       21800723
# StudyTime                                                                      80556.875
# ProcedureCodeSequence_CodeMeaning                                    CHEST (PORTABLE AP)
# ViewCodeSequence_CodeMeaning                                            antero-posterior
# PatientOrientationCodeSequence_CodeMeaning                                           NaN
# view                                                                             frontal
# Atelectasis                                                                          NaN
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        NaN
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         NaN
# No Finding                                                                           1.0
# Pleural Effusion                                                                     NaN
# Pleural Other                                                                        NaN
# Pneumonia                                                                            NaN
# Pneumothorax                                                                         NaN
# Support Devices                                                                      NaN
# has_chexpert_finding                                                               False
# has_chexpert_pos_finding                                                           False
# is_chexpert_normal                                                                  True
# has_chexpert_neg_finding                                                           False
# target                                                                                 1
#
#                                                                                   5       \
# dicom_id                                    fffabebf-74fd3a1f-673b6b41-96ec0ac9-2ab69818
# study_id                                                                        53911762
# subject_id                                                                      10000032
# split                                                                              train
# PerformedProcedureStepDescription                                    CHEST (PORTABLE AP)
# ViewPosition                                                                          AP
# Rows                                                                                2906
# Columns                                                                             2258
# StudyDate                                                                       21800723
# StudyTime                                                                      80556.875
# ProcedureCodeSequence_CodeMeaning                                    CHEST (PORTABLE AP)
# ViewCodeSequence_CodeMeaning                                            antero-posterior
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
# view                                                                             frontal
# Atelectasis                                                                          NaN
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        NaN
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         NaN
# No Finding                                                                           1.0
# Pleural Effusion                                                                     NaN
# Pleural Other                                                                        NaN
# Pneumonia                                                                            NaN
# Pneumothorax                                                                         NaN
# Support Devices                                                                      NaN
# has_chexpert_finding                                                               False
# has_chexpert_pos_finding                                                           False
# is_chexpert_normal                                                                  True
# has_chexpert_neg_finding                                                           False
# target                                                                                 1
#
#                                                                                   6       \
# dicom_id                                    ea030e7a-2e3b1346-bc518786-7a8fd698-f673b44c
# study_id                                                                        56699142
# subject_id                                                                      10000032
# split                                                                              train
# PerformedProcedureStepDescription                                    CHEST (PORTABLE AP)
# ViewPosition                                                                          AP
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21800805
# StudyTime                                                                     234424.765
# ProcedureCodeSequence_CodeMeaning                                    CHEST (PORTABLE AP)
# ViewCodeSequence_CodeMeaning                                            antero-posterior
# PatientOrientationCodeSequence_CodeMeaning                                           NaN
# view                                                                             frontal
# Atelectasis                                                                          NaN
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        NaN
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         NaN
# No Finding                                                                           1.0
# Pleural Effusion                                                                     NaN
# Pleural Other                                                                        NaN
# Pneumonia                                                                            NaN
# Pneumothorax                                                                         NaN
# Support Devices                                                                      NaN
# has_chexpert_finding                                                               False
# has_chexpert_pos_finding                                                           False
# is_chexpert_normal                                                                  True
# has_chexpert_neg_finding                                                           False
# target                                                                                 1
#
#                                                                                   7       \
# dicom_id                                    096052b7-d256dc40-453a102b-fa7d01c6-1b22c6b4
# study_id                                                                        57375967
# subject_id                                                                      10000764
# split                                                                              train
# PerformedProcedureStepDescription                                     CHEST (PA AND LAT)
# ViewPosition                                                                          AP
# Rows                                                                                2544
# Columns                                                                             3056
# StudyDate                                                                       21321015
# StudyTime                                                                      84047.984
# ProcedureCodeSequence_CodeMeaning                                     CHEST (PA AND LAT)
# ViewCodeSequence_CodeMeaning                                            antero-posterior
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
# view                                                                             frontal
# Atelectasis                                                                          NaN
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        1.0
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         NaN
# No Finding                                                                           NaN
# Pleural Effusion                                                                     NaN
# Pleural Other                                                                        NaN
# Pneumonia                                                                           -1.0
# Pneumothorax                                                                         NaN
# Support Devices                                                                      NaN
# has_chexpert_finding                                                                True
# has_chexpert_pos_finding                                                            True
# is_chexpert_normal                                                                 False
# has_chexpert_neg_finding                                                            True
# target                                                                                 1
#
#                                                                                   8       \
# dicom_id                                    b79e55c3-735ce5ac-64412506-cdc9ea79-f1af521f
# study_id                                                                        57375967
# subject_id                                                                      10000764
# split                                                                              train
# PerformedProcedureStepDescription                                     CHEST (PA AND LAT)
# ViewPosition                                                                     LATERAL
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21321015
# StudyTime                                                                      84047.984
# ProcedureCodeSequence_CodeMeaning                                     CHEST (PA AND LAT)
# ViewCodeSequence_CodeMeaning                                                     lateral
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
# view                                                                             lateral
# Atelectasis                                                                          NaN
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        1.0
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         NaN
# No Finding                                                                           NaN
# Pleural Effusion                                                                     NaN
# Pleural Other                                                                        NaN
# Pneumonia                                                                           -1.0
# Pneumothorax                                                                         NaN
# Support Devices                                                                      NaN
# has_chexpert_finding                                                                True
# has_chexpert_pos_finding                                                            True
# is_chexpert_normal                                                                 False
# has_chexpert_neg_finding                                                            True
# target                                                                                 0
#
#                                                                                   9       \
# dicom_id                                    dcfeeac4-1597e318-d0e6736a-8b2c2238-47ac3f1b
# study_id                                                                        57375967
# subject_id                                                                      10000764
# split                                                                              train
# PerformedProcedureStepDescription                                     CHEST (PA AND LAT)
# ViewPosition                                                                     LATERAL
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21321015
# StudyTime                                                                      84047.984
# ProcedureCodeSequence_CodeMeaning                                     CHEST (PA AND LAT)
# ViewCodeSequence_CodeMeaning                                                     lateral
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
# view                                                                             lateral
# Atelectasis                                                                          NaN
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        1.0
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         NaN
# No Finding                                                                           NaN
# Pleural Effusion                                                                     NaN
# Pleural Other                                                                        NaN
# Pneumonia                                                                           -1.0
# Pneumothorax                                                                         NaN
# Support Devices                                                                      NaN
# has_chexpert_finding                                                                True
# has_chexpert_pos_finding                                                            True
# is_chexpert_normal                                                                 False
# has_chexpert_neg_finding                                                            True
# target                                                                                 0
#
#                                             ...  \
# dicom_id                                    ...
# study_id                                    ...
# subject_id                                  ...
# split                                       ...
# PerformedProcedureStepDescription           ...
# ViewPosition                                ...
# Rows                                        ...
# Columns                                     ...
# StudyDate                                   ...
# StudyTime                                   ...
# ProcedureCodeSequence_CodeMeaning           ...
# ViewCodeSequence_CodeMeaning                ...
# PatientOrientationCodeSequence_CodeMeaning  ...
# view                                        ...
# Atelectasis                                 ...
# Cardiomegaly                                ...
# Consolidation                               ...
# Edema                                       ...
# Enlarged Cardiomediastinum                  ...
# Fracture                                    ...
# Lung Lesion                                 ...
# Lung Opacity                                ...
# No Finding                                  ...
# Pleural Effusion                            ...
# Pleural Other                               ...
# Pneumonia                                   ...
# Pneumothorax                                ...
# Support Devices                             ...
# has_chexpert_finding                        ...
# has_chexpert_pos_finding                    ...
# is_chexpert_normal                          ...
# has_chexpert_neg_finding                    ...
# target                                      ...
#
#                                                                                   361316  \
# dicom_id                                    2eb70dfe-52fa728e-a36e09be-ec0ed3cf-0a2ea7f0
# study_id                                                                        58938059
# subject_id                                                                      19999287
# split                                                                              train
# PerformedProcedureStepDescription                                    CHEST (PORTABLE AP)
# ViewPosition                                                                          AP
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21970805
# StudyTime                                                                      93746.343
# ProcedureCodeSequence_CodeMeaning                                    CHEST (PORTABLE AP)
# ViewCodeSequence_CodeMeaning                                            antero-posterior
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
# view                                                                             frontal
# Atelectasis                                                                          NaN
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        NaN
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         1.0
# No Finding                                                                           NaN
# Pleural Effusion                                                                     NaN
# Pleural Other                                                                        NaN
# Pneumonia                                                                            NaN
# Pneumothorax                                                                         NaN
# Support Devices                                                                      NaN
# has_chexpert_finding                                                                True
# has_chexpert_pos_finding                                                            True
# is_chexpert_normal                                                                 False
# has_chexpert_neg_finding                                                           False
# target                                                                                 1
#
#                                                                                   361317  \
# dicom_id                                    53e9b6d0-5d5317f5-f1a4c031-01d40558-fd14a425
# study_id                                                                        57540554
# subject_id                                                                      19999376
# split                                                                              train
# PerformedProcedureStepDescription                                    CHEST (PORTABLE AP)
# ViewPosition                                                                          AP
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21450731
# StudyTime                                                                      45417.656
# ProcedureCodeSequence_CodeMeaning                                    CHEST (PORTABLE AP)
# ViewCodeSequence_CodeMeaning                                            antero-posterior
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
# view                                                                             frontal
# Atelectasis                                                                          NaN
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        NaN
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         NaN
# No Finding                                                                           1.0
# Pleural Effusion                                                                     NaN
# Pleural Other                                                                        NaN
# Pneumonia                                                                            NaN
# Pneumothorax                                                                         NaN
# Support Devices                                                                      NaN
# has_chexpert_finding                                                               False
# has_chexpert_pos_finding                                                           False
# is_chexpert_normal                                                                  True
# has_chexpert_neg_finding                                                           False
# target                                                                                 1
#
#                                                                                   361318  \
# dicom_id                                    ee9155f3-944c056b-c76c73d0-3f792f2c-92ae461e
# study_id                                                                        58497551
# subject_id                                                                      19999442
# split                                                                              train
# PerformedProcedureStepDescription                                    CHEST (PORTABLE AP)
# ViewPosition                                                                          AP
# Rows                                                                                2544
# Columns                                                                             3056
# StudyDate                                                                       21481128
# StudyTime                                                                     133244.093
# ProcedureCodeSequence_CodeMeaning                                    CHEST (PORTABLE AP)
# ViewCodeSequence_CodeMeaning                                            antero-posterior
# PatientOrientationCodeSequence_CodeMeaning                                           NaN
# view                                                                             frontal
# Atelectasis                                                                          1.0
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        NaN
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         1.0
# No Finding                                                                           NaN
# Pleural Effusion                                                                    -1.0
# Pleural Other                                                                        NaN
# Pneumonia                                                                            NaN
# Pneumothorax                                                                         0.0
# Support Devices                                                                      NaN
# has_chexpert_finding                                                                True
# has_chexpert_pos_finding                                                            True
# is_chexpert_normal                                                                 False
# has_chexpert_neg_finding                                                            True
# target                                                                                 1
#
#                                                                                   361319  \
# dicom_id                                    16b6c70f-6d36bd77-89d2fef4-9c4b8b0a-79c69135
# study_id                                                                        58708861
# subject_id                                                                      19999442
# split                                                                              train
# PerformedProcedureStepDescription                                    CHEST (PORTABLE AP)
# ViewPosition                                                                          AP
# Rows                                                                                2544
# Columns                                                                             3056
# StudyDate                                                                       21481119
# StudyTime                                                                     224703.375
# ProcedureCodeSequence_CodeMeaning                                    CHEST (PORTABLE AP)
# ViewCodeSequence_CodeMeaning                                            antero-posterior
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
# view                                                                             frontal
# Atelectasis                                                                          NaN
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        NaN
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         NaN
# No Finding                                                                           1.0
# Pleural Effusion                                                                     NaN
# Pleural Other                                                                        NaN
# Pneumonia                                                                            NaN
# Pneumothorax                                                                         NaN
# Support Devices                                                                      1.0
# has_chexpert_finding                                                                True
# has_chexpert_pos_finding                                                            True
# is_chexpert_normal                                                                  True
# has_chexpert_neg_finding                                                           False
# target                                                                                 1
#
#                                                                                   361320  \
# dicom_id                                    3fcd0406-9b111603-feae7033-96632b3a-111333e5
# study_id                                                                        57132437
# subject_id                                                                      19999733
# split                                                                              train
# PerformedProcedureStepDescription                                     CHEST (PA AND LAT)
# ViewPosition                                                                          PA
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21520708
# StudyTime                                                                     224550.171
# ProcedureCodeSequence_CodeMeaning                                     CHEST (PA AND LAT)
# ViewCodeSequence_CodeMeaning                                            postero-anterior
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
# view                                                                             frontal
# Atelectasis                                                                          NaN
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        NaN
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         NaN
# No Finding                                                                           1.0
# Pleural Effusion                                                                     NaN
# Pleural Other                                                                        NaN
# ...
# Lung Lesion                                                                          0.0
# Lung Opacity                                                                         NaN
# No Finding                                                                           NaN
# Pleural Effusion                                                                     0.0
# Pleural Other                                                                        NaN
# Pneumonia                                                                            NaN
# Pneumothorax                                                                         0.0
# Support Devices                                                                      NaN
# has_chexpert_finding                                                                True
# has_chexpert_pos_finding                                                            True
# is_chexpert_normal                                                                 False
# has_chexpert_neg_finding                                                            True
# target                                                                                 1
#
#                                                                                   361324  \
# dicom_id                                    7ba273af-3d290f8d-e28d0ab4-484b7a86-7fc12b08
# study_id                                                                        58621812
# subject_id                                                                      19999987
# split                                                                              train
# PerformedProcedureStepDescription                                    CHEST (PORTABLE AP)
# ViewPosition                                                                          AP
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21451102
# StudyTime                                                                     202809.234
# ProcedureCodeSequence_CodeMeaning                                    CHEST (PORTABLE AP)
# ViewCodeSequence_CodeMeaning                                            antero-posterior
# PatientOrientationCodeSequence_CodeMeaning                                         Erect
# view                                                                             frontal
# Atelectasis                                                                          1.0
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        NaN
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         NaN
# No Finding                                                                           NaN
# Pleural Effusion                                                                     NaN
# Pleural Other                                                                        NaN
# Pneumonia                                                                            NaN
# Pneumothorax                                                                         NaN
# Support Devices                                                                      1.0
# has_chexpert_finding                                                                True
# has_chexpert_pos_finding                                                            True
# is_chexpert_normal                                                                 False
# has_chexpert_neg_finding                                                           False
# target                                                                                 1
#
#                                                                                   361325
# dicom_id                                    1a1fe7e3-cbac5d93-b339aeda-86bb86b5-4f31e82e
# study_id                                                                        58971208
# subject_id                                                                      19999987
# split                                                                              train
# PerformedProcedureStepDescription                                    CHEST (PORTABLE AP)
# ViewPosition                                                                          AP
# Rows                                                                                3056
# Columns                                                                             2544
# StudyDate                                                                       21451103
# StudyTime                                                                      50507.625
# ProcedureCodeSequence_CodeMeaning                                    CHEST (PORTABLE AP)
# ViewCodeSequence_CodeMeaning                                            antero-posterior
# PatientOrientationCodeSequence_CodeMeaning                                     Recumbent
# view                                                                             frontal
# Atelectasis                                                                          1.0
# Cardiomegaly                                                                         NaN
# Consolidation                                                                        NaN
# Edema                                                                                NaN
# Enlarged Cardiomediastinum                                                           NaN
# Fracture                                                                             NaN
# Lung Lesion                                                                          NaN
# Lung Opacity                                                                         NaN
# No Finding                                                                           NaN
# Pleural Effusion                                                                     NaN
# Pleural Other                                                                        NaN
# Pneumonia                                                                            NaN
# Pneumothorax                                                                         NaN
# Support Devices                                                                      NaN
# has_chexpert_finding                                                                True
# has_chexpert_pos_finding                                                            True
# is_chexpert_normal                                                                 False
# has_chexpert_neg_finding                                                           False
# target                                                                                 1
#
# [33 rows x 361326 columns]
#          dicom_id
# view
# frontal  0.673456
# lateral  0.326544
#         dicom_id
# target
# 0       0.326544
# 1       0.673456
# * training set 353622
#         dicom_id
# target
# 0       0.327041
# 1       0.672959
# * validation set 2867
#         dicom_id
# target
# 0       0.316707
# 1       0.683293
# * test set 4837
#         dicom_id
# target
# 0       0.296051
# 1       0.703949
# (361326, 3)
#         subject_id  study_id                                      dicom_id  \
# 0         10000032  50414267  02aa804e-bde0afdd-112c0b34-7bc16630-4e384014
# 1         10000032  50414267  174413ec-4ec4c1f7-34ea26b7-c5f994f8-79ef1962
# 2         10000032  53189527  2a2277a9-b0ded155-c0de8eb9-c124d10e-82c5caab
# 3         10000032  53189527  e084de3b-be89b11e-20fe3f9f-9c8d8dfe-4cfd202c
# 4         10000032  53911762  68b5c4b1-227d0485-9cc38c3f-7b84ab51-4b472714
# ...            ...       ...                                           ...
# 377105    19999733  57132437  428e2c18-5721d8f3-35a05001-36f3d080-9053b83c
# 377106    19999733  57132437  58c403aa-35ff8bd9-73e39f54-8dc9cc5d-e0ec3fa9
# 377107    19999987  55368167  58766883-376a15ce-3b323a28-6af950a0-16b793bd
# 377108    19999987  58621812  7ba273af-3d290f8d-e28d0ab4-484b7a86-7fc12b08
# 377109    19999987  58971208  1a1fe7e3-cbac5d93-b339aeda-86bb86b5-4f31e82e
#
#                                                      path
# 0       files/p10/p10000032/s50414267/02aa804e-bde0afd...
# 1       files/p10/p10000032/s50414267/174413ec-4ec4c1f...
# 2       files/p10/p10000032/s53189527/2a2277a9-b0ded15...
# 3       files/p10/p10000032/s53189527/e084de3b-be89b11...
# 4       files/p10/p10000032/s53911762/68b5c4b1-227d048...
# ...                                                   ...
# 377105  files/p19/p19999733/s57132437/428e2c18-5721d8f...
# 377106  files/p19/p19999733/s57132437/58c403aa-35ff8bd...
# 377107  files/p19/p19999987/s55368167/58766883-376a15c...
# 377108  files/p19/p19999987/s58621812/7ba273af-3d290f8...
# 377109  files/p19/p19999987/s58971208/1a1fe7e3-cbac5d9...
#
# [377110 rows x 4 columns]
#                                                      0       \
# dicom_id       02aa804e-bde0afdd-112c0b34-7bc16630-4e384014
# target                                                    1
# split                                                 train
# path      files/p10/p10000032/s50414267/02aa804e-bde0afd...
#
#                                                      1       \
# dicom_id       174413ec-4ec4c1f7-34ea26b7-c5f994f8-79ef1962
# target                                                    0
# split                                                 train
# path      files/p10/p10000032/s50414267/174413ec-4ec4c1f...
#
#                                                      2       \
# dicom_id       2a2277a9-b0ded155-c0de8eb9-c124d10e-82c5caab
# target                                                    1
# split                                                 train
# path      files/p10/p10000032/s53189527/2a2277a9-b0ded15...
#
#                                                      3       \
# dicom_id       e084de3b-be89b11e-20fe3f9f-9c8d8dfe-4cfd202c
# target                                                    0
# split                                                 train
# path      files/p10/p10000032/s53189527/e084de3b-be89b11...
#
#                                                      4       \
# dicom_id       68b5c4b1-227d0485-9cc38c3f-7b84ab51-4b472714
# target                                                    1
# split                                                 train
# path      files/p10/p10000032/s53911762/68b5c4b1-227d048...
#
#                                                      5       \
# dicom_id       fffabebf-74fd3a1f-673b6b41-96ec0ac9-2ab69818
# target                                                    1
# split                                                 train
# path      files/p10/p10000032/s53911762/fffabebf-74fd3a1...
#
#                                                      6       \
# dicom_id       ea030e7a-2e3b1346-bc518786-7a8fd698-f673b44c
# target                                                    1
# split                                                 train
# path      files/p10/p10000032/s56699142/ea030e7a-2e3b134...
#
#                                                      7       \
# dicom_id       096052b7-d256dc40-453a102b-fa7d01c6-1b22c6b4
# target                                                    1
# split                                                 train
# path      files/p10/p10000764/s57375967/096052b7-d256dc4...
#
#                                                      8       \
# dicom_id       b79e55c3-735ce5ac-64412506-cdc9ea79-f1af521f
# target                                                    0
# split                                                 train
# path      files/p10/p10000764/s57375967/b79e55c3-735ce5a...
#
#                                                      9       ...  \
# dicom_id       dcfeeac4-1597e318-d0e6736a-8b2c2238-47ac3f1b  ...
# target                                                    0  ...
# split                                                 train  ...
# path      files/p10/p10000764/s57375967/dcfeeac4-1597e31...  ...
#
#                                                      361316  \
# dicom_id       ebe1c050-b5cd68d5-7eb2b544-8906f022-e95300a4
# target                                                    1
# split                                                  test
# path      files/p19/p19991135/s56918032/ebe1c050-b5cd68d...
#
#                                                      361317  \
# dicom_id       3616a226-c86c9ea2-733dbb59-4b1530a0-ba7b25dc
# target                                                    0
# split                                                  test
# path      files/p19/p19991135/s57096024/3616a226-c86c9ea...
#
#                                                      361318  \
# dicom_id       4998e40c-698af874-8c293856-85757f55-1a4817e4
# target                                                    1
# split                                                  test
# path      files/p19/p19991135/s57096024/4998e40c-698af87...
#
#                                                      361319  \
# dicom_id       6e57e7d7-a4f8c909-e7540997-0280112e-14da108f
# target                                                    0
# split                                                  test
# path      files/p19/p19991135/s57096024/6e57e7d7-a4f8c90...
#
#                                                      361320  \
# dicom_id       727e2aa5-ddfdd2ff-b5723867-520a758e-c81ca8e2
# target                                                    1
# split                                                  test
# path      files/p19/p19991135/s57757467/727e2aa5-ddfdd2f...
#
#                                                      361321  \
# dicom_id       313f1d75-23648c34-dd36ecad-5d0f94e8-93a40356
# target                                                    1
# split                                                  test
# path      files/p19/p19991135/s58283482/313f1d75-23648c3...
#
#                                                      361322  \
# dicom_id       4d0251eb-cc875c55-fde85f43-3a9d7888-c62772b8
# target                                                    1
# split                                                  test
# path      files/p19/p19991135/s58283482/4d0251eb-cc875c5...
#
#                                                      361323  \
# dicom_id       f6a7a470-9e057a45-d244e0e5-3efe1422-bb946478
# target                                                    1
# split                                                  test
# path      files/p19/p19991135/s58283482/f6a7a470-9e057a4...
#
#                                                      361324  \
# dicom_id       43636aec-98ae2504-18f03cac-4fe8e211-62049c6d
# target                                                    0
# split                                                  test
# path      files/p19/p19991135/s59381316/43636aec-98ae250...
#
#                                                      361325
# dicom_id       d122eb74-bc404dd2-45a05cd3-18505b72-5058fbdd
# target                                                    1
# split                                                  test
# path      files/p19/p19991135/s59381316/d122eb74-bc404dd...
#
# [4 rows x 361326 columns]

# %%
# TODO : EXP: MIMIC, balance normal vs other (TODO)
target = "No Finding"

df["target"] = df[target]
df.loc[df["target"].isna(), "target"] = 0  # No Finding is 1

display(df[['dicom_id', 'view']].groupby(['view']).count() / len(df))
display(df[['dicom_id', 'target']].groupby(['target']).count() / len(df))

sub_columns = ["study_id", "dicom_id", "view", "target", "split"]
training_set = df.loc[df.split=="train", sub_columns]  # .groupby(["study_id", "target"]).sample(1)

validation_set = df.loc[df.split=="validate", sub_columns]
test_set = df.loc[df.split == "test", sub_columns]

print(f"* training set {len(training_set)}")
print(  training_set[["dicom_id", "target"]].groupby(  ["target"]  ).count() / len(training_set)  )

print(f"* validation set {len(validation_set)}")
print(  validation_set[["dicom_id", "target"]].groupby(  ["target"]  ).count() / len(validation_set)  )

print(f"* test set {len(test_set)}")
print(  test_set[["dicom_id", "target"]].groupby(  ["target"]  ).count() / len(test_set)  )

sub_columns = ["dicom_id", "target", "split"]
dataset = pd.concat(  [training_set[sub_columns], validation_set[sub_columns], test_set[sub_columns]], axis=0  )
print(dataset.shape)

paths = pd.read_csv(filename_records)
display(paths)

dataset = dataset.merge(paths[["dicom_id", "path"]], on="dicom_id", how="left")
display(dataset.T)

out_fld = "/mnt/datasets/mimic-cxr/training_data/mimic"
dataset.to_csv( join(out_fld, "normal_bin_unbal.tsv"), sep="\t", index=False)

# %%
# EXP: 1 use the entire training set, V I E W

target = "No Finding"

df["target"] = df[target]
df.loc[df["target"].isna(), "target"] = 0  # No Finding is 1

display(df[['dicom_id', 'view']].groupby(['view']).count() / len(df))
display(df[['dicom_id', 'target']].groupby(['target']).count() / len(df))

sub_columns = ["study_id", "dicom_id", "view", "target", "split"]
training_set = df.loc[df.split=="train", sub_columns]  # .groupby(["study_id", "target"]).sample(1)
validation_set = df.loc[df.split=="validate", sub_columns]
test_set = df.loc[df.split == "test", sub_columns]

print(f"* training set {len(training_set)}")
print(  training_set[["dicom_id", "target"]].groupby(  ["target"]  ).count() / len(training_set)  )

print(f"* validation set {len(validation_set)}")
print(  validation_set[["dicom_id", "target"]].groupby(  ["target"]  ).count() / len(validation_set)  )

print(f"* test set {len(test_set)}")
print(  test_set[["dicom_id", "target"]].groupby(  ["target"]  ).count() / len(test_set)  )

sub_columns = ["dicom_id", "target", "split"]
dataset = pd.concat(  [training_set[sub_columns], validation_set[sub_columns], test_set[sub_columns]], axis=0  )
print(dataset.shape)

paths = pd.read_csv(filename_records)
display(paths)

dataset = dataset.merge(paths[["dicom_id", "path"]], on="dicom_id", how="left")
display(dataset.T)

out_fld = "/mnt/datasets/mimic-cxr/training_data/mimic"
dataset.to_csv( join(out_fld, "normal_bin_unbal.tsv"), sep="\t", index=False)

# %% [markdown]
# <font color="yellow">unbalanced training sets</font>
# 50%-50% normal vs rest

# %%
# No-finding vs rest
# encoding no_finding = 1, with_findings = 1
# 1 image per dicom study: either training or validation study
# test set untouched (so not balanced)

# we now have one image per available view for each study

# %%
import numpy as np
import pandas as pd

values = [[np.nan, 1], [np.nan, 1], [1, 1], [np.nan, 1], [3, 2]]
df = pd.DataFrame(data=values, columns=["A", "B"])
print(df)
df["A"].where(~df["A"].isna(), 0, inplace=True)

print(df)

# %%
# validation set
splits = ["validate", "test"]
d = df.loc[df.split.isin(splits), ["split", "dicom_id", "study_id", "view"]]
d = d.merge(cx, on="study_id", how="left")
for p in splits:
    partitions[p] = d[d.split==p].where(~d["No Finding"].isna(), 0)
for p in partitions:
    print(p)
    display(partitions[p].T)

# %%
# add labels for chexpert
display(d)
display(cx)
display(d)

# %%
display(d.T)

# %% [markdown]
# <font color="yellow">STATS ABOUT HAS_FINDING</font>

# %%
splits = ['train', 'validate', 'test']
split_views = df.groupby(['split', 'view'])[['dicom_id']].count()
row_idx = ['frontal', 'lateral']  #, 'other'] other removed

# number of images in each set
n_images = {}
for c in splits:
    n_images[c] = split_views.loc[c].loc[row_idx, 'dicom_id'].sum()

tbl = pd.DataFrame.from_dict(n_images, orient='index')
tbl.columns = ['Number of images']
tbl = tbl.T
display(tbl)

# number of images in each set for each view
n_images = {}
for c in splits:
    n_images[c] = {}
    for view in row_idx:
        n_images[c][view] = split_views.loc[c].loc[view, 'dicom_id']
n_images = pd.DataFrame.from_dict(n_images, orient='index')
display(n_images)
n_images = n_images.T
display(n_images)

# convert frontal/lateral/other into "N (%)"
for i in n_images.index:
    for c in splits:
        val = n_images.loc[i, c]
        n_images.loc[i, c] = f'{val} ({100.0*val/tbl.loc["Number of images", c]:3.1f}%)'

tbl = pd.concat([tbl, n_images], axis=0, sort=False)

# add in the number of subjects
n_studies = df.groupby('split')[['study_id']].nunique().T
n_studies.index = ['Number of studies']
tbl = pd.concat([tbl, n_studies], axis=0, sort=False)

# studies with a finding
n_studies = df.loc[df['has_chexpert_finding']].groupby('split')[['study_id']].nunique().T
n_studies.index = ['  with a finding']
for c in splits:
    val = n_studies.loc['  with a finding', c]
    n_studies.loc['  with a finding', c] = f'{val} ({100.0*val/tbl.loc["Number of studies", c]:3.1f}%)'
tbl = pd.concat([tbl, n_studies], axis=0, sort=False)

# patients
n_pt = df.groupby('split')[['subject_id']].nunique().T
n_pt.index = ['Number of patients']
tbl = pd.concat([tbl, n_pt], axis=0, sort=False)

# patients with a finding
n_studies = df.loc[df['has_chexpert_finding']].groupby('split')[['subject_id']].nunique().T
n_studies.index = ['  with a finding']
for c in splits:
    val = n_studies.loc['  with a finding', c]
    n_studies.loc['  with a finding', c] = f'{val} ({100.0*val/tbl.loc["Number of patients", c]:3.1f}%)'
tbl = pd.concat([tbl, n_studies], axis=0, sort=False)

# tbl.to_latex('table2.tex')

display(tbl)

# %% [markdown]
# <font color="yellow">AGREEMENT</font>

# %%
nb = pd.read_csv(filename_negbio)
cx = pd.read_csv(filename_chexpert)

# merge these findings to create a table
# both agree -> output label
# disagree -> output -9

# drop subject_id from cx - we have it in nb
df = cx.merge(
    nb.drop('subject_id', axis=1),
    how='left',
    left_on='study_id', right_on='study_id',
    suffixes=('', '_nb')
)

# subselect to training set
study_ids = set(df_split.loc[df_split['split']=='train', 'study_id'])
df = df.loc[df['study_id'].isin(study_ids)]

# replace numeric labels with meaningful labels
# also annotate disagreements between the two labelers
labels = {0: 'Negative', 1: 'Positive', -1: 'Uncertain', -9: 'Disagreement'}
for c in df.columns:
    if c in ('subject_id', 'study_id'):
        continue
    elif c.endswith('_nb'):
        continue
    
    # chexpert column
    c_nb = f'{c}_nb'
    
    # annotate disagreement
    for val in labels.keys():
        if val == -9:
            continue
        
        # check one is null and the other isn't
        idx = df[c].isnull() & df[c_nb].notnull()
        df.loc[idx, c] = -9
        
        idx = df[c].notnull() & df[c_nb].isnull()
        df.loc[idx, c] = -9
        
        # check both non-null, but different value
        idx = df[c].notnull() & df[c_nb].notnull() & (df[c] != df[c_nb])
        df.loc[idx, c] = -9
        
    # now for those missing in chexpert
    idx = df[c].isnull() & df[f'{c}_nb'].notnull()
    df.loc[idx, c] = -9
    
    df[c] = df[c].map(labels)
    
# drop chexpert columns
cols_drop = [c for c in df.columns if c.endswith('_nb')]
df.drop(cols_drop, axis=1, inplace=True)

# display a few example cases
display(df.head(n=10))

# create a summary table of the findings
grp_cols = [c for c in df.columns if c not in ('subject_id', 'study_id')]
tbl = {}
for c in grp_cols:
    tbl[c] = df[c].value_counts().to_dict()
tbl = pd.DataFrame.from_dict(tbl, orient='index')


# pretty format the labels
N = df.shape[0]
for c in tbl.columns:
    tbl[c] = tbl[c].apply(lambda x: f'{x:,} ({100.0*x/N:3.1f}%)')

# sort columns
print(f'Frequency of labels in MIMIC-CXR-JPG on the training subset of {df.shape[0]:,} unique radiologic studies.')
tbl = tbl[['Positive', 'Negative', 'Uncertain', 'Disagreement']]
# tbl.to_latex('findings_frequency.tex')
tbl

# %%
df = pd.read_csv(filename_records, header=0, sep=',')

sections = pd.read_csv(filename_sections)

print(sections.columns)
N = df['study_id'].nunique()
print(f'Of the total {N:,} reports.. ')
idx = sections['study'].notnull()
for c in ['impression', 'findings', 'last_paragraph']:
    n = sections.loc[idx, c].count()
    print(f'  {n:,} ({100.0*n/N:3.1f}%) had a {c} section')
    # limit next check to only rows where this section is null
    idx = idx & sections[c].isnull()



# ! code from github ends here

# %% [markdown]
# <font color="red">my code</font>

# %%
# from dcm: read all files
ds = pd.read_csv(filename_records).set_index(["subject_id", "study_id"])
print("record list - from dcm, shape:", ds.shape)
display(ds)

# from jpg
metadata = pd.read_csv( join(jpg_fld, "mimic-cxr-2.0.0-metadata.csv") ).set_index(["subject_id", "study_id"])
print("metadata - from jpg, shape:", metadata.shape)
display(metadata)


# jpg

# %% [markdown]
# display some images

# %%
vp = metadata.ViewPosition
print(vp.value_counts())
ds["ViewPosition"] = vp

display(ds)

# print("PA")
# pa = ds.loc[ds.ViewPosition == "PA", ["path"]]
# fns = pa.iloc[[0,1,2]].path
# for fn in fns:
#     fn = fn.replace(".dcm", ".jpg")
#     display(Image( join(jpg_fld, fn), width=224, height=224))

# print("AP")
# pa = ds.loc[ds.ViewPosition == "AP", ["path"]]
# fns = pa.iloc[[0,1,2]].path
# for fn in fns:
#     fn = fn.replace(".dcm", ".jpg")
#     display(Image( join(jpg_fld, fn), width=224, height=224))

# print("LATERAL")
# pa = ds.loc[ds.ViewPosition == "LATERAL", ["path"]]
# fns = pa.iloc[[0,1,2]].path
# for fn in fns:
#     fn = fn.replace(".dcm", ".jpg")
#     display(Image( join(jpg_fld, fn), width=224, height=224))

# print("XTABLE LATERAL")
# pa = ds.loc[ds.ViewPosition == "XTABLE LATERAL", ["path"]]
# print(len(pa))
# fns = pa.iloc[[0,1]].path
# for fn in fns:
#     fn = fn.replace(".dcm", ".jpg")
#     display(Image( join(jpg_fld, fn), width=224, height=224))

print("LL")
pa = ds.loc[ds.ViewPosition == "LL", ["path"]]
print(len(pa))
fns = pa.iloc[[10,20]].path
for fn in fns:
    fn = fn.replace(".dcm", ".jpg")
    display(Image( join(jpg_fld, fn), width=224, height=224))

# %% [markdown]
# - add column with labels
# - add column with text

# %% [markdown]
# Read labels from chexpert/negbio in jpg folder
# for each label
# - +1 means positive mention
# - -1 means negative mention
# - 0 means uncertainty in the mention

# %%
# jpg
chexpert = pd.read_csv( join(jpg_fld, "mimic-cxr-2.0.0-chexpert.csv"), na_filter=False).set_index(["subject_id", "study_id"])
print("chexpert - from jpg, shape:", chexpert.shape)
display(chexpert)

columns = chexpert.columns
print(f"n labels: {len(columns)}")

# %% [markdown]
# There are several strategies for managing the uncertain label (zero), as suggested by the authors themselves:
# - U-Ignore: We ignore the uncertain labels during training.
# - U-Zeroes: We map all instances of the uncertain label to 0.
# - U-Ones: We map all instances of the uncertain label to 1.
# - U-SelfTrained: We first train a model using the U-Ignore approach to convergence, and then use the model to make predictions that re-label each of the uncertainty labels with the probability prediction outputted by the model.
# - U-MultiClass: We treat the uncertainty label as its own class.
#
# U-Ignore selected
