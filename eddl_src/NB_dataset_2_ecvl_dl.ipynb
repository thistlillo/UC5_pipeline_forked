# %%
import numpy as np
import pandas as pd
import os
from posixpath import join
import yaml

# %%
def ecvl_yaml(name, description, filenames, labels, train_ids, valid_ids, test_ids):
    d = {
        "name"        : name,
        "description" : description,
        "classes"     : [], 
        "images"      : [],
        "split"       : dict(training = train_ids, 
                            validation = valid_ids, 
                            test=test_ids)
    }
    imgs = []
    for fn, l in zip(filenames, labels):
        imgs.append({
            "location": fn,
            "label": l
        })
    d["images"] = imgs
    d["classes"] = sorted(list(set(labels)))
    return d

# %%
# mimic normal vs rest, unbalanced
# 3 models, dataset stays the same, random seed changes

in_file = join("/mnt/datasets/mimic-cxr/training_data/mimic", "normal_bin_unbal.tsv")  # input dataset
exp_fld = "/mnt/datasets/uc5/UC5_pipeline_forked/experiments_eddl/mimic/normal_unbal"  # output fld
img_fld = "/mnt/datasets/mimic-cxr/mimic-cxr-jpg/physionet.org/files/mimic-cxr-jpg/2.0.0"

dataset = pd.read_csv(in_file, sep="\t")
def adjust_path(path):
    path = path[:-len(".dcm")]
    path = join(img_fld, path + ".jpg")
    return path
display(dataset.T)

dataset["path"] = dataset["path"].apply(lambda path: adjust_path(path))
dataset = dataset.reset_index().set_index(pd.RangeIndex(len(dataset)))
splits = ["train", "validate", "test"]
filenames = []
labels = []
ids = {}
for s in splits:
    split = dataset.loc[dataset.split == s]
    print(f"{s}: {split.shape}")
    filenames += split.path.tolist()
    labels += split.target.tolist()
    ids[s] = split.index.values.tolist()
print(f"filenames, {len(filenames)}")
print(f"labels, {len(labels)}")

print(f"train:", len(ids["train"]))
print(f"validate:", len(ids["validate"]))
print(f"test:", len(ids["test"]))

yml_ds = ecvl_yaml(filenames, labels, ids["train"], ids["validate"], ids["test"])
for k, v in yml_ds.items():
    print(f"{k}: {len(v)}")

n_folds = 3
for i in range(n_folds):
    out_fld = join(  exp_fld, f"fold_{i}" )
    os.makedirs(out_fld, exist_ok=True)
    fn = join(out_fld, "dataset.yml")
    
    with open(fn, "w") as fout:
        yaml.safe_dump(yml_ds, fout, default_flow_style=None)
    print(f"saved {fn}")
#     # takes up to
# Out:
#                                                      0       \
# dicom_id       02aa804e-bde0afdd-112c0b34-7bc16630-4e384014
# target                                                  1.0
# split                                                 train
# path      files/p10/p10000032/s50414267/02aa804e-bde0afd...
#
#                                                      1       \
# dicom_id       174413ec-4ec4c1f7-34ea26b7-c5f994f8-79ef1962
# target                                                  1.0
# split                                                 train
# path      files/p10/p10000032/s50414267/174413ec-4ec4c1f...
#
#                                                      2       \
# dicom_id       2a2277a9-b0ded155-c0de8eb9-c124d10e-82c5caab
# target                                                  1.0
# split                                                 train
# path      files/p10/p10000032/s53189527/2a2277a9-b0ded15...
#
#                                                      3       \
# dicom_id       e084de3b-be89b11e-20fe3f9f-9c8d8dfe-4cfd202c
# target                                                  1.0
# split                                                 train
# path      files/p10/p10000032/s53189527/e084de3b-be89b11...
#
#                                                      4       \
# dicom_id       68b5c4b1-227d0485-9cc38c3f-7b84ab51-4b472714
# target                                                  1.0
# split                                                 train
# path      files/p10/p10000032/s53911762/68b5c4b1-227d048...
#
#                                                      5       \
# dicom_id       fffabebf-74fd3a1f-673b6b41-96ec0ac9-2ab69818
# target                                                  1.0
# split                                                 train
# path      files/p10/p10000032/s53911762/fffabebf-74fd3a1...
#
#                                                      6       \
# dicom_id       ea030e7a-2e3b1346-bc518786-7a8fd698-f673b44c
# target                                                  1.0
# split                                                 train
# path      files/p10/p10000032/s56699142/ea030e7a-2e3b134...
#
#                                                      7       \
# dicom_id       096052b7-d256dc40-453a102b-fa7d01c6-1b22c6b4
# target                                                  0.0
# split                                                 train
# path      files/p10/p10000764/s57375967/096052b7-d256dc4...
#
#                                                      8       \
# dicom_id       b79e55c3-735ce5ac-64412506-cdc9ea79-f1af521f
# target                                                  0.0
# split                                                 train
# path      files/p10/p10000764/s57375967/b79e55c3-735ce5a...
#
#                                                      9       ...  \
# dicom_id       dcfeeac4-1597e318-d0e6736a-8b2c2238-47ac3f1b  ...
# target                                                  0.0  ...
# split                                                 train  ...
# path      files/p10/p10000764/s57375967/dcfeeac4-1597e31...  ...
#
#                                                      361316  \
# dicom_id       ebe1c050-b5cd68d5-7eb2b544-8906f022-e95300a4
# target                                                  0.0
# split                                                  test
# path      files/p19/p19991135/s56918032/ebe1c050-b5cd68d...
#
#                                                      361317  \
# dicom_id       3616a226-c86c9ea2-733dbb59-4b1530a0-ba7b25dc
# target                                                  0.0
# split                                                  test
# path      files/p19/p19991135/s57096024/3616a226-c86c9ea...
#
#                                                      361318  \
# dicom_id       4998e40c-698af874-8c293856-85757f55-1a4817e4
# target                                                  0.0
# split                                                  test
# path      files/p19/p19991135/s57096024/4998e40c-698af87...
#
#                                                      361319  \
# dicom_id       6e57e7d7-a4f8c909-e7540997-0280112e-14da108f
# target                                                  0.0
# split                                                  test
# path      files/p19/p19991135/s57096024/6e57e7d7-a4f8c90...
#
#                                                      361320  \
# dicom_id       727e2aa5-ddfdd2ff-b5723867-520a758e-c81ca8e2
# target                                                  0.0
# split                                                  test
# path      files/p19/p19991135/s57757467/727e2aa5-ddfdd2f...
#
#                                                      361321  \
# dicom_id       313f1d75-23648c34-dd36ecad-5d0f94e8-93a40356
# target                                                  1.0
# split                                                  test
# path      files/p19/p19991135/s58283482/313f1d75-23648c3...
#
#                                                      361322  \
# dicom_id       4d0251eb-cc875c55-fde85f43-3a9d7888-c62772b8
# target                                                  1.0
# split                                                  test
# path      files/p19/p19991135/s58283482/4d0251eb-cc875c5...
#
#                                                      361323  \
# dicom_id       f6a7a470-9e057a45-d244e0e5-3efe1422-bb946478
# target                                                  1.0
# split                                                  test
# path      files/p19/p19991135/s58283482/f6a7a470-9e057a4...
#
#                                                      361324  \
# dicom_id       43636aec-98ae2504-18f03cac-4fe8e211-62049c6d
# target                                                  0.0
# split                                                  test
# path      files/p19/p19991135/s59381316/43636aec-98ae250...
#
#                                                      361325
# dicom_id       d122eb74-bc404dd2-45a05cd3-18505b72-5058fbdd
# target                                                  0.0
# split                                                  test
# path      files/p19/p19991135/s59381316/d122eb74-bc404dd...
#
# [4 rows x 361326 columns]
# train: (353622, 5)
# validate: (2867, 5)
# test: (4837, 5)
# filenames, 361326
# labels, 361326
# train: 353622
# validate: 2867
# test: 4837
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /mnt/datasets/uc5/UC5_pipeline_forked/eddl_src/ds_2_ecvl_ds.ipynb Cell 3' in <cell line: 34>()
#      <a href='vscode-notebook-cell://k8s-container%2Bcontext%3Ddeephealth-context%2Bpodname%3Duc5-pipeline-pylibs-cudnn-84c4d7994-8jbd7%2Bnamespace%3Dunito-uc5%2Bname%3Duc5-pipeline-pylibs-cudnn%2Bimage%3Ddhealth%252fpylibs%253a0.10.1-cudnn/mnt/datasets/uc5/UC5_pipeline_forked/eddl_src/ds_2_ecvl_ds.ipynb#ch0000002vscode-remote?line=30'>31</a> print(f"validate:", len(ids["validate"]))
#      <a href='vscode-notebook-cell://k8s-container%2Bcontext%3Ddeephealth-context%2Bpodname%3Duc5-pipeline-pylibs-cudnn-84c4d7994-8jbd7%2Bnamespace%3Dunito-uc5%2Bname%3Duc5-pipeline-pylibs-cudnn%2Bimage%3Ddhealth%252fpylibs%253a0.10.1-cudnn/mnt/datasets/uc5/UC5_pipeline_forked/eddl_src/ds_2_ecvl_ds.ipynb#ch0000002vscode-remote?line=31'>32</a> print(f"test:", len(ids["test"]))
# ---> <a href='vscode-notebook-cell://k8s-container%2Bcontext%3Ddeephealth-context%2Bpodname%3Duc5-pipeline-pylibs-cudnn-84c4d7994-8jbd7%2Bnamespace%3Dunito-uc5%2Bname%3Duc5-pipeline-pylibs-cudnn%2Bimage%3Ddhealth%252fpylibs%253a0.10.1-cudnn/mnt/datasets/uc5/UC5_pipeline_forked/eddl_src/ds_2_ecvl_ds.ipynb#ch0000002vscode-remote?line=33'>34</a> yml_ds = ecvl_yaml(filenames, labels, ids["train"], ids["validate"], ids["test"])
#      <a href='vscode-notebook-cell://k8s-container%2Bcontext%3Ddeephealth-context%2Bpodname%3Duc5-pipeline-pylibs-cudnn-84c4d7994-8jbd7%2Bnamespace%3Dunito-uc5%2Bname%3Duc5-pipeline-pylibs-cudnn%2Bimage%3Ddhealth%252fpylibs%253a0.10.1-cudnn/mnt/datasets/uc5/UC5_pipeline_forked/eddl_src/ds_2_ecvl_ds.ipynb#ch0000002vscode-remote?line=34'>35</a> for k, v in yml_ds.items():
#      <a href='vscode-notebook-cell://k8s-container%2Bcontext%3Ddeephealth-context%2Bpodname%3Duc5-pipeline-pylibs-cudnn-84c4d7994-8jbd7%2Bnamespace%3Dunito-uc5%2Bname%3Duc5-pipeline-pylibs-cudnn%2Bimage%3Ddhealth%252fpylibs%253a0.10.1-cudnn/mnt/datasets/uc5/UC5_pipeline_forked/eddl_src/ds_2_ecvl_ds.ipynb#ch0000002vscode-remote?line=35'>36</a>     print(f"{k}: {len(v)}")
#
# TypeError: ecvl_yaml() missing 2 required positional arguments: 'valid_ids' and 'test_ids'

# %%
# mimic view frontal/lateral, unbalanced
# 3 models, dataset stays the same, random seed changes

in_file = join("/mnt/datasets/mimic-cxr/training_data/mimic", "frontal_lateral_mimic.tsv")  # input dataset
exp_fld = "/mnt/datasets/uc5/UC5_pipeline_forked/experiments_eddl/mimic/view_unbal"  # output fld
img_fld = "/mnt/datasets/mimic-cxr/mimic-cxr-jpg/physionet.org/files/mimic-cxr-jpg/2.0.0"

dataset = pd.read_csv(in_file, sep="\t")
def adjust_path(path):
    path = path[:-len(".dcm")]
    path = join(img_fld, path + ".jpg")
    return path
display(dataset.T)

dataset["path"] = dataset["path"].apply(lambda path: adjust_path(path))
dataset = dataset.reset_index().set_index(pd.RangeIndex(len(dataset)))
splits = ["train", "validate", "test"]
filenames = []
labels = []
ids = {}
for s in splits:
    split = dataset.loc[dataset.split == s]
    print(f"{s}: {split.shape}")
    filenames += split.path.tolist()
    labels += split.target.tolist()
    ids[s] = split.index.values.tolist()
print(f"filenames, {len(filenames)}")
print(f"labels, {len(labels)}")

yml_ds = ecvl_yaml("view classifier", "frontal-lateral, unbalanced", filenames, labels, ids["train"], ids["validate"], ids["test"])
for k, v in yml_ds.items():
    print(f"{k}: {len(v)}")

n_folds = 3
for i in range(n_folds):
    out_fld = join(  exp_fld, f"fold_{i}" )
    os.makedirs(out_fld, exist_ok=True)
    fn = join(out_fld, "dataset.yml")
    
    with open(fn, "w") as fout:
        yaml.safe_dump(yml_ds, fout, default_flow_style=None)
    print(f"saved {fn}")
#     # takes up to
# Out:
#                                                      0       \
# dicom_id       02aa804e-bde0afdd-112c0b34-7bc16630-4e384014
# target                                                    1
# split                                                 train
# path      files/p10/p10000032/s50414267/02aa804e-bde0afd...
#
#                                                      1       \
# dicom_id       174413ec-4ec4c1f7-34ea26b7-c5f994f8-79ef1962
# target                                                    0
# split                                                 train
# path      files/p10/p10000032/s50414267/174413ec-4ec4c1f...
#
#                                                      2       \
# dicom_id       2a2277a9-b0ded155-c0de8eb9-c124d10e-82c5caab
# target                                                    1
# split                                                 train
# path      files/p10/p10000032/s53189527/2a2277a9-b0ded15...
#
#                                                      3       \
# dicom_id       e084de3b-be89b11e-20fe3f9f-9c8d8dfe-4cfd202c
# target                                                    0
# split                                                 train
# path      files/p10/p10000032/s53189527/e084de3b-be89b11...
#
#                                                      4       \
# dicom_id       68b5c4b1-227d0485-9cc38c3f-7b84ab51-4b472714
# target                                                    1
# split                                                 train
# path      files/p10/p10000032/s53911762/68b5c4b1-227d048...
#
#                                                      5       \
# dicom_id       fffabebf-74fd3a1f-673b6b41-96ec0ac9-2ab69818
# target                                                    1
# split                                                 train
# path      files/p10/p10000032/s53911762/fffabebf-74fd3a1...
#
#                                                      6       \
# dicom_id       ea030e7a-2e3b1346-bc518786-7a8fd698-f673b44c
# target                                                    1
# split                                                 train
# path      files/p10/p10000032/s56699142/ea030e7a-2e3b134...
#
#                                                      7       \
# dicom_id       096052b7-d256dc40-453a102b-fa7d01c6-1b22c6b4
# target                                                    1
# split                                                 train
# path      files/p10/p10000764/s57375967/096052b7-d256dc4...
#
#                                                      8       \
# dicom_id       b79e55c3-735ce5ac-64412506-cdc9ea79-f1af521f
# target                                                    0
# split                                                 train
# path      files/p10/p10000764/s57375967/b79e55c3-735ce5a...
#
#                                                      9       ...  \
# dicom_id       dcfeeac4-1597e318-d0e6736a-8b2c2238-47ac3f1b  ...
# target                                                    0  ...
# split                                                 train  ...
# path      files/p10/p10000764/s57375967/dcfeeac4-1597e31...  ...
#
#                                                      361316  \
# dicom_id       ebe1c050-b5cd68d5-7eb2b544-8906f022-e95300a4
# target                                                    1
# split                                                  test
# path      files/p19/p19991135/s56918032/ebe1c050-b5cd68d...
#
#                                                      361317  \
# dicom_id       3616a226-c86c9ea2-733dbb59-4b1530a0-ba7b25dc
# target                                                    0
# split                                                  test
# path      files/p19/p19991135/s57096024/3616a226-c86c9ea...
#
#                                                      361318  \
# dicom_id       4998e40c-698af874-8c293856-85757f55-1a4817e4
# target                                                    1
# split                                                  test
# path      files/p19/p19991135/s57096024/4998e40c-698af87...
#
#                                                      361319  \
# dicom_id       6e57e7d7-a4f8c909-e7540997-0280112e-14da108f
# target                                                    0
# split                                                  test
# path      files/p19/p19991135/s57096024/6e57e7d7-a4f8c90...
#
#                                                      361320  \
# dicom_id       727e2aa5-ddfdd2ff-b5723867-520a758e-c81ca8e2
# target                                                    1
# split                                                  test
# path      files/p19/p19991135/s57757467/727e2aa5-ddfdd2f...
#
#                                                      361321  \
# dicom_id       313f1d75-23648c34-dd36ecad-5d0f94e8-93a40356
# target                                                    1
# split                                                  test
# path      files/p19/p19991135/s58283482/313f1d75-23648c3...
#
#                                                      361322  \
# dicom_id       4d0251eb-cc875c55-fde85f43-3a9d7888-c62772b8
# target                                                    1
# split                                                  test
# path      files/p19/p19991135/s58283482/4d0251eb-cc875c5...
#
#                                                      361323  \
# dicom_id       f6a7a470-9e057a45-d244e0e5-3efe1422-bb946478
# target                                                    1
# split                                                  test
# path      files/p19/p19991135/s58283482/f6a7a470-9e057a4...
#
#                                                      361324  \
# dicom_id       43636aec-98ae2504-18f03cac-4fe8e211-62049c6d
# target                                                    0
# split                                                  test
# path      files/p19/p19991135/s59381316/43636aec-98ae250...
#
#                                                      361325
# dicom_id       d122eb74-bc404dd2-45a05cd3-18505b72-5058fbdd
# target                                                    1
# split                                                  test
# path      files/p19/p19991135/s59381316/d122eb74-bc404dd...
#
# [4 rows x 361326 columns]
# train: (353622, 5)
# validate: (2867, 5)
# test: (4837, 5)
# filenames, 361326
# labels, 361326
# name: 15
# description: 27
# classes: 2
# images: 361326
# split: 3
# saved /mnt/datasets/uc5/UC5_pipeline_forked/experiments_eddl/mimic/view_unbal/fold_0/dataset.yml
# saved /mnt/datasets/uc5/UC5_pipeline_forked/experiments_eddl/mimic/view_unbal/fold_1/dataset.yml
# saved /mnt/datasets/uc5/UC5_pipeline_forked/experiments_eddl/mimic/view_unbal/fold_2/dataset.yml
